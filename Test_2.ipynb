# %%
import config

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
results = sp.search(q="All out 2000s",limit=5,market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=All+out+2000s&type=track&market=GB&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3xCR5Ld0s2k0rK15PnaN98'},
#      'href': 'https://api.spotify.com/v1/albums/3xCR5Ld0s2k0rK15PnaN98',
#      'id': '3xCR5Ld0s2k0rK15PnaN98',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273338cd0ae44e7c9b9aa702f3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02338cd0ae44e7c9b9aa702f3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851338cd0ae44e7c9b9aa702f3f',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'The Greatest Trance Tracks of All Times',
#      'release_date': '2012-08-03',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3xCR5Ld0s2k0rK15PnaN98'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1faFXHs2iCutMnaCkrwsap'},
#       'href': 'https://api.spotify.com/v1/artists/1faFXHs2iCutMnaCkrwsap',
#       'id': '1faFXHs2iCutMnaCkrwsap',
#       'name': 'DJ Tom Stevens vs. Fridge',
#       'type': 'artist',
#       'uri': 'spotify:artist:1faFXHs2iCutMnaCkrwsap'}],
#     'disc_number': 1,
#     'duration_ms': 540040,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEG840701480'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0OfQzP53rzGbYZxf6CrI4w'},
#     'href': 'https://api.spotify.com/v1/tracks/0OfQzP53rzGbYZxf6CrI4w',
#     'id': '0OfQzP53rzGbYZxf6CrI4w',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Outface 2000 - DJ Tom Stevens Remixxx',
#     'popularity': 19,
#     'preview_url': 'https://p.scdn.co/mp3-preview/012b52caf1cf69f9ee2bbec5e288de047322a5a1?cid=3cdaae92842748f4b4e8491566562cd2',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:0OfQzP53rzGbYZxf6CrI4w'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZwdS5xdxEREPySFridCfh'},
#        'href': 'https://api.spotify.com/v1/artists/1ZwdS5xdxEREPySFridCfh',
#        'id': '1ZwdS5xdxEREPySFridCfh',
#        'name': '2Pac',
#        'type': 'artist',
#        'uri': 'spotify:artist:1ZwdS5xdxEREPySFridCfh'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0uT4bCZS9o5C1ThDa2VxpV'},
#      'href': 'https://api.spotify.com/v1/albums/0uT4bCZS9o5C1ThDa2VxpV',
#      'id': '0uT4bCZS9o5C1ThDa2VxpV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739e6b304642811ad3469dc8bc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029e6b304642811ad3469dc8bc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519e6b304642811ad3469dc8bc',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Until The End Of Time',
#      'release_date': '2001-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:0uT4bCZS9o5C1ThDa2VxpV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZwdS5xdxEREPySFridCfh'},
#       'href': 'https://api.spotify.com/v1/artists/1ZwdS5xdxEREPySFridCfh',
#       'id': '1ZwdS5xdxEREPySFridCfh',
#       'name': '2Pac',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ZwdS5xdxEREPySFridCfh'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2jp3Fk52x0HbymU0lNYbSC'},
#       'href': 'https://api.spotify.com/v1/artists/2jp3Fk52x0HbymU0lNYbSC',
#       'id': '2jp3Fk52x0HbymU0lNYbSC',
#       'name': 'Outlawz',
#       'type': 'artist',
#       'uri': 'spotify:artist:2jp3Fk52x0HbymU0lNYbSC'}],
#     'disc_number': 1,
#     'duration_ms': 332600,
#     'explicit': True,
#     'external_ids': {'isrc': 'USIR10110193'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/79aBywThq61WnAlDFHmm9n'},
#     'href': 'https://api.spotify.com/v1/tracks/79aBywThq61WnAlDFHmm9n',
#     'id': '79aBywThq61WnAlDFHmm9n',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'All Out',
#     'popularity': 40,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:79aBywThq61WnAlDFHmm9n'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7IH6YQVqv4F5CZI00YDfVV'},
#        'href': 'https://api.spotify.com/v1/artists/7IH6YQVqv4F5CZI00YDfVV',
#        'id': '7IH6YQVqv4F5CZI00YDfVV',
#        'name': 'Chemical Bathhouse',
#        'type': 'artist',
#        'uri': 'spotify:artist:7IH6YQVqv4F5CZI00YDfVV'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/
',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fc352dba10dc57036a24fbc1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fc352dba10dc57036a24fbc1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fc352dba10dc57036a24fbc1',
#        'width': 64}],
#      'is_playable': True,
#      'name': "2000's Coping Mechanisms",
#      'release_date': '2022-12-16',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1nu9Ih1tO8BozydY9Q1GOM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MppGcs4q1kdfISf0lf2CS'},
#       'href': 'https://api.spotify.com/v1/artists/5MppGcs4q1kdfISf0lf2CS',
#       'id': '5MppGcs4q1kdfISf0lf2CS',
#       'name': 'Checked-Out',
#       'type': 'artist',
#       'uri': 'spotify:artist:5MppGcs4q1kdfISf0lf2CS'}],
#     'disc_number': 1,
#     'duration_ms': 209742,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZTB92216889'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5B4ORkPyTbDFeU2DR4KOyr'},
#     'href': 'https://api.spotify.com/v1/tracks/5B4ORkPyTbDFeU2DR4KOyr',
#     'id': '5B4ORkPyTbDFeU2DR4KOyr',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Alligator Boy',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a7bef846112158320eff1bc984e84855ba5d6e8e?cid=3cdaae92842748f4b4e8491566562cd2',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:5B4ORkPyTbDFeU2DR4KOyr'}],
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?query=All+out+2000s&type=track&market=GB&offset=5&limit=5',
#   'offset': 0,
#   'previous': None,
#   'total': 158}}

# %%
from IPython.display import IFrame

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song("37i9dQZF1DX4o1oenSJRJd")
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/37i9dQZF1DX4o1oenSJRJd?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
get_playlist_tracks('spotify','37i9dQZF1DX4o1oenSJRJd')
# Out:
# [{'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#       'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#       'id': '6jJ0s89eD6GaHleKKya26X',
#       'name': 'Katy Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0r2BUyPTmpbfuz4rR39mLl'},
#     'href': 'https://api.spotify.com/v1/albums/0r2BUyPTmpbfuz4rR39mLl',
#     'id': '0r2BUyPTmpbfuz4rR39mLl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cd3978ebe35d93a07249b97f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cd3978ebe35d93a07249b97f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cd3978ebe35d93a07249b97f',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'One Of The Boys',
#     'release_date': '2008-06-17',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0r2BUyPTmpbfuz4rR39mLl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#      'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#      'id': '6jJ0s89eD6GaHleKKya26X',
#      'name': 'Katy Perry',
#      'type': 'artist',
#      'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#    'disc_number': 1,
#    'duration_ms': 220226,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA20802544'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0iGckQFyv6svOfAbAY9aWJ'},
#    'href': 'https://api.spotify.com/v1/tracks/0iGckQFyv6svOfAbAY9aWJ',
#    'id': '0iGckQFyv6svOfAbAY9aWJ',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1y4eb6hmAvsqlDOl3fx9kk'},
#     'href': 'https://api.spotify.com/v1/tracks/1y4eb6hmAvsqlDOl3fx9kk',
#     'id': '1y4eb6hmAvsqlDOl3fx9kk',
#     'type': 'track',
#     'uri': 'spotify:track:1y4eb6hmAvsqlDOl3fx9kk'},
#    'name': 'Hot N Cold',
#    'popularity': 79,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:0iGckQFyv6svOfAbAY9aWJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#       'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#       'id': '4gzpq5DPGxSnKTe4SA8HAU',
#       'name': 'Coldplay',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#     'href': 'https://api.spotify.com/v1/albums/6ZG5lRT77aJ3btmArcykra',
#     'id': '6ZG5lRT77aJ3btmArcykra',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733d92b2ad5af9fbc8637425f0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023d92b2ad5af9fbc8637425f0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513d92b2ad5af9fbc8637425f0',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Parachutes',
#     'release_date': '2000-07-10',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:6ZG5lRT77aJ3btmArcykra'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#      'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#      'id': '4gzpq5DPGxSnKTe4SA8HAU',
#      'name': 'Coldplay',
#      'type': 'artist',
#      'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#    'disc_number': 1,
#    'duration_ms': 266773,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE0000267'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3AJwUDP919kvQ9QcozQPxg'},
#    'href': 'https://api.spotify.com/v1/tracks/3AJwUDP919kvQ9QcozQPxg',
#    'id': '3AJwUDP919kvQ9QcozQPxg',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Yellow',
#    'popularity': 94,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c0d9119dc69cae75baf6463e21e43f433fdf5ff4?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:3AJwUDP919kvQ9QcozQPxg'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2cWBwpqMsDJC1ZUwz813lo'},
#     'href': 'https://api.spotify.com/v1/albums/2cWBwpqMsDJC1ZUwz813lo',
#     'id': '2cWBwpqMsDJC1ZUwz813lo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736ca5c90113b30c3c43ffb8f4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026

#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851346d77e155d854735410ed18',
#       'width': 64}],
#     'is_playable': True,
#     'name': '808s & Heartbreak',
#     'release_date': '2008-11-24',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3WFTGIO6E3Xh4paEOBY9OU'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#      'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#      'id': '5K4W6rqBFWDnAN6FQUkS6x',
#      'name': 'Kanye West',
#      'type': 'artist',
#      'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#    'disc_number': 1,
#    'duration_ms': 211000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70840511'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ZMJshw6UOvaTWWThYtEoW'},
#    'href': 'https://api.spotify.com/v1/tracks/4ZMJshw6UOvaTWWThYtEoW',
#    'id': '4ZMJshw6UOvaTWWThYtEoW',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4EWCNWgDS8707fNSZ1oaA5'},
#     'href': 'https://api.spotify.com/v1/tracks/4EWCNWgDS8707fNSZ1oaA5',
#     'id': '4EWCNWgDS8707fNSZ1oaA5',
#     'type': 'track',
#     'uri': 'spotify:track:4EWCNWgDS8707fNSZ1oaA5'},
#    'name': 'Heartless',
#    'popularity': 71,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4ZMJshw6UOvaTWWThYtEoW'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#       'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#       'id': '4F84IBURUo98rz4r61KF70',
#       'name': 'The White Stripes',
#       'type': 'artist',
#       'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6D9urpsOWWKtYvF6PaorGE'},
#     'href': 'https://api.spotify.com/v1/albums/6D9urpsOWWKtYvF6PaorGE',
#     'id': '6D9urpsOWWKtYvF6PaorGE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a69f71a8794e2d867a52f98f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a69f71a8794e2d867a52f98f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a69f71a8794e2d867a52f98f',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Elephant',
#     'release_date': '2003-04-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:6D9urpsOWWKtYvF6PaorGE'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#      'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#      'id': '4F84IBURUo98rz4r61KF70',
#      'name': 'The White Stripes',
#      'type': 'artist',
#      'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'}],
#    'disc_number': 1,
#    'duration_ms': 232106,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USVT10300001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3dPQuX8Gs42Y7b454ybpMR'},
#    'href': 'https://api.spotify.com/v1/tracks/3dPQuX8Gs42Y7b454ybpMR',
#    'id': '3dPQuX8Gs42Y7b454ybpMR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Seven Nation Army',
#    'popularity': 88,
#    'preview_url': 'https://p.scdn.co/mp3-preview/eca519f0a85862d9510d57d59df557081d375e3a?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3dPQuX8Gs42Y7b454ybpMR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AA28KZvwAUcZuOKwyblJQ'},
#       'href': 'https://api.spotify.com/v1/artists/3AA28KZvwAUcZuOKwyblJQ',
#       'id': '3AA28KZvwAUcZuOKwyblJQ',
#       'name': 'Gorillaz',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AA28KZvwAUcZuOKwyblJQ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0bUTHlWbkSQysoM3VsWldT'},
#     'href': 'https://api.spotify.com/v1/albums/0bUTHlWbkSQysoM3VsWldT',
#     'id': '0bUTHlWbkSQysoM3VsWldT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27319d85a472f328a6ed9b704cf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0219d85a472f328a6ed9b704cf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485119d85a472f328a6ed9b704cf',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Demon Days',
#     'release_date': '2005-05-23',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:0bUTHlWbkSQysoM3VsWldT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AA28KZvwAUcZuOKwyblJQ'},
#      'href': 'https://api.spotify.com/v1/artists/3AA28KZvwAUcZuOKwyblJQ',
#      'id': '3AA28KZvwAUcZuOKwyblJQ',
#      'name': 'Gorillaz',
#      'type': 'artist',
#      'uri': 'spotify:artist:3AA28KZvwAUcZuOKwyblJQ'}],
#    'disc_number': 1,
#    'duration_ms': 222640,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE0500172'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0d28khcov6AiegSCpG5TuT'},
#    'href': 'https://api.spotify.com/v1/tracks/0d28khcov6AiegSCpG5TuT',
#    'id': '0d28khcov6AiegSCpG5TuT',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Feel Good Inc.',
#    'popularity': 87,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b13a1bb2d8a04132982a49b6efee933cc9d67c7e?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0d28khcov6AiegSCpG5TuT'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gP3bB2nilZXLfPHJhMdvc'},
#       'href': 'https://api.spotify.com/v1/artists/7gP3bB2nilZXLfPHJhMdvc',
#       'id': '7gP3bB2nilZXLfPHJhMdvc',
#       'name': 'Foster The People',
#       'type': 'artist',
#       'uri': 'spotify:artist:7
'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#      'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#      'id': '7dGJo4pcD2V6oG8kP0tJRR',
#      'name': 'Eminem',
#      'type': 'artist',
#      'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Oa0bMld0A3u5OTYfMzp5h'},
#      'href': 'https://api.spotify.com/v1/artists/1Oa0bMld0A3u5OTYfMzp5h',
#      'id': '1Oa0bMld0A3u5OTYfMzp5h',
#      'name': 'Nate Dogg',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Oa0bMld0A3u5OTYfMzp5h'}],
#    'disc_number': 1,
#    'duration_ms': 297786,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USIR10211066'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4xkOaSrkexMciUUogZKVTS'},
#    'href': 'https://api.spotify.com/v1/tracks/4xkOaSrkexMciUUogZKVTS',
#    'id': '4xkOaSrkexMciUUogZKVTS',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Till I Collapse',
#    'popularity': 88,
#    'preview_url': None,
#    'track': True,
#    'track_number': 18,
#    'type': 'track',
# ...
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2V4bv1fNWfTcyRJKmej6Sj'},
#    'href': 'https://api.spotify.com/v1/tracks/2V4bv1fNWfTcyRJKmej6Sj',
#    'id': '2V4bv1fNWfTcyRJKmej6Sj',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Cooler Than Me - Single Mix',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/649f480a624454b97a73e354568fcfb9214fdd46?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2V4bv1fNWfTcyRJKmej6Sj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/39P7VD7qlg3Z0ltq60eHp7'},
#     'href': 'https://api.spotify.com/v1/albums/39P7VD7qlg3Z0ltq60eHp7',
#     'id': '39P7VD7qlg3Z0ltq60eHp7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273801c4d205accdba0a468a10b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02801c4d205accdba0a468a10b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851801c4d205accdba0a468a10b',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'I AM...SASHA FIERCE',
#     'release_date': '2008-11-17',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:39P7VD7qlg3Z0ltq60eHp7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#      'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#      'id': '6vWDO969PvNqNYHIOW5v0m',
#      'name': 'Beyoncé',
#      'type': 'artist',
#      'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#    'disc_number': 1,
#    'duration_ms': 261160,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10804556'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2CvOqDpQIMw69cCzWqr5yr'},
#    'href': 'https://api.spotify.com/v1/tracks/2CvOqDpQIMw69cCzWqr5yr',
#    'id': '2CvOqDpQIMw69cCzWqr5yr',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4JehYebiI9JE8sR8MisGVb'},
#     'href': 'https://api.spotify.com/v1/tracks/4JehYebiI9JE8sR8MisGVb',
#     'id': '4JehYebiI9JE8sR8MisGVb',
#     'type': 'track',
#     'uri': 'spotify:track:4JehYebiI9JE8sR8MisGVb'},
#    'name': 'Halo',
#    'popularity': 78,
#    'preview_url': 'https://p.scdn.co/mp3-preview/506a90b2b8f91b522c041d839d716302555452d2?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2CvOqDpQIMw69cCzWqr5yr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6u11Qbko2N2hP4lTBYjX86'},
#       'href': 'https://api.spotify.com/v1/artists/6u11Qbko2N2hP4lTBYjX86',
#       'id': '6u11Qbko2N2hP4lTBYjX86',
#       'name': 'Peter Bjorn and John',
#       'type': 'artist',
#       'uri': 'spotify:artist:6u11Qbko2N2hP4lTBYjX86'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5g4E06cxsFEMFE9hSekAt2'},
#     'href': 'https://api.spotify.com/v1/albums/5g4E06cxsFEMFE9hSekAt2',
#     'id': '5g4E06cxsFEMFE9hSekAt2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739cf4ac84b224a02f34d2e4f6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029cf4ac84b224a02f34d2e4f6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519cf4ac84b224a02f34d2e4f6',
#       'width': 64}],
#     'is_playable': True,
#     'name': "Writer's Block",
#     'release_date': '2006-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:5g4E06cxsFEMFE9hSekAt2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6u11Qbko2N2hP4lTBYjX86'},
#      'href': 'https://api.spotify.com/v1/artists/6u11Qbko2N2hP4lTBYjX86',
#      'id': '6u11Qbko2N2hP4lTBYjX86',
#      'name': 'Peter Bjorn and John',
#      'type': 'artist',
#      'uri': 'spotify:artist:6u11Qbko2N2hP4lTBYjX86'}],
#    'disc_number': 1,
#    'duration_ms': 276693,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'SEBPA0600024'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/
'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lKZWd6HiSCLfnDGrq9RAm'},
#       'href': 'https://api.spotify.com/v1/artists/5lKZWd6HiSCLfnDGrq9RAm',
#       'id': '5lKZWd6HiSCLfnDGrq9RAm',
#       'name': 'Leona Lewis',
#       'type': 'artist',
#       'uri': 'spotify:artist:5lKZWd6HiSCLfnDGrq9RAm'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0VaAFegRAAn4OCg7p4QjN5'},
#     'href': 'https://api.spotify.com/v1/albums/0VaAFegRAAn4OCg7p4QjN5',
#     'id': '0VaAFegRAAn4OCg7p4QjN5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27334fd9eb8cd48e518598aec55',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0234fd9eb8cd48e518598aec55',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485134fd9eb8cd48e518598aec55',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Spirit',
#     'release_date': '2007',
#     'release_date_precision': 'year',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:0VaAFegRAAn4OCg7p4QjN5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lKZWd6HiSCLfnDGrq9RAm'},
#      'href': 'https://api.spotify.com/v1/artists/5lKZWd6HiSCLfnDGrq9RAm',
#      'id': '5lKZWd6HiSCLfnDGrq9RAm',
#      'name': 'Leona Lewis',
#      'type': 'artist',
#      'uri': 'spotify:artist:5lKZWd6HiSCLfnDGrq9RAm'}],
#    'disc_number': 1,
#    'duration_ms': 262693,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBHMU0700049'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6LtPIXlIzPOTF8vTecYjRe'},
#    'href': 'https://api.spotify.com/v1/tracks/6LtPIXlIzPOTF8vTecYjRe',
#    'id': '6LtPIXlIzPOTF8vTecYjRe',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7wZUrN8oemZfsEd1CGkbXE'},
#     'href': 'https://api.spotify.com/v1/tracks/7wZUrN8oemZfsEd1CGkbXE',
#     'id': '7wZUrN8oemZfsEd1CGkbXE',
#     'type': 'track',
#     'uri': 'spotify:track:7wZUrN8oemZfsEd1CGkbXE'},
#    'name': 'Bleeding Love',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/068f41d644b4e5d15f390bd995628f03166219c7?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6LtPIXlIzPOTF8vTecYjRe'},
#   'video_thumbnail': {'url': None}}]

# %%
selected_playlist = get_playlist_tracks('spotify','37i9dQZF1DX4o1oenSJRJd')

# %%
selected_playlist
# Out:
# [{'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#       'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#       'id': '6jJ0s89eD6GaHleKKya26X',
#       'name': 'Katy Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0r2BUyPTmpbfuz4rR39mLl'},
#     'href': 'https://api.spotify.com/v1/albums/0r2BUyPTmpbfuz4rR39mLl',
#     'id': '0r2BUyPTmpbfuz4rR39mLl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cd3978ebe35d93a07249b97f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cd3978ebe35d93a07249b97f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cd3978ebe35d93a07249b97f',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'One Of The Boys',
#     'release_date': '2008-06-17',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0r2BUyPTmpbfuz4rR39mLl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#      'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#      'id': '6jJ0s89eD6GaHleKKya26X',
#      'name': 'Katy Perry',
#      'type': 'artist',
#      'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#    'disc_number': 1,
#    'duration_ms': 220226,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA20802544'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0iGckQFyv6svOfAbAY9aWJ'},
#    'href': 'https://api.spotify.com/v1/tracks/0iGckQFyv6svOfAbAY9aWJ',
#    'id': '0iGckQFyv6svOfAbAY9aWJ',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1y4eb6hmAvsqlDOl3fx9kk'},
#     'href': 'https://api.spotify.com/v1/tracks/1y4eb6hmAvsqlDOl3fx9kk',
#     'id': '1y4eb6hmAvsqlDOl3fx9kk',
#     'type': 'track',
#     'uri': 'spotify:track:1y4eb6hmAvsqlDOl3fx9kk'},
#    'name': 'Hot N Cold',
#    'popularity': 79,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:0iGckQFyv6svOfAbAY9aWJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#       'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#       'id': '4gzpq5DPGxSnKTe4SA8HAU',
#       'name': 'Coldplay',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#     'href': 'https://api.spotify.com/v1/albums/6ZG5lRT77aJ3btmArcykra',
#     'id': '6ZG5lRT77aJ3btmArcykra',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2
05-26',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1CEODgTmTwLyabvwd7HBty'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#      'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#      'id': '4gzpq5DPGxSnKTe4SA8HAU',
#      'name': 'Coldplay',
#      'type': 'artist',
#      'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#    'disc_number': 1,
#    'duration_ms': 242373,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE0800265'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4zOfy9kqJlG0ZXvcaSh4gv'},
#    'href': 'https://api.spotify.com/v1/tracks/4zOfy9kqJlG0ZXvcaSh4gv',
#    'id': '4zOfy9kqJlG0ZXvcaSh4gv',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1mea3bSkSGXuIRvnydlB5b'},
#     'href': 'https://api.spotify.com/v1/tracks/1mea3bSkSGXuIRvnydlB5b',
#     'id': '1mea3bSkSGXuIRvnydlB5b',
#     'type': 'track',
#     'uri': 'spotify:track:1mea3bSkSGXuIRvnydlB5b'},
#    'name': 'Viva La Vida',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fb9f4a9b0887326776b4fb7c6d331acd167a7778?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:4zOfy9kqJlG0ZXvcaSh4gv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6t7956yu5zYf5A829XRiHC'},
#     'href': 'https://api.spotify.com/v1/albums/6t7956yu5zYf5A829XRiHC',
#     'id': '6t7956yu5zYf5A829XRiHC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dbb3dd82da45b7d7f31b1b42',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dbb3dd82da45b7d7f31b1b42',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dbb3dd82da45b7d7f31b1b42',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'The Marshall Mathers LP',
#     'release_date': '2000-05-23',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:6t7956yu5zYf5A829XRiHC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#      'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#      'id': '7dGJo4pcD2V6oG8kP0tJRR',
#      'name': 'Eminem',
#      'type': 'artist',
#      'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#    'disc_number': 1,
#    'duration_ms': 284200,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USIR10000448'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3yfqSUWxFvZELEM4PmlwIR'},
#    'href': 'https://api.spotify.com/v1/tracks/3yfqSUWxFvZELEM4PmlwIR',
#    'id': '3yfqSUWxFvZELEM4PmlwIR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'The Real Slim Shady',
#    'popularity': 90,
#    'preview_url': None,
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:3yfqSUWxFvZELEM4PmlwIR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#       'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#       'id': '6XyY86QOPPrYVGvF9ch6wz',
#       'name': 'Linkin Park',
#       'type': 'artist',
#       'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4Gfnly5CzMJQqkUFfoHaP3'},
#     'href': 'https://api.spotify.com/v1/albums/4Gfnly5CzMJQqkUFfoHaP3',
#     'id': '4Gfnly5CzMJQqkUFfoHaP3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b4ad7ebaf4575f120eb3f193',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b4ad7ebaf4575f120eb3f193',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b4ad7ebaf4575f120eb3f193',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Meteora',
#     'release_date': '2003-03-24',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4Gfnly5CzMJQqkUFfoHaP3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#      'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#      'id': '6XyY86QOPPrYVGvF9ch6wz',
#      'name': 'Linkin Park',
#      'type': 'artist',
#      'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#    'disc_number': 1,
#    'duration_ms': 185586,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWB10300474'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2nLtzopw4rPReszdYBJU6h'},
#    'href': 'https://api.spotify.com/v1/tracks/2nLtzopw4rPReszdYBJU6h',
#    'id': '2nLtzopw4rPReszdYBJU6h',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Numb',
#    'popularity': 89,
#    'preview_url': 'https://p.scdn.co/mp3-preview/15e1178c9eb7f626ac1112ad8f56eccbec2cd6e5?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:2nLtzopw4rPReszdYBJU6h'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4pLuE50wL9T26lSv42X0J2'},
#     'href': 'https://api.spotify.com/v1/albums/4pLuE50wL9T26lSv42X0J2',
#     'id': '4pLuE50wL9T26lSv42X0J2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736bdcdf82ecce36bff808a40c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026bdcdf82ecce36bff808a40c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516bdcdf82ecce36bff808a40c',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Barrio Fino (Bonus Track Version)',
#     'release_date': '2004-07-13',
#     'release_date_precision': 'day',
#     'total_tracks': 23,
#     'type': 'album',
#     'uri': 'spotify:album:4pLuE50wL9T26lSv42X0J2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#      'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#      'id': '4VMYDCV2IEDYJArk749S6m',
#      'name': 'Daddy Yankee',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#    'disc_number': 1,
#    'duration_ms': 192600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM6N21759342'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/228BxWXUYQPJrJYHDLOHkj'},
#    'href': 'https://api.spotify.com/v1/tracks/228BxWXUYQPJrJYHDLOHkj',
#    'id': '228BxWXUYQPJrJYHDLOHkj',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Gasolina',
#    'popularity': 88,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7c545be6847f3a6b13c4ad9c70d10a34f49a92d3?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:228BxWXUYQPJrJYHDLOHkj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-05-15T14:01:41Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3WFTGIO6E3Xh4paEOBY9OU'},
#     'href': 'https://api.spotify.com/v1/albums/3WFTGIO6E3Xh4paEOBY9OU',
#     'id': '3WFTGIO6E3Xh4paEOBY9OU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273346d77e155d854735410ed18',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02346d77e155d854735410ed18',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851346d77e155d854735410ed18',
#       'width': 64}],
#     'is_playable': True,
#     'name': '808s & Heartbreak',
#     'release_date': '2008-11-24',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3WFTGIO6E3Xh4paEOBY9OU'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#      'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#      'id': '5K4W6rqBFWDnAN6FQUkS6x',
#      'name': 'Kanye West',
#      'type': 'artist',
#      'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#    'disc_number': 1,
#    'duration_ms': 211000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70840511'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ZMJshw6UOvaTWWThYtEoW'},
#    'href': 'https://api.spotify.com/v1/tracks/4ZMJshw6UOvaTWWThYtEoW',
#    'id': '4ZMJshw6UOvaTWWThYtEoW',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4EWCNWgDS8707fNSZ1oaA5'},
#     'href': 'https://api.spotify.com/v1/tracks/4EWCNWgDS8707fNSZ1oaA5',
#     'id': '4EWCNWgDS8707fNSZ1oaA5',
#     'type': 'track',
#     'uri': 'spotify:track:4EWCNWgDS8707fNSZ1oaA5'},
#    'name': 'Heartless',
#    'popularity': 71,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4ZMJshw6UOvaTWWThYtEoW'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#       'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#       'id': '4F84IBURUo98rz4r61KF70',
#       'name': 'The White Stripes',
#       'type': 'artist',
#       'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6D9urpsOWWKtYvF6PaorGE'},
#     'href': 'https://api.spotify.com/v1/albums/6D9urpsOWWKtYvF6PaorGE',
#     'id': '6D9urpsOWWKtYvF6PaorGE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a69f71a8794e2d867a52f98f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a69f71a8794e2d867a52f98f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a69f71a8794e2d867a52f98f',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Elephant',
#     'release_date': '2003-04-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:6D9urpsOWWKtYvF6PaorGE'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F84IBURUo98rz4r61KF70'},
#      'href': 'https://api.spotify.com/v1/artists/4F84IBURUo98rz4r61KF70',
#      'id': '4F84IBURUo98rz4r61KF70',
#      'name': 'The White Stripes',
#      'type': 'artist',
#      'uri': 'spotify:artist:4F84IBURUo98rz4r61KF70'}],
#    'disc_number': 1,
#    'duration_ms': 232106,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USVT10300001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3dPQuX8Gs42Y7b454ybpMR'},
#    'href': 'https://api.spotify.com/v1/tracks/3dPQuX8Gs42Y7b454ybpMR',
#    'id': '3dPQuX8Gs42Y7b454ybpMR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Seven Nation Army',
#    'popularity': 88,
#    'preview_url': 'https://p.scdn.co/mp3-preview/eca519f0a85862d9510d57d59df557081d375e3a?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3dPQuX8Gs42Y7b454ybpMR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AA28KZvwAUcZuOKwyblJQ'},
#       'href': 'https://api.spotify.com/v1/artists/3AA28KZvwAUcZuOKwyblJQ',
#       'id': '3AA28KZvwAUcZuOKwyblJQ',
#       'name': 'Gorillaz',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AA28KZvwAUcZuOKwyblJQ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0bUTHlWbkSQysoM3VsWldT'},
#     'href': 'https://api.spotify.com/v1/albums/0bUTHlWbkSQysoM3VsWldT',
#     'id': '0bUTHlWbkSQysoM3VsWldT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27319d85a472f328a6ed9b704cf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0219d85a472f328a6ed9b704cf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485119d85a472f328a6ed9b704cf',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Demon Days',
#     'release_date': '2005-05-23',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album

#      'type': 'artist',
#      'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#    'disc_number': 1,
#    'duration_ms': 309600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE0200772'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/75JFxkI2RXiU7L9VXzMkle'},
#    'href': 'https://api.spotify.com/v1/tracks/75JFxkI2RXiU7L9VXzMkle',
#    'id': '75JFxkI2RXiU7L9VXzMkle',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'The Scientist',
#    'popularity': 89,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cb283ce76eeee06a724b942d36a140cc088dd50f?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:75JFxkI2RXiU7L9VXzMkle'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2cWBwpqMsDJC1ZUwz813lo'},
#     'href': 'https://api.spotify.com/v1/albums/2cWBwpqMsDJC1ZUwz813lo',
#     'id': '2cWBwpqMsDJC1ZUwz813lo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736ca5c90113b30c3c43ffb8f4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026ca5c90113b30c3c43ffb8f4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516ca5c90113b30c3c43ffb8f4',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'The Eminem Show',
#     'release_date': '2002-05-26',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:2cWBwpqMsDJC1ZUwz813lo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#      'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#      'id': '7dGJo4pcD2V6oG8kP0tJRR',
#      'name': 'Eminem',
#      'type': 'artist',
#      'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Oa0bMld0A3u5OTYfMzp5h'},
#      'href': 'https://api.spotify.com/v1/artists/1Oa0bMld0A3u5OTYfMzp5h',
#      'id': '1Oa0bMld0A3u5OTYfMzp5h',
#      'name': 'Nate Dogg',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Oa0bMld0A3u5OTYfMzp5h'}],
#    'disc_number': 1,
#    'duration_ms': 297786,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USIR10211066'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4xkOaSrkexMciUUogZKVTS'},
#    'href': 'https://api.spotify.com/v1/tracks/4xkOaSrkexMciUUogZKVTS',
#    'id': '4xkOaSrkexMciUUogZKVTS',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Till I Collapse',
#    'popularity': 88,
#    'preview_url': None,
#    'track': True,
#    'track_number': 18,
#    'type': 'track',
# ...
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2V4bv1fNWfTcyRJKmej6Sj'},
#    'href': 'https://api.spotify.com/v1/tracks/2V4bv1fNWfTcyRJKmej6Sj',
#    'id': '2V4bv1fNWfTcyRJKmej6Sj',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Cooler Than Me - Single Mix',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/649f480a624454b97a73e354568fcfb9214fdd46?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2V4bv1fNWfTcyRJKmej6Sj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/39P7VD7qlg3Z0ltq60eHp7'},
#     'href': 'https://api.spotify.com/v1/albums/39P7VD7qlg3Z0ltq60eHp7',
#     'id': '39P7VD7qlg3Z0ltq60eHp7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273801c4d205accdba0a468a10b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02801c4d205accdba0a468a10b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851801c4d205accdba0a468a10b',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'I AM...SASHA FIERCE',
#     'release_date': '2008-11-17',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:39P7VD7qlg3Z0ltq60eHp7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#      'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#      'id': '6vWDO969PvNqNYHIOW5v0m',
#      'name': 'Beyoncé',
#      'type': 'artist',
#      'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#    'disc_number': 1,
#    'duration_ms': 261160,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10804556'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2CvOqDpQIMw69cCzWqr5yr'},
#    'href': 'https://api.spotify.com/v1/tracks/2CvOqDpQIMw69cCzWqr5yr',
#    'id': '2CvOqDpQIMw69cCzWqr5yr',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4JehYebiI9JE8sR8MisGVb'},
#     'href': 'https://api.spotify.com/v1/tracks/4JehYebiI9JE8sR8MisGVb',
#     'id': '4JehYebiI9JE8sR8MisGVb',
#     'type': 'track',
#     'uri': 'spotify:track:4JehYebiI9JE8sR8MisGVb'},
#    'name': 'Halo',
#    'popularity': 78,
#    'preview_url': 'https://p.scdn.co/mp3-preview/506a90b2b8f91b522c041d839d716302555452d2?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2CvOqDpQIMw69cCzWqr5yr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6u11Qbko2N2hP4lTBYjX86'},
#       'href': 'https://api.spotify.com/v1/artists/6u11Qbko2N2hP4lTBYjX86',
#       'id': '6u11Qbko2N2hP4lTBYjX86',
#       'name': 'Peter Bjorn and John',
#       'type': 'artist',
#       'uri': 'spotify:artist:6u11Qbko2N2hP4lTBYjX86'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5g4E06cxsFEMFE9hSekAt2'},
#     'href': 'https://api.spotify.com/v1/albums/5g4E06cxsFEMFE9hSekAt2',
#     'id': '5g4E06cxsFEMFE9hSekAt2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2
},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3EzFY9Rg0PpbADMth746zi'},
#     'href': 'https://api.spotify.com/v1/albums/3EzFY9Rg0PpbADMth746zi',
#     'id': '3EzFY9Rg0PpbADMth746zi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27360cb9332e8c8c7d8e50854b3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0260cb9332e8c8c7d8e50854b3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485160cb9332e8c8c7d8e50854b3',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Fearless (Big Machine Radio Release Special)',
#     'release_date': '2008-11-11',
#     'release_date_precision': 'day',
#     'total_tracks': 26,
#     'type': 'album',
#     'uri': 'spotify:album:3EzFY9Rg0PpbADMth746zi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'disc_number': 1,
#    'duration_ms': 232120,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCJY0803328'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1GEBsLDvJGw7kviySRI6GX'},
#    'href': 'https://api.spotify.com/v1/tracks/1GEBsLDvJGw7kviySRI6GX',
#    'id': '1GEBsLDvJGw7kviySRI6GX',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'You Belong With Me',
#    'popularity': 79,
#    'preview_url': None,
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:1GEBsLDvJGw7kviySRI6GX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-22T14:09:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lKZWd6HiSCLfnDGrq9RAm'},
#       'href': 'https://api.spotify.com/v1/artists/5lKZWd6HiSCLfnDGrq9RAm',
#       'id': '5lKZWd6HiSCLfnDGrq9RAm',
#       'name': 'Leona Lewis',
#       'type': 'artist',
#       'uri': 'spotify:artist:5lKZWd6HiSCLfnDGrq9RAm'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0VaAFegRAAn4OCg7p4QjN5'},
#     'href': 'https://api.spotify.com/v1/albums/0VaAFegRAAn4OCg7p4QjN5',
#     'id': '0VaAFegRAAn4OCg7p4QjN5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27334fd9eb8cd48e518598aec55',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0234fd9eb8cd48e518598aec55',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485134fd9eb8cd48e518598aec55',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Spirit',
#     'release_date': '2007',
#     'release_date_precision': 'year',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:0VaAFegRAAn4OCg7p4QjN5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lKZWd6HiSCLfnDGrq9RAm'},
#      'href': 'https://api.spotify.com/v1/artists/5lKZWd6HiSCLfnDGrq9RAm',
#      'id': '5lKZWd6HiSCLfnDGrq9RAm',
#      'name': 'Leona Lewis',
#      'type': 'artist',
#      'uri': 'spotify:artist:5lKZWd6HiSCLfnDGrq9RAm'}],
#    'disc_number': 1,
#    'duration_ms': 262693,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBHMU0700049'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6LtPIXlIzPOTF8vTecYjRe'},
#    'href': 'https://api.spotify.com/v1/tracks/6LtPIXlIzPOTF8vTecYjRe',
#    'id': '6LtPIXlIzPOTF8vTecYjRe',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7wZUrN8oemZfsEd1CGkbXE'},
#     'href': 'https://api.spotify.com/v1/tracks/7wZUrN8oemZfsEd1CGkbXE',
#     'id': '7wZUrN8oemZfsEd1CGkbXE',
#     'type': 'track',
#     'uri': 'spotify:track:7wZUrN8oemZfsEd1CGkbXE'},
#    'name': 'Bleeding Love',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/068f41d644b4e5d15f390bd995628f03166219c7?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6LtPIXlIzPOTF8vTecYjRe'},
#   'video_thumbnail': {'url': None}}]

# %%
id_songs_from_playlist = []

# %%
for i in selected_playlist:
    id_songs_from_playlist.append(i['track']['id'])

# %%
id_songs_from_playlist
# Out:
# ['0iGckQFyv6svOfAbAY9aWJ',
#  '3AJwUDP919kvQ9QcozQPxg',
#  '7lQ8MOhq6IN2w8EYcFNSUk',
#  '60a0Rd6pjrkxjPbaKzXjfq',
#  '5TRPicyLGbAF2LGBFbHGvO',
#  '003vvx7Niy0yvhvHt4a68B',
#  '3ZFTkvIE7kyPt6Nu3PEa7V',
#  '3Gf5nttwcX9aaSQXRWidEZ',
#  '3NLrRZoMF0Lx6zTlYqeIo4',
#  '34ceTg8ChN5HjrqiIYCn9Q',
#  '4VqPOruhp5EdPBeR92t6lQ',
#  '0VwNdo84DaVYLIkbVO86ND',
#  '3850dYVgOFIXJh5U4BFEWH',
#  '04KTF78FFg8sOHC1BADqbY',
#  '0vg4WnUWvze6pBOJDTq99k',
#  '1SKPmfSYaPsETbRHaiA18G',
#  '1AdYZ6X00nXmO613Y7GJOl',
#  '6SKwQghsR8AISlxhcwyA9R',
#  '3jlbL2OTD5YmIunYzgQTAN',
#  '2H1047e0oMSj10dgp7p2VG',
#  '1zNXF2svmdlNxfS5XeNUgr',
#  '7iL6o9tox1zgHpKUfh9vuC',
#  '1f2V8U1BiWaC9aJWmpOARe',
#  '0mUyMawtxj1CJ76kn9gIZK',
#  '2V4bv1fNWfTcyRJKmej6Sj',
#  '2CvOqDpQIMw69cCzWqr5yr',
#  '4dyx5SzxPPaD8xQIid5Wjj',
#  '1xNcBAoUw8Hz6LqK2jt4Ff',
#  '2x7MyWybabEz6Y6wvHuwGE',
#  '1GEBsLDvJGw7kviySRI6GX',
#  '6LtPIXlIzPOTF8vTecYjRe']

# %%
song_list =[]
for i in id_songs_from_playlist:
    song_list.append(sp.audio_features(i)[0])

# %%
song_list
# Out:
# [{'danceability': 0.706,
#   'energy': 0.841,
#   'key': 7,
#   'loudness': -3.956,
#   'mode': 1,
#   'speechiness': 0.0418,
#   'acousticness': 7.95e-05,
#   'instrumentalness': 0,
#   'liveness': 0.0688,
#   'valence': 0.861,
#   'tempo': 132.032,
#   'type': 'audio_features',
#   'id': '0iGckQFyv6svOfAbAY9aWJ',
#   'uri': 'spotify:track:0iGckQFyv6svOfAbAY9aWJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0iGckQFyv6svOfAbAY9aWJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0iGckQFyv6svOfAbAY9aWJ',
#   'duration_ms': 220227,
#   'time_signature': 4},
#  {'danceability': 0.429,
#   'energy': 0.661,
#   'key': 11,
#   'loudness': -7.227,
#   'mode': 1,
#   'speechiness': 0.0281,
#   'acousticness': 0.00239,
#   'instrumentalness': 0.000121,
#   'liveness': 0.234,
#   'valence': 0.285,
#   'tempo': 173.372,
#   'type': 'audio_features',
#   'id': '3AJwUDP919kvQ9QcozQPxg',
#   'uri': 'spotify:track:3AJwUDP919kvQ9QcozQPxg',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AJwUDP919kvQ9QcozQPxg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AJwUDP919kvQ9QcozQPxg',
#   'duration_ms': 266773,
#   'time_signature': 4},
#  {'danceability': 0.908,
#   'energy': 0.669,
#   'key': 7,
#   'loudness': -2.827,
#   'mode': 1,
#   'speechiness': 0.0738,
#   'acousticness': 0.00286,
#   'instrumentalness': 0,
#   'liveness': 0.237,
#   'valence': 0.662,
#   'tempo': 112.238,
#   'type': 'audio_features',
#   'id': '7lQ8MOhq6IN2w8EYcFNSUk',
#   'uri': 'spotify:track:7lQ8MOhq6IN2w8EYcFNSUk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7lQ8MOhq6IN2w8EYcFNSUk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7lQ8MOhq6IN2w8EYcFNSUk',
#   'duration_ms': 290320,
#   'time_signature': 4},
#  {'danceability': 0.556,
#   'energy': 0.864,
#   'key': 3,
#   'loudness': -5.87,
#   'mode': 0,
#   'speechiness': 0.0584,
#   'acousticness': 0.00958,
#   'instrumentalness': 0,
#   'liveness': 0.209,
#   'valence': 0.4,
#   'tempo': 105.143,
#   'type': 'audio_features',
#   'id': '60a0Rd6pjrkxjPbaKzXjfq',
#   'uri': 'spotify:track:60a0Rd6pjrkxjPbaKzXjfq',
#   'track_href': 'https://api.spotify.com/v1/tracks/60a0Rd6pjrkxjPbaKzXjfq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60a0Rd6pjrkxjPbaKzXjfq',
#   'duration_ms': 216880,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.628,
#   'key': 6,
#   'loudness': -7.578,
#   'mode': 0,
#   'speechiness': 0.0399,
#   'acousticness': 0.0381,
#   'instrumentalness': 0,
#   'liveness': 0.386,
#   'valence': 0.43,
#   'tempo': 90.482,
#   'type': 'audio_features',
#   'id': '5TRPicyLGbAF2LGBFbHGvO',
#   'uri': 'spotify:track:5TRPicyLGbAF2LGBFbHGvO',
#   'track_href': 'https://api.spotify.com/v1/tracks/5TRPicyLGbAF2LGBFbHGvO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5TRPicyLGbAF2LGBFbHGvO',
#   'duration_ms': 237507,
#   'time_signature': 4},
#  {'danceability': 0.352,
#   'energy': 0.911,
#   'key': 1,
#   'loudness': -5.23,
#   'mode': 1,
#   'speechiness': 0.0747,
#   'acousticness': 0.00121,
#   'instrumentalness': 0,
#   'liveness': 0.0995,
#   'valence': 0.236,
#   'tempo': 148.033,
#   'type': 'audio_features',
#   'id': '003vvx7Niy0yvhvHt4a68B',
#   'uri': 'spotify:track:003vvx7Niy0yvhvHt4a68B',
#   'track_href': 'https://api.spotify.com/v1/tracks/003vvx7Niy0yvhvHt4a68B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/003vvx7Niy0yvhvHt4a68B',
#   'duration_ms': 222973,
#   'time_signature': 4},
#  {'danceability': 0.778,
#   'energy': 0.824,
#   'key': 10,
#   'loudness': -5.892,
#   'mode': 0,
#   'speechiness': 0.0707,
#   'acousticness': 0.284,
#   'instrumentalness': 0,
#   'liveness': 0.405,
#   'valence': 0.758,
#   'tempo': 100.024,
#   'type': 'audio_features',
#   'id': '3ZFTkvIE7kyPt6Nu3PEa7V',
#   'uri': 'spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZFTkvIE7kyPt6Nu3PEa7V',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZFTkvIE7kyPt6Nu3PEa7V',
#   'duration_ms': 218093,
#   'time_signature': 4},
#  {'danceability': 0.699,
#   'energy': 0.76,
#   'key': 5,
#   'loudness': -3.173,
#   'mode': 1,
#   'speechiness': 0.0677,
#   'acousticness': 0.00223,
#   'instrumentalness': 0,
#   'liveness': 0.132,
#   'valence': 0.696,
#   'tempo': 129.996,
#   'type': 'audio_features',
#   'id': '14iN3o8ptQ8cFVZTEmyQRV',
#   'uri': 'spotify:track:14iN3o8ptQ8cFVZTEmyQRV',
#   'track_href': 'https://api.spotify.com/v1/tracks/14iN3o8ptQ8cFVZTEmyQRV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/14iN3o8ptQ8cFVZTEmyQRV',
#   'duration_ms': 179640,
#   'time_signature': 4},
#  {'danceability': 0.486,
#   'energy': 0.617,
#   'key': 5,
#   'loudness': -7.115,
#   'mode': 0,
#   'speechiness': 0.0287,
#   'acousticness': 0.0954,
#   'instrumentalness': 3.23e-06,
#   'liveness': 0.109,
#   'valence': 0.417,
#   'tempo': 138.015,
#   'type': 'audio_features',
#   'id': '4zOfy9kqJlG0ZXvcaSh4gv',
#   'uri': 'spotify:track:4zOfy9kqJlG0ZXvcaSh4gv',
#   'track_href': 'https://api.spotify.com/v1/tracks/4zOfy9kqJlG0ZXvcaSh4gv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zOfy9kqJlG0ZXvcaSh4gv',
#   'duration_ms': 242373,
#   'time_signature': 4},
#  {'danceability': 0.949,
#   'energy': 0.661,
#   'key': 5,
#   'loudness': -4.244,
#   'mode': 0,
#   'speechiness': 0.0572,
#   'acousticness': 0.0302,
#   'instrumentalness': 0,
#   'liveness': 0.0454,
#   'valence': 0.76,
#   'tempo': 104.504,
#   'type': 'audio_features',
#   'id': '3yfqSUWxFvZELEM4PmlwIR',
#   'uri': 'spotify:track:3yfqSUWxFvZELEM4PmlwIR',
#   'track_href': 'https://api.spotify.com/v1/tracks/3yfqSUWxFvZELEM4PmlwIR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yfqSUWxFvZELEM4PmlwIR',
#   'duration_ms': 284200,
#   'time_signature': 4},
#  {'danceability': 0.496,
#   'energy': 0.863,
#   'key': 9,
#   'loudness': -4.153,
#   'mode': 1,
#   'speechiness': 0.0381,
#   'acousticness': 0.0046,
#   'instrumentalness': 0,
#   'liveness': 0.639,
#   'valence': 0.243,
#   'tempo': 110.018,
#   'type': 'audio_features',
#   'id': '2nLtzopw4rPReszdYBJU6h',
#   'uri': 'spotify:track:2nLtzopw4rPReszdYBJU6h',
#   'track_href': 'https://api.spotify.com/v1/tracks/2nLtzopw4rPReszdYBJU6h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2nLtzopw4rPReszdYBJU6h',
#   'duration_ms': 185587,
#   'time_signature': 4},
#  {'danceability': 0.852,
#   'energy': 0.797,
#   'key': 0,
#   'loudness': -6.543,
#   'mode': 1,
#   'speechiness': 0.0614,
#   'acousticness': 0.322,
#   'instrumentalness': 2.69e-06,
#   'liveness': 0.0845,
#   'valence': 0.741,
#   'tempo': 96.008,
#   'type': 'audio_features',
#   'id': '228BxWXUYQPJrJYHDLOHkj',
#   'uri': 'spotify:track:228BxWXUYQPJrJYHDLOHkj',
#   'track_href': 'https://api.spotify.com/v1/tracks/228BxWXUYQPJrJYHDLOHkj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/228BxWXUYQPJrJYHDLOHkj',
#   'duration_ms': 192600,
#   'time_signature': 4},
#  {'danceability': 0.79,
#   'energy': 0.647,
#   'key': 10,
#   'loudness': -5.983,
#   'mode': 0,
#   'speechiness': 0.136,
#   'acousticness': 0.0515,
#   'instrumentalness': 0,
#   'liveness': 0.248,
#   'valence': 0.654,
#   'tempo': 87.999,
#   'type': 'audio_features',
#   'id': '4ZMJshw6UOvaTWWThYtEoW',
#   'uri': 'spotify:track:4ZMJshw6UOvaTWWThYtEoW',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ZMJshw6UOvaTWWThYtEoW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ZMJshw6UOvaTWWThYtEoW',
#   'duration_ms': 211000,
#   'time_signature': 4},
#  {'danceability': 0.743,
#   'energy': 0.446,
#   'key': 4,
#   'loudness': -7.807,
#   'mode': 0,
#   'speechiness': 0.0683,
#   'acousticness': 0.0039,
#   'instrumentalness': 0.118,
#   'liveness': 0.337,
#   'valence': 0.278,
#   'tempo': 123.596,
#   'type': 'audio_features',
#   'id': '3dPQuX8Gs42Y7b454ybpMR',
#   'uri': 'spotify:track:3dPQuX8Gs42Y7b454ybpMR',
#   'track_href': 'https://api.spotify.com/v1/tracks/3dPQuX8Gs42Y7b454ybpMR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3dPQuX8Gs42Y7b454ybpMR',
#   'duration_ms': 232107,
#   'time_signature': 4},
#  {'danceability': 0.818,
#   'energy': 0.705,
#   'key': 6,
#   'loudness': -6.679,
#   'mode': 1,
#   'speechiness': 0.177,
#   'acousticness': 0.00836,
#   'instrumentalness': 0.00233,
#   'liveness': 0.613,
#   'valence': 0.772,
#   'tempo': 138.559,
#   'type': 'audio_features',
#   'id': '0d28khcov6AiegSCpG5TuT',
#   'uri': 'spotify:track:0d28khcov6AiegSCpG5TuT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0d28khcov6AiegSCpG5TuT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0d28khcov6AiegSCpG5TuT',
#   'duration_ms': 222640,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.71,
#   'key': 5,
#   'loudness': -5.849,
#   'mode': 0,
#   'speechiness': 0.0292,
#   'acousticness': 0.145,
#   'instrumentalness': 0.115,
#   'liveness': 0.0956,
#   'valence': 0.965,
#   'tempo': 127.975,
#   'type': 'audio_features',
#   'id': '7w87IxuO7BDcJ3YUqCyMTT',
#   'uri': 'spotify:track:7w87IxuO7BDcJ3YUqCyMTT',
#   'track_href': 'https://api.spotify.com/v1/tracks/7w87IxuO7BDcJ3YUqCyMTT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7w87IxuO7BDcJ3YUqCyMTT',
#   'duration_ms': 239600,
#   'time_signature': 4},
#  {'danceability': 0.649,
#   'energy': 0.815,
#   'key': 3,
#   'loudness': -3.796,
#   'mode': 0,
#   'speechiness': 0.0415,
#   'acousticness': 0.00125,
#   'instrumentalness': 4.31e-05,
#   'liveness': 0.671,
#   'valence': 0.765,
#   'tempo': 126.03,
#   'type': 'audio_features',
#   'id': '455AfCsOhhLPRc68sE01D8',
#   'uri': 'spotify:track:455AfCsOhhLPRc68sE01D8',
#   'track_href': 'https://api.spotify.com/v1/tracks/455AfCsOhhLPRc68sE01D8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/455AfCsOhhLPRc68sE01D8',
#   'duration_ms': 230747,
#   'time_signature': 4},
#  {'danceability': 0.557,
#   'energy': 0.442,
#   'key': 5,
#   'loudness': -7.224,
#   'mode': 1,
#   'speechiness': 0.0243,
#   'acousticness': 0.731,
#   'instrumentalness': 1.46e-05,
#   'liveness': 0.11,
#   'valence': 0.213,
#   'tempo': 146.277,
#   'type': 'audio_features',
#   'id': '75JFxkI2RXiU7L9VXzMkle',
#   'uri': 'spotify:track:75JFxkI2RXiU7L9VXzMkle',
#   'track_href': 'https://api.spotify.com/v1/tracks/75JFxkI2RXiU7L9VXzMkle',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/75JFxkI2RXiU7L9VXzMkle',
#   'duration_ms': 309600,
#   'time_signature': 4},
#  {'danceability': 0.548,
#   'energy': 0.847,
#   'key': 1,
#   'loudness': -3.237,
#   'mode': 1,
#   'speechiness': 0.186,
#   'acousticness': 0.0622,
#   'instrumentalness': 0,
#   'liveness': 0.0816,
#   'valence': 0.1,
#   'tempo': 171.447,
#   'type': 'audio_features',
#   'id': '4xkOaSrkexMciUUogZKVTS',
#   'uri': 'spotify:track:4xkOaSrkexMciUUogZKVTS',
#   'track_href': 'https://api.spotify.com/v1/tracks/4xkOaSrkexMciUUogZKVTS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4xkOaSrkexMciUUogZKVTS',
#   'duration_ms': 297787,
#   'time_signature': 4},
#  {'danceability': 0.808,
#   'energy': 0.97,
#   'key': 10,
#   'loudness': -6.098,
#   'mode': 0,
#   'speechiness': 0.0506,
#   'acousticness': 0.0569,
#   'instrumentalness': 6.13e-05,
#   'liveness': 0.154,
#   'valence': 0.868,
#   'tempo': 114.328,
#   'type': 'audio_features',
#   'id': '2gam98EZKrF9XuOkU13ApN',
#   'uri': 'spotify:track:2gam98EZKrF9XuOkU13ApN',
#   'track_href': 'https://api.spotify.com/v1/tracks/2gam98EZKrF9XuOkU13ApN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2gam98EZKrF9XuOkU13ApN',
#   'duration_ms': 242293,
#   'time_signature': 4},
#  {'danceability': 0.583,
#   'energy': 0.829,
#   'key': 1,
#   'loudness': -4.603,
#   'mode': 1,
#   'speechiness': 0.134,
#   'acousticness': 0.00864,
#   'instrumentalness': 0,
#   'liveness': 0.0426,
#   'valence': 0.575,
#   'tempo': 174.028,
#   'type': 'audio_features',
#   'id': '49FYlytm3dAAraYgpoJZux',
#   'uri': 'spotify:track:49FYlytm3dAAraYgpoJZux',
#   'track_href': 'https://api.spotify.com/v1/tracks/49FYlytm3dAAraYgpoJZux',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/49FYlytm3dAAraYgpoJZux',
#   'duration_ms': 275987,
#   'time_signature': 4},
#  {'danceability': 0.331,
#   'energy': 0.943,
#   'key': 4,
#   'loudness': -3.188,
#   'mode': 0,
#   'speechiness': 0.0698,
#   'acousticness': 0.00721,
#   'instrumentalness': 2.06e-06,
#   'liveness': 0.242,
#   'valence': 0.296,
#   'tempo': 94.612,
#   'type': 'audio_features',
#   'id': '0COqiPhxzoWICwFCS4eZcp',
#   'uri': 'spotify:track:0COqiPhxzoWICwFCS4eZcp',
#   'track_href': 'https://api.spotify.com/v1/tracks/0COqiPhxzoWICwFCS4eZcp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0COqiPhxzoWICwFCS4eZcp',
#   'duration_ms': 235893,
#   'time_signature': 4},
#  {'danceability': 0.673,
#   'energy': 0.886,
#   'key': 1,
#   'loudness': -4.44,
#   'mode': 0,
#   'speechiness': 0.0431,
#   'acousticness': 0.185,
#   'instrumentalness': 0,
#   'liveness': 0.0826,
#   'valence': 0.795,
#   'tempo': 97.012,
#   'type': 'audio_features',
#   'id': '4HlFJV71xXKIGcU3kRyttv',
#   'uri': 'spotify:track:4HlFJV71xXKIGcU3kRyttv',
#   'track_href': 'https://api.spotify.com/v1/tracks/4HlFJV71xXKIGcU3kRyttv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4HlFJV71xXKIGcU3kRyttv',
#   'duration_ms': 216773,
#   'time_signature': 4},
#  {'danceability': 0.894,
#   'energy': 0.791,
#   'key': 2,
#   'loudness': -4.699,
#   'mode': 1,
#   'speechiness': 0.112,
#   'acousticness': 0.0183,
#   'instrumentalness': 0,
#   'liveness': 0.0388,
#   'valence': 0.583,
#   'tempo': 105.018,
#   'type': 'audio_features',
#   'id': '5rb9QrpfcKFHM1EUbSIurX',
#   'uri': 'spotify:track:5rb9QrpfcKFHM1EUbSIurX',
#   'track_href': 'https://api.spotify.com/v1/tracks/5rb9QrpfcKFHM1EUbSIurX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5rb9QrpfcKFHM1EUbSIurX',
#   'duration_ms': 250373,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.605,
#   'key': 8,
#   'loudness': -7.371,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.00481,
#   'instrumentalness': 0,
#   'liveness': 0.0605,
#   'valence': 0.394,
#   'tempo': 126.091,
#   'type': 'audio_features',
#   'id': '360UM2DaiHZPRu0EsrOvMp',
#   'uri': 'spotify:track:360UM2DaiHZPRu0EsrOvMp',
#   'track_href': 'https://api.spotify.com/v1/tracks/360UM2DaiHZPRu0EsrOvMp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/360UM2DaiHZPRu0EsrOvMp',
#   'duration_ms': 292707,
#   'time_signature': 4},
#  {'danceability': 0.727,
#   'energy': 0.974,
#   'key': 4,
#   'loudness': -2.261,
#   'mode': 0,
#   'speechiness': 0.0664,
#   'acousticness': 0.103,
#   'instrumentalness': 0.000532,
#   'liveness': 0.174,
#   'valence': 0.965,
#   'tempo': 79.526,
#   'type': 'audio_features',
#   'id': '2PpruBYCo4H7WOBJ7Q2EwM',
#   'uri': 'spotify:track:2PpruBYCo4H7WOBJ7Q2EwM',
#   'track_href': 'https://api.spotify.com/v1/tracks/2PpruBYCo4H7WOBJ7Q2EwM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2PpruBYCo4H7WOBJ7Q2EwM',
#   'duration_ms': 235213,
#   'time_signature': 4},
#  {'danceability': 0.755,
#   'energy': 0.837,
#   'key': 2,
#   'loudness': -2.718,
#   'mode': 0,
#   'speechiness': 0.142,
#   'acousticness': 0.0991,
#   'instrumentalness': 0,
#   'liveness': 0.289,
#   'valence': 0.714,
#   'tempo': 120.028,
#   'type': 'audio_features',
#   'id': '0HPD5WQqrq7wPWR7P7Dw1i',
#   'uri': 'spotify:track:0HPD5WQqrq7wPWR7P7Dw1i',
#   'track_href': 'https://api.spotify.com/v1/tracks/0HPD5WQqrq7wPWR7P7Dw1i',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0HPD5WQqrq7wPWR7P7Dw1i',
#   'duration_ms': 199693,
#   'time_signature': 4},
#  {'danceability': 0.209,
#   'energy': 0.417,
#   'key': 3,
#   'loudness': -8.74,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.164,
#   'instrumentalness': 0.00196,
#   'liveness': 0.113,
#   'valence': 0.124,
#   'tempo': 138.178,
#   'type': 'audio_features',
#   'id': '7LVHVU3tWfcxj5aiPFEW4Q',
#   'uri': 'spotify:track:7LVHVU3tWfcxj5aiPFEW4Q',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LVHVU3tWfcxj5aiPFEW4Q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LVHVU3tWfcxj5aiPFEW4Q',
#   'duration_ms': 295533,
#   'time_signature': 4},
#  {'danceability': 0.618,
#   'energy': 0.938,
#   'key': 9,
#   'loudness': -3.442,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.0179,
#   'instrumentalness': 0,
#   'liveness': 0.167,
#   'valence': 0.875,
#   'tempo': 91.455,
#   'type': 'audio_features',
#   'id': '3ZOEytgrvLwQaqXreDs2Jx',
#   'uri': 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZOEytgrvLwQaqXreDs2Jx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZOEytgrvLwQaqXreDs2Jx',
#   'duration_ms': 269000,
#   'time_signature': 4},
#  {'danceability': 0.491,
#   'energy': 0.956,
#   'key': 11,
#   'loudness': -1.538,
#   'mode': 1,
#   'speechiness': 0.392,
#   'acousticness': 0.0295,
#   'instrumentalness': 0,
#   'liveness': 0.46,
#   'valence': 0.811,
#   'tempo': 173.585,
#   'type': 'audio_features',
#   'id': '2igwFfvr1OAGX9SKDCPBwO',
#   'uri': 'spotify:track:2igwFfvr1OAGX9SKDCPBwO',
#   'track_href': 'https://api.spotify.com/v1/tracks/2igwFfvr1OAGX9SKDCPBwO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2igwFfvr1OAGX9SKDCPBwO',
#   'duration_ms': 276920,
#   'time_signature': 4},
#  {'danceability': 0.78,
#   'energy': 0.768,
#   'key': 6,
#   'loudness': -4.325,
#   'mode': 0,
#   'speechiness': 0.238,
#   'acousticness': 0.0371,
#   'instrumentalness': 2.34e-06,
#   'liveness': 0.518,
#   'valence': 0.507,
#   'tempo': 80.063,
#   'type': 'audio_features',
#   'id': '3UmaczJpikHgJFyBTAJVoz',
#   'uri': 'spotify:track:3UmaczJpikHgJFyBTAJVoz',
#   'track_href': 'https://api.spotify.com/v1/tracks/3UmaczJpikHgJFyBTAJVoz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3UmaczJpikHgJFyBTAJVoz',
#   'duration_ms': 404107,
#   'time_signature': 4},
#  {'danceability': 0.939,
#   'energy': 0.742,
#   'key': 5,
#   'loudness': -5.171,
#   'mode': 0,
#   'speechiness': 0.0467,
#   'acousticness': 0.321,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'valence': 0.924,
#   'tempo': 118.978,
#   'type': 'audio_features',
#   'id': '2kQuhkFX7uSVepCD3h29g5',
#   'uri': 'spotify:track:2kQuhkFX7uSVepCD3h29g5',
#   'track_href': 'https://api.spotify.com/v1/tracks/2kQuhkFX7uSVepCD3h29g5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2kQuhkFX7uSVepCD3h29g5',
#   'duration_ms': 212360,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.905,
#   'key': 9,
#   'loudness': -5.653,
#   'mode': 1,
#   'speechiness': 0.054,
#   'acousticness': 0.00172,
#   'instrumentalness': 0.0104,
#   'liveness': 0.136,
#   'valence': 0.374,
#   'tempo': 153.398,
#   'type': 'audio_features',
#   'id': '5A1FmxbYVRZKy4nc16MAue',
#   'uri': 'spotify:track:5A1FmxbYVRZKy4nc16MAue',
#   'track_href': 'https://api.spotify.com/v1/tracks/5A1FmxbYVRZKy4nc16MAue',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5A1FmxbYVRZKy4nc16MAue',
#   'duration_ms': 203347,
#   'time_signature': 4},
#  {'danceability': 0.696,
#   'energy': 0.921,
#   'key': 0,
#   'loudness': -3.755,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.00314,
#   'instrumentalness': 5.24e-05,
#   'liveness': 0.0842,
#   'valence': 0.714,
#   'tempo': 119.001,
#   'type': 'audio_features',
#   'id': '0SiywuOBRcynK0uKGWdCnn',
#   'uri': 'spotify:track:0SiywuOBRcynK0uKGWdCnn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0SiywuOBRcynK0uKGWdCnn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SiywuOBRcynK0uKGWdCnn',
#   'duration_ms': 294573,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.849,
#   'key': 2,
#   'loudness': -5.428,
#   'mode': 1,
#   'speechiness': 0.0526,
#   'acousticness': 0.0371,
#   'instrumentalness': 0,
#   'liveness': 0.058,
#   'valence': 0.903,
#   'tempo': 162.152,
#   'type': 'audio_features',
#   'id': '6GG73Jik4jUlQCkKg9JuGO',
#   'uri': 'spotify:track:6GG73Jik4jUlQCkKg9JuGO',
#   'track_href': 'https://api.spotify.com/v1/tracks/6GG73Jik4jUlQCkKg9JuGO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GG73Jik4jUlQCkKg9JuGO',
#   'duration_ms': 165853,
#   'time_signature': 4},
#  {'danceability': 0.843,
#   'energy': 0.806,
#   'key': 4,
#   'loudness': -5.946,
#   'mode': 0,
#   'speechiness': 0.269,
#   'acousticness': 0.143,
#   'instrumentalness': 0,
#   'liveness': 0.0771,
#   'valence': 0.613,
#   'tempo': 94.948,
#   'type': 'audio_features',
#   'id': '0I3q5fE6wg7LIfHGngUTnV',
#   'uri': 'spotify:track:0I3q5fE6wg7LIfHGngUTnV',
#   'track_href': 'https://api.spotify.com/v1/tracks/0I3q5fE6wg7LIfHGngUTnV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0I3q5fE6wg7LIfHGngUTnV',
#   'duration_ms': 270507,
#   'time_signature': 4},
#  {'danceability': 0.577,
#   'energy': 0.749,
#   'key': 5,
#   'loudness': -7.215,
#   'mode': 0,
#   'speechiness': 0.0279,
#   'acousticness': 0.599,
#   'instrumentalness': 0.0115,
#   'liveness': 0.183,
#   'valence': 0.255,
#   'tempo': 130.97,
#   'type': 'audio_features',
#   'id': '0BCPKOYdS2jbQ8iyB56Zns',
#   'uri': 'spotify:track:0BCPKOYdS2jbQ8iyB56Zns',
#   'track_href': 'https://api.spotify.com/v1/tracks/0BCPKOYdS2jbQ8iyB56Zns',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BCPKOYdS2jbQ8iyB56Zns',
#   'duration_ms': 307880,
#   'time_signature': 4},
#  {'danceability': 0.472,
#   'energy': 0.671,
#   'key': 4,
#   'loudness': -4.649,
#   'mode': 1,
#   'speechiness': 0.029,
#   'acousticness': 0.0129,
#   'instrumentalness': 0,
#   'liveness': 0.159,
#   'valence': 0.0681,
#   'tempo': 82.952,
#   'type': 'audio_features',
#   'id': '77loZpT5Y5PRP1S451P9Yz',
#   'uri': 'spotify:track:77loZpT5Y5PRP1S451P9Yz',
#   'track_href': 'https://api.spotify.com/v1/tracks/77loZpT5Y5PRP1S451P9Yz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77loZpT5Y5PRP1S451P9Yz',
#   'duration_ms': 232800,
#   'time_signature': 4},
#  {'danceability': 0.617,
#   'energy': 0.717,
#   'key': 10,
#   'loudness': -7.858,
#   'mode': 0,
#   'speechiness': 0.153,
#   'acousticness': 0.00564,
#   'instrumentalness': 0,
#   'liveness': 0.408,
#   'valence': 0.49,
#   'tempo': 103.992,
#   'type': 'audio_features',
#   'id': '0j2T0R9dR9qdJYsB7ciXhf',
#   'uri': 'spotify:track:0j2T0R9dR9qdJYsB7ciXhf',
#   'track_href': 'https://api.spotify.com/v1/tracks/0j2T0R9dR9qdJYsB7ciXhf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0j2T0R9dR9qdJYsB7ciXhf',
#   'duration_ms': 311867,
#   'time_signature': 4},
#  {'danceability': 0.802,
#   'energy': 0.785,
#   'key': 9,
#   'loudness': -4.781,
#   'mode': 1,
#   'speechiness': 0.207,
#   'acousticness': 0.14,
#   'instrumentalness': 0,
#   'liveness': 0.123,
#   'valence': 0.435,
#   'tempo': 99.998,
#   'type': 'audio_features',
#   'id': '2wGSgTmgSF3xjRrHkTc25R',
#   'uri': 'spotify:track:2wGSgTmgSF3xjRrHkTc25R',
#   'track_href': 'https://api.spotify.com/v1/tracks/2wGSgTmgSF3xjRrHkTc25R',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2wGSgTmgSF3xjRrHkTc25R',
#   'duration_ms': 206400,
#   'time_signature': 4},
#  {'danceability': 0.589,
#   'energy': 0.89,
#   'key': 4,
#   'loudness': -3.719,
#   'mode': 0,
#   'speechiness': 0.0603,
#   'acousticness': 0.000481,
#   'instrumentalness': 0.00082,
#   'liveness': 0.201,
#   'valence': 0.692,
#   'tempo': 90.598,
#   'type': 'audio_features',
#   'id': '5W8YXBz9MTIDyrpYaCg2Ky',
#   'uri': 'spotify:track:5W8YXBz9MTIDyrpYaCg2Ky',
#   'track_href': 'https://api.spotify.com/v1/tracks/5W8YXBz9MTIDyrpYaCg2Ky',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5W8YXBz9MTIDyrpYaCg2Ky',
#   'duration_ms': 199907,
#   'time_signature': 4},
#  {'danceability': 0.951,
#   'energy': 0.6,
#   'key': 0,
#   'loudness': -4.675,
#   'mode': 0,
#   'speechiness': 0.0685,
#   'acousticness': 0.106,
#   'instrumentalness': 0,
#   'liveness': 0.0712,
#   'valence': 0.822,
#   'tempo': 125.04,
#   'type': 'audio_features',
#   'id': '0k2GOhqsrxDTAbFFSdNJjT',
#   'uri': 'spotify:track:0k2GOhqsrxDTAbFFSdNJjT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0k2GOhqsrxDTAbFFSdNJjT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0k2GOhqsrxDTAbFFSdNJjT',
#   'duration_ms': 218573,
#   'time_signature': 4},
#  {'danceability': 0.731,
#   'energy': 0.807,
#   'key': 3,
#   'loudness': -6.492,
#   'mode': 0,
#   'speechiness': 0.1,
#   'acousticness': 0.181,
#   'instrumentalness': 0.751,
#   'liveness': 0.319,
#   'valence': 0.765,
#   'tempo': 114.759,
#   'type': 'audio_features',
#   'id': '2bLqfJjuC5syrsgDsZfGmn',
#   'uri': 'spotify:track:2bLqfJjuC5syrsgDsZfGmn',
#   'track_href': 'https://api.spotify.com/v1/tracks/2bLqfJjuC5syrsgDsZfGmn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2bLqfJjuC5syrsgDsZfGmn',
#   'duration_ms': 179120,
#   'time_signature': 4},
#  {'danceability': 0.918,
#   'energy': 0.609,
#   'key': 10,
#   'loudness': -5.64,
#   'mode': 0,
#   'speechiness': 0.0791,
#   'acousticness': 0.0928,
#   'instrumentalness': 0,
#   'liveness': 0.139,
#   'valence': 0.304,
#   'tempo': 128.008,
#   'type': 'audio_features',
#   'id': '0CAfXk7DXMnon4gLudAp7J',
#   'uri': 'spotify:track:0CAfXk7DXMnon4gLudAp7J',
#   'track_href': 'https://api.spotify.com/v1/tracks/0CAfXk7DXMnon4gLudAp7J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0CAfXk7DXMnon4gLudAp7J',
#   'duration_ms': 231400,
#   'time_signature': 4},
#  {'danceability': 0.796,
#   'energy': 0.766,
#   'key': 7,
#   'loudness': -5.974,
#   'mode': 1,
#   'speechiness': 0.238,
#   'acousticness': 0.0742,
#   'instrumentalness': 0,
#   'liveness': 0.0827,
#   'valence': 0.558,
#   'tempo': 110.034,
#   'type': 'audio_features',
#   'id': '3iVcZ5G6tvkXZkZKlMpIUs',
#   'uri': 'spotify:track:3iVcZ5G6tvkXZkZKlMpIUs',
#   'track_href': 'https://api.spotify.com/v1/tracks/3iVcZ5G6tvkXZkZKlMpIUs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3iVcZ5G6tvkXZkZKlMpIUs',
#   'duration_ms': 219333,
#   'time_signature': 4},
#  {'danceability': 0.922,
#   'energy': 0.909,
#   'key': 10,
#   'loudness': -2.429,
#   'mode': 0,
#   'speechiness': 0.27,
#   'acousticness': 0.0281,
#   'instrumentalness': 0,
#   'liveness': 0.0856,
#   'valence': 0.309,
#   'tempo': 95.295,
#   'type': 'audio_features',
#   'id': '4LwU4Vp6od3Sb08CsP99GC',
#   'uri': 'spotify:track:4LwU4Vp6od3Sb08CsP99GC',
#   'track_href': 'https://api.spotify.com/v1/tracks/4LwU4Vp6od3Sb08CsP99GC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4LwU4Vp6od3Sb08CsP99GC',
#   'duration_ms': 161507,
#   'time_signature': 4},
#  {'danceability': 0.56,
#   'energy': 0.595,
#   'key': 9,
#   'loudness': -4.53,
#   'mode': 1,
#   'speechiness': 0.0274,
#   'acousticness': 0.199,
#   'instrumentalness': 6.47e-05,
#   'liveness': 0.132,
#   'valence': 0.144,
#   'tempo': 104.011,
#   'type': 'audio_features',
#   'id': '5hnyJvgoWiQUYZttV4wXy6',
#   'uri': 'spotify:track:5hnyJvgoWiQUYZttV4wXy6',
#   'track_href': 'https://api.spotify.com/v1/tracks/5hnyJvgoWiQUYZttV4wXy6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5hnyJvgoWiQUYZttV4wXy6',
#   'duration_ms': 267960,
#   'time_signature': 4},
#  {'danceability': 0.794,
#   'energy': 0.832,
#   'key': 1,
#   'loudness': -4.862,
#   'mode': 0,
#   'speechiness': 0.0407,
#   'acousticness': 0.237,
#   'instrumentalness': 1.14e-05,
#   'liveness': 0.203,
#   'valence': 0.871,
#   'tempo': 107.657,
#   'type': 'audio_features',
#   'id': '2lnzGkdtDj5mtlcOW2yRtG',
#   'uri': 'spotify:track:2lnzGkdtDj5mtlcOW2yRtG',
#   'track_href': 'https://api.spotify.com/v1/tracks/2lnzGkdtDj5mtlcOW2yRtG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lnzGkdtDj5mtlcOW2yRtG',
#   'duration_ms': 196160,
#   'time_signature': 4},
#  {'danceability': 0.609,
#   'energy': 0.444,
#   'key': 7,
#   'loudness': -9.129,
#   'mode': 1,
#   'speechiness': 0.106,
#   'acousticness': 0.603,
#   'instrumentalness': 6.86e-06,
#   'liveness': 0.104,
#   'valence': 0.166,
#   'tempo': 118.402,
#   'type': 'audio_features',
#   'id': '3XVBdLihbNbxUwZosxcGuJ',
#   'uri': 'spotify:track:3XVBdLihbNbxUwZosxcGuJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3XVBdLihbNbxUwZosxcGuJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3XVBdLihbNbxUwZosxcGuJ',
#   'duration_ms': 228707,
#   'time_signature': 3},
#  {'danceability': 0.614,
#   'energy': 0.574,
#   'key': 11,
#   'loudness': -7.961,
#   'mode': 1,
#   'speechiness': 0.466,
#   'acousticness': 0.0253,
#   'instrumentalness': 3.2e-05,
#   'liveness': 0.38,
#   'valence': 0.755,
#   'tempo': 125.173,
#   'type': 'audio_features',
#   'id': '5D2mYZuzcgjpchVY1pmTPh',
#   'uri': 'spotify:track:5D2mYZuzcgjpchVY1pmTPh',
#   'track_href': 'https://api.spotify.com/v1/tracks/5D2mYZuzcgjpchVY1pmTPh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5D2mYZuzcgjpchVY1pmTPh',
#   'duration_ms': 209107,
#   'time_signature': 5},
#  {'danceability': 0.834,
#   'energy': 0.699,
#   'key': 5,
#   'loudness': -3.222,
#   'mode': 1,
#   'speechiness': 0.178,
#   'acousticness': 0.111,
#   'instrumentalness': 0,
#   'liveness': 0.131,
#   'valence': 0.809,
#   'tempo': 94.086,
#   'type': 'audio_features',
#   'id': '0xmjwnQ3FNE6HuWCt2nHdZ',
#   'uri': 'spotify:track:0xmjwnQ3FNE6HuWCt2nHdZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xmjwnQ3FNE6HuWCt2nHdZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xmjwnQ3FNE6HuWCt2nHdZ',
#   'duration_ms': 272533,
#   'time_signature': 4},
#  {'danceability': 0.796,
#   'energy': 0.777,
#   'key': 6,
#   'loudness': -4.81,
#   'mode': 1,
#   'speechiness': 0.0397,
#   'acousticness': 0.0261,
#   'instrumentalness': 0.000358,
#   'liveness': 0.121,
#   'valence': 0.787,
#   'tempo': 132.722,
#   'type': 'audio_features',
#   'id': '4wH4dJgrsxONID6KS2tDQM',
#   'uri': 'spotify:track:4wH4dJgrsxONID6KS2tDQM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4wH4dJgrsxONID6KS2tDQM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wH4dJgrsxONID6KS2tDQM',
#   'duration_ms': 258893,
#   'time_signature': 4},
#  {'danceability': 0.712,
#   'energy': 0.862,
#   'key': 5,
#   'loudness': -4.612,
#   'mode': 0,
#   'speechiness': 0.0378,
#   'acousticness': 0.0525,
#   'instrumentalness': 0,
#   'liveness': 0.093,
#   'valence': 0.809,
#   'tempo': 95.051,
#   'type': 'audio_features',
#   'id': '6ECp64rv50XVz93WvxXMGF',
#   'uri': 'spotify:track:6ECp64rv50XVz93WvxXMGF',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ECp64rv50XVz93WvxXMGF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ECp64rv50XVz93WvxXMGF',
#   'duration_ms': 206200,
#   'time_signature': 4},
#  {'danceability': 0.446,
#   'energy': 0.764,
#   'key': 10,
#   'loudness': -5.042,
#   'mode': 1,
#   'speechiness': 0.033,
#   'acousticness': 0.00135,
#   'instrumentalness': 0,
#   'liveness': 0.099,
#   'valence': 0.543,
#   'tempo': 172.094,
#   'type': 'audio_features',
#   'id': '0gmbgwZ8iqyMPmXefof8Yf',
#   'uri': 'spotify:track:0gmbgwZ8iqyMPmXefof8Yf',
#   'track_href': 'https://api.spotify.com/v1/tracks/0gmbgwZ8iqyMPmXefof8Yf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0gmbgwZ8iqyMPmXefof8Yf',
#   'duration_ms': 223840,
#   'time_signature': 4},
#  {'danceability': 0.835,
#   'energy': 0.669,
#   'key': 6,
#   'loudness': -5.582,
#   'mode': 0,
#   'speechiness': 0.0643,
#   'acousticness': 0.0336,
#   'instrumentalness': 6.92e-05,
#   'liveness': 0.0535,
#   'valence': 0.542,
#   'tempo': 122.668,
#   'type': 'audio_features',
#   'id': '0ByMNEPAPpOR5H69DVrTNy',
#   'uri': 'spotify:track:0ByMNEPAPpOR5H69DVrTNy',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ByMNEPAPpOR5H69DVrTNy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ByMNEPAPpOR5H69DVrTNy',
#   'duration_ms': 267080,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.696,
#   'key': 1,
#   'loudness': -5.572,
#   'mode': 0,
#   'speechiness': 0.348,
#   'acousticness': 0.0195,
#   'instrumentalness': 0,
#   'liveness': 0.0554,
#   'valence': 0.623,
#   'tempo': 93.034,
#   'type': 'audio_features',
#   'id': '3QHPHLAkYV5cQBUYs6rowx',
#   'uri': 'spotify:track:3QHPHLAkYV5cQBUYs6rowx',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QHPHLAkYV5cQBUYs6rowx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QHPHLAkYV5cQBUYs6rowx',
#   'duration_ms': 207627,
#   'time_signature': 4},
#  {'danceability': 0.788,
#   'energy': 0.844,
#   'key': 2,
#   'loudness': -3.131,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.25,
#   'instrumentalness': 0.000678,
#   'liveness': 0.0723,
#   'valence': 0.382,
#   'tempo': 113.324,
#   'type': 'audio_features',
#   'id': '6ic8OlLUNEATToEFU3xmaH',
#   'uri': 'spotify:track:6ic8OlLUNEATToEFU3xmaH',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ic8OlLUNEATToEFU3xmaH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ic8OlLUNEATToEFU3xmaH',
#   'duration_ms': 251240,
#   'time_signature': 4},
#  {'danceability': 0.924,
#   'energy': 0.74,
#   'key': 8,
#   'loudness': -1.299,
#   'mode': 1,
#   'speechiness': 0.0774,
#   'acousticness': 0.0827,
#   'instrumentalness': 0,
#   'liveness': 0.163,
#   'valence': 0.621,
#   'tempo': 133.974,
#   'type': 'audio_features',
#   'id': '7iXF2W9vKmDoGAhlHdpyIa',
#   'uri': 'spotify:track:7iXF2W9vKmDoGAhlHdpyIa',
#   'track_href': 'https://api.spotify.com/v1/tracks/7iXF2W9vKmDoGAhlHdpyIa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7iXF2W9vKmDoGAhlHdpyIa',
#   'duration_ms': 222293,
#   'time_signature': 4},
#  {'danceability': 0.871,
#   'energy': 0.701,
#   'key': 5,
#   'loudness': -5.594,
#   'mode': 0,
#   'speechiness': 0.0458,
#   'acousticness': 0.257,
#   'instrumentalness': 7.52e-06,
#   'liveness': 0.0589,
#   'valence': 0.716,
#   'tempo': 126.975,
#   'type': 'audio_features',
#   'id': '5r5cp9IpziiIsR6b93vcnQ',
#   'uri': 'spotify:track:5r5cp9IpziiIsR6b93vcnQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5r5cp9IpziiIsR6b93vcnQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5r5cp9IpziiIsR6b93vcnQ',
#   'duration_ms': 198440,
#   'time_signature': 4},
#  {'danceability': 0.853,
#   'energy': 0.606,
#   'key': 0,
#   'loudness': -4.596,
#   'mode': 1,
#   'speechiness': 0.0713,
#   'acousticness': 0.0561,
#   'instrumentalness': 0,
#   'liveness': 0.313,
#   'valence': 0.654,
#   'tempo': 94.759,
#   'type': 'audio_features',
#   'id': '3WkibOpDF7cQ5xntM1epyf',
#   'uri': 'spotify:track:3WkibOpDF7cQ5xntM1epyf',
#   'track_href': 'https://api.spotify.com/v1/tracks/3WkibOpDF7cQ5xntM1epyf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WkibOpDF7cQ5xntM1epyf',
#   'duration_ms': 227600,
#   'time_signature': 4},
#  {'danceability': 0.872,
#   'energy': 0.872,
#   'key': 1,
#   'loudness': -6.328,
#   'mode': 1,
#   'speechiness': 0.139,
#   'acousticness': 0.0476,
#   'instrumentalness': 0.00112,
#   'liveness': 0.0543,
#   'valence': 0.809,
#   'tempo': 116.948,
#   'type': 'audio_features',
#   'id': '2aI21FnmY7TJVKeMaoQZ0t',
#   'uri': 'spotify:track:2aI21FnmY7TJVKeMaoQZ0t',
#   'track_href': 'https://api.spotify.com/v1/tracks/2aI21FnmY7TJVKeMaoQZ0t',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2aI21FnmY7TJVKeMaoQZ0t',
#   'duration_ms': 223080,
#   'time_signature': 4},
#  {'danceability': 0.64,
#   'energy': 0.743,
#   'key': 10,
#   'loudness': -4.08,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.269,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.361,
#   'tempo': 122.035,
#   'type': 'audio_features',
#   'id': '5fVZC9GiM4e8vu99W0Xf6J',
#   'uri': 'spotify:track:5fVZC9GiM4e8vu99W0Xf6J',
#   'track_href': 'https://api.spotify.com/v1/tracks/5fVZC9GiM4e8vu99W0Xf6J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5fVZC9GiM4e8vu99W0Xf6J',
#   'duration_ms': 262533,
#   'time_signature': 4},
#  {'danceability': 0.651,
#   'energy': 0.663,
#   'key': 0,
#   'loudness': -5.569,
#   'mode': 0,
#   'speechiness': 0.0281,
#   'acousticness': 0.228,
#   'instrumentalness': 0,
#   'liveness': 0.0994,
#   'valence': 0.465,
#   'tempo': 102.0,
#   'type': 'audio_features',
#   'id': '4llK75pXNWZz6KAho2Gp16',
#   'uri': 'spotify:track:4llK75pXNWZz6KAho2Gp16',
#   'track_href': 'https://api.spotify.com/v1/tracks/4llK75pXNWZz6KAho2Gp16',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4llK75pXNWZz6KAho2Gp16',
#   'duration_ms': 259453,
#   'time_signature': 4},
#  {'danceability': 0.277,
#   'energy': 0.663,
#   'key': 4,
#   'loudness': -8.821,
#   'mode': 0,
#   'speechiness': 0.0377,
#   'acousticness': 0.000409,
#   'instrumentalness': 0.00051,
#   'liveness': 0.136,
#   'valence': 0.527,
#   'tempo': 104.561,
#   'type': 'audio_features',
#   'id': '20I8RduZC2PWMWTDCZuuAN',
#   'uri': 'spotify:track:20I8RduZC2PWMWTDCZuuAN',
#   'track_href': 'https://api.spotify.com/v1/tracks/20I8RduZC2PWMWTDCZuuAN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/20I8RduZC2PWMWTDCZuuAN',
#   'duration_ms': 237027,
#   'time_signature': 4},
#  {'danceability': 0.657,
#   'energy': 0.734,
#   'key': 8,
#   'loudness': -4.832,
#   'mode': 0,
#   'speechiness': 0.484,
#   'acousticness': 0.149,
#   'instrumentalness': 0,
#   'liveness': 0.139,
#   'valence': 0.434,
#   'tempo': 91.03,
#   'type': 'audio_features',
#   'id': '5SkRLpaGtvYPhw02vZhQQ9',
#   'uri': 'spotify:track:5SkRLpaGtvYPhw02vZhQQ9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5SkRLpaGtvYPhw02vZhQQ9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5SkRLpaGtvYPhw02vZhQQ9',
#   'duration_ms': 223507,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.776,
#   'key': 5,
#   'loudness': -5.898,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.0572,
#   'instrumentalness': 7.74e-06,
#   'liveness': 0.3,
#   'valence': 0.427,
#   'tempo': 77.987,
#   'type': 'audio_features',
#   'id': '5xEM5hIgJ1jjgcEBfpkt2F',
#   'uri': 'spotify:track:5xEM5hIgJ1jjgcEBfpkt2F',
#   'track_href': 'https://api.spotify.com/v1/tracks/5xEM5hIgJ1jjgcEBfpkt2F',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5xEM5hIgJ1jjgcEBfpkt2F',
#   'duration_ms': 244507,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.77,
#   'key': 2,
#   'loudness': -6.596,
#   'mode': 0,
#   'speechiness': 0.226,
#   'acousticness': 0.00249,
#   'instrumentalness': 0,
#   'liveness': 0.0715,
#   'valence': 0.681,
#   'tempo': 99.165,
#   'type': 'audio_features',
#   'id': '5IVuqXILoxVWvWEPm82Jxr',
#   'uri': 'spotify:track:5IVuqXILoxVWvWEPm82Jxr',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IVuqXILoxVWvWEPm82Jxr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IVuqXILoxVWvWEPm82Jxr',
#   'duration_ms': 236133,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.698,
#   'key': 10,
#   'loudness': -4.667,
#   'mode': 0,
#   'speechiness': 0.042,
#   'acousticness': 0.00112,
#   'instrumentalness': 0.000115,
#   'liveness': 0.0886,
#   'valence': 0.47,
#   'tempo': 96.021,
#   'type': 'audio_features',
#   'id': '3E7dfMvvCLUddWissuqMwr',
#   'uri': 'spotify:track:3E7dfMvvCLUddWissuqMwr',
#   'track_href': 'https://api.spotify.com/v1/tracks/3E7dfMvvCLUddWissuqMwr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3E7dfMvvCLUddWissuqMwr',
#   'duration_ms': 202067,
#   'time_signature': 4},
#  {'danceability': 0.791,
#   'energy': 0.59,
#   'key': 1,
#   'loudness': -9.206,
#   'mode': 0,
#   'speechiness': 0.0793,
#   'acousticness': 0.0994,
#   'instrumentalness': 0.00203,
#   'liveness': 0.065,
#   'valence': 0.714,
#   'tempo': 119.951,
#   'type': 'audio_features',
#   'id': '2GYHyAoLWpkxLVa4oYTVko',
#   'uri': 'spotify:track:2GYHyAoLWpkxLVa4oYTVko',
#   'track_href': 'https://api.spotify.com/v1/tracks/2GYHyAoLWpkxLVa4oYTVko',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2GYHyAoLWpkxLVa4oYTVko',
#   'duration_ms': 206067,
#   'time_signature': 4},
#  {'danceability': 0.779,
#   'energy': 0.64,
#   'key': 7,
#   'loudness': -8.415,
#   'mode': 1,
#   'speechiness': 0.159,
#   'acousticness': 0.000155,
#   'instrumentalness': 0.00077,
#   'liveness': 0.101,
#   'valence': 0.498,
#   'tempo': 99.019,
#   'type': 'audio_features',
#   'id': '4TsmezEQVSZNNPv5RJ65Ov',
#   'uri': 'spotify:track:4TsmezEQVSZNNPv5RJ65Ov',
#   'track_href': 'https://api.spotify.com/v1/tracks/4TsmezEQVSZNNPv5RJ65Ov',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4TsmezEQVSZNNPv5RJ65Ov',
#   'duration_ms': 246960,
#   'time_signature': 4},
#  {'danceability': 0.433,
#   'energy': 0.959,
#   'key': 9,
#   'loudness': -4.04,
#   'mode': 1,
#   'speechiness': 0.0431,
#   'acousticness': 0.000917,
#   'instrumentalness': 0,
#   'liveness': 0.028,
#   'valence': 0.365,
#   'tempo': 172.984,
#   'type': 'audio_features',
#   'id': '7x8dCjCr0x6x2lXKujYD34',
#   'uri': 'spotify:track:7x8dCjCr0x6x2lXKujYD34',
#   'track_href': 'https://api.spotify.com/v1/tracks/7x8dCjCr0x6x2lXKujYD34',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7x8dCjCr0x6x2lXKujYD34',
#   'duration_ms': 269373,
#   'time_signature': 4},
#  {'danceability': 0.459,
#   'energy': 0.891,
#   'key': 10,
#   'loudness': -5.057,
#   'mode': 0,
#   'speechiness': 0.0623,
#   'acousticness': 0.00511,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.588,
#   'tempo': 154.837,
#   'type': 'audio_features',
#   'id': '3Zwu2K0Qa5sT6teCCHPShP',
#   'uri': 'spotify:track:3Zwu2K0Qa5sT6teCCHPShP',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Zwu2K0Qa5sT6teCCHPShP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Zwu2K0Qa5sT6teCCHPShP',
#   'duration_ms': 203507,
#   'time_signature': 4},
#  {'danceability': 0.7,
#   'energy': 0.709,
#   'key': 7,
#   'loudness': -5.006,
#   'mode': 1,
#   'speechiness': 0.0838,
#   'acousticness': 0.0048,
#   'instrumentalness': 0,
#   'liveness': 0.029,
#   'valence': 0.624,
#   'tempo': 122.019,
#   'type': 'audio_features',
#   'id': '1gv4xPanImH17bKZ9rOveR',
#   'uri': 'spotify:track:1gv4xPanImH17bKZ9rOveR',
#   'track_href': 'https://api.spotify.com/v1/tracks/1gv4xPanImH17bKZ9rOveR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1gv4xPanImH17bKZ9rOveR',
#   'duration_ms': 202960,
#   'time_signature': 4},
#  {'danceability': 0.751,
#   'energy': 0.783,
#   'key': 4,
#   'loudness': -3.724,
#   'mode': 1,
#   'speechiness': 0.0859,
#   'acousticness': 0.00379,
#   'instrumentalness': 0,
#   'liveness': 0.036,
#   'valence': 0.816,
#   'tempo': 119.975,
#   'type': 'audio_features',
#   'id': '2CEgGE6aESpnmtfiZwYlbV',
#   'uri': 'spotify:track:2CEgGE6aESpnmtfiZwYlbV',
#   'track_href': 'https://api.spotify.com/v1/tracks/2CEgGE6aESpnmtfiZwYlbV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2CEgGE6aESpnmtfiZwYlbV',
#   'duration_ms': 202613,
#   'time_signature': 4},
#  {'danceability': 0.632,
#   'energy': 0.924,
#   'key': 1,
#   'loudness': -1.802,
#   'mode': 1,
#   'speechiness': 0.29,
#   'acousticness': 0.281,
#   'instrumentalness': 0,
#   'liveness': 0.263,
#   'valence': 0.441,
#   'tempo': 86.844,
#   'type': 'audio_features',
#   'id': '7LR85XLWw2yXqKBSI5brbG',
#   'uri': 'spotify:track:7LR85XLWw2yXqKBSI5brbG',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LR85XLWw2yXqKBSI5brbG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LR85XLWw2yXqKBSI5brbG',
#   'duration_ms': 267520,
#   'time_signature': 4},
#  {'danceability': 0.739,
#   'energy': 0.511,
#   'key': 9,
#   'loudness': -7.844,
#   'mode': 1,
#   'speechiness': 0.0362,
#   'acousticness': 0.167,
#   'instrumentalness': 1.34e-06,
#   'liveness': 0.133,
#   'valence': 0.542,
#   'tempo': 96.038,
#   'type': 'audio_features',
#   'id': '2nGFzvICaeEWjIrBrL2RAx',
#   'uri': 'spotify:track:2nGFzvICaeEWjIrBrL2RAx',
#   'track_href': 'https://api.spotify.com/v1/tracks/2nGFzvICaeEWjIrBrL2RAx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2nGFzvICaeEWjIrBrL2RAx',
#   'duration_ms': 215360,
#   'time_signature': 4},
#  {'danceability': 0.751,
#   'energy': 0.834,
#   'key': 1,
#   'loudness': -5.444,
#   'mode': 0,
#   'speechiness': 0.0437,
#   'acousticness': 0.3,
#   'instrumentalness': 1.77e-05,
#   'liveness': 0.355,
#   'valence': 0.894,
#   'tempo': 95.053,
#   'type': 'audio_features',
#   'id': '6naxalmIoLFWR0siv8dnQQ',
#   'uri': 'spotify:track:6naxalmIoLFWR0siv8dnQQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6naxalmIoLFWR0siv8dnQQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6naxalmIoLFWR0siv8dnQQ',
#   'duration_ms': 211160,
#   'time_signature': 4},
#  {'danceability': 0.403,
#   'energy': 0.422,
#   'key': 7,
#   'loudness': -13.964,
#   'mode': 0,
#   'speechiness': 0.0373,
#   'acousticness': 0.134,
#   'instrumentalness': 2.05e-05,
#   'liveness': 0.0861,
#   'valence': 0.378,
#   'tempo': 122.728,
#   'type': 'audio_features',
#   'id': '3FAclTFfvUuQYnEsptbK8w',
#   'uri': 'spotify:track:3FAclTFfvUuQYnEsptbK8w',
#   'track_href': 'https://api.spotify.com/v1/tracks/3FAclTFfvUuQYnEsptbK8w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3FAclTFfvUuQYnEsptbK8w',
#   'duration_ms': 241293,
#   'time_signature': 4},
#  {'danceability': 0.628,
#   'energy': 0.882,
#   'key': 1,
#   'loudness': -5.024,
#   'mode': 0,
#   'speechiness': 0.0323,
#   'acousticness': 0.259,
#   'instrumentalness': 0,
#   'liveness': 0.065,
#   'valence': 0.853,
#   'tempo': 95.083,
#   'type': 'audio_features',
#   'id': '2T3jgoAMbBXiMMD8pSc6QL',
#   'uri': 'spotify:track:2T3jgoAMbBXiMMD8pSc6QL',
#   'track_href': 'https://api.spotify.com/v1/tracks/2T3jgoAMbBXiMMD8pSc6QL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2T3jgoAMbBXiMMD8pSc6QL',
#   'duration_ms': 184413,
#   'time_signature': 4},
#  {'danceability': 0.622,
#   'energy': 0.469,
#   'key': 3,
#   'loudness': -6.798,
#   'mode': 0,
#   'speechiness': 0.0363,
#   'acousticness': 0.00454,
#   'instrumentalness': 2.25e-06,
#   'liveness': 0.0335,
#   'valence': 0.679,
#   'tempo': 77.019,
#   'type': 'audio_features',
#   'id': '6FB3v4YcR57y4tXFcdxI1E',
#   'uri': 'spotify:track:6FB3v4YcR57y4tXFcdxI1E',
#   'track_href': 'https://api.spotify.com/v1/tracks/6FB3v4YcR57y4tXFcdxI1E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6FB3v4YcR57y4tXFcdxI1E',
#   'duration_ms': 219720,
#   'time_signature': 4},
#  {'danceability': 0.656,
#   'energy': 0.291,
#   'key': 2,
#   'loudness': -10.572,
#   'mode': 1,
#   'speechiness': 0.0293,
#   'acousticness': 0.872,
#   'instrumentalness': 0,
#   'liveness': 0.114,
#   'valence': 0.298,
#   'tempo': 103.971,
#   'type': 'audio_features',
#   'id': '4RCWB3V8V0dignt99LZ8vH',
#   'uri': 'spotify:track:4RCWB3V8V0dignt99LZ8vH',
#   'track_href': 'https://api.spotify.com/v1/tracks/4RCWB3V8V0dignt99LZ8vH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4RCWB3V8V0dignt99LZ8vH',
#   'duration_ms': 232533,
#   'time_signature': 4},
#  {'danceability': 0.967,
#   'energy': 0.583,
#   'key': 7,
#   'loudness': -5.562,
#   'mode': 0,
#   'speechiness': 0.0789,
#   'acousticness': 0.0584,
#   'instrumentalness': 0,
#   'liveness': 0.0519,
#   'valence': 0.964,
#   'tempo': 117.0,
#   'type': 'audio_features',
#   'id': '0O45fw2L5vsWpdsOdXwNAR',
#   'uri': 'spotify:track:0O45fw2L5vsWpdsOdXwNAR',
#   'track_href': 'https://api.spotify.com/v1/tracks/0O45fw2L5vsWpdsOdXwNAR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0O45fw2L5vsWpdsOdXwNAR',
#   'duration_ms': 242733,
#   'time_signature': 4},
#  {'danceability': 0.727,
#   'energy': 0.552,
#   'key': 2,
#   'loudness': -8.074,
#   'mode': 0,
#   'speechiness': 0.14,
#   'acousticness': 0.227,
#   'instrumentalness': 0.000164,
#   'liveness': 0.198,
#   'valence': 0.607,
#   'tempo': 168.189,
#   'type': 'audio_features',
#   'id': '0ARK753YaiJbpLUk7z5yIM',
#   'uri': 'spotify:track:0ARK753YaiJbpLUk7z5yIM',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ARK753YaiJbpLUk7z5yIM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ARK753YaiJbpLUk7z5yIM',
#   'duration_ms': 289160,
#   'time_signature': 4},
#  {'danceability': 0.494,
#   'energy': 0.842,
#   'key': 7,
#   'loudness': -4.784,
#   'mode': 1,
#   'speechiness': 0.0843,
#   'acousticness': 0.00579,
#   'instrumentalness': 0,
#   'liveness': 0.122,
#   'valence': 0.574,
#   'tempo': 162.011,
#   'type': 'audio_features',
#   'id': '2TfSHkHiFO4gRztVIkggkE',
#   'uri': 'spotify:track:2TfSHkHiFO4gRztVIkggkE',
#   'track_href': 'https://api.spotify.com/v1/tracks/2TfSHkHiFO4gRztVIkggkE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2TfSHkHiFO4gRztVIkggkE',
#   'duration_ms': 229093,
#   'time_signature': 4},
#  {'danceability': 0.727,
#   'energy': 0.68,
#   'key': 2,
#   'loudness': -4.498,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.0101,
#   'instrumentalness': 0,
#   'liveness': 0.0821,
#   'valence': 0.728,
#   'tempo': 132.012,
#   'type': 'audio_features',
#   'id': '6cmm1LMvZdB5zsCwX5BjqE',
#   'uri': 'spotify:track:6cmm1LMvZdB5zsCwX5BjqE',
#   'track_href': 'https://api.spotify.com/v1/tracks/6cmm1LMvZdB5zsCwX5BjqE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6cmm1LMvZdB5zsCwX5BjqE',
#   'duration_ms': 212507,
#   'time_signature': 4},
#  {'danceability': 0.762,
#   'energy': 0.661,
#   'key': 1,
#   'loudness': -6.075,
#   'mode': 0,
#   'speechiness': 0.0687,
#   'acousticness': 0.15,
#   'instrumentalness': 0,
#   'liveness': 0.256,
#   'valence': 0.769,
#   'tempo': 130.009,
#   'type': 'audio_features',
#   'id': '1hGy2eLcmC8eKx7qr1tOqx',
#   'uri': 'spotify:track:1hGy2eLcmC8eKx7qr1tOqx',
#   'track_href': 'https://api.spotify.com/v1/tracks/1hGy2eLcmC8eKx7qr1tOqx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1hGy2eLcmC8eKx7qr1tOqx',
#   'duration_ms': 225373,
#   'time_signature': 4},
#  {'danceability': 0.662,
#   'energy': 0.507,
#   'key': 5,
#   'loudness': -8.238,
#   'mode': 1,
#   'speechiness': 0.118,
#   'acousticness': 0.257,
#   'instrumentalness': 0,
#   'liveness': 0.0465,
#   'valence': 0.676,
#   'tempo': 86.412,
#   'type': 'audio_features',
#   'id': '68vgtRHr7iZHpzGpon6Jlo',
#   'uri': 'spotify:track:68vgtRHr7iZHpzGpon6Jlo',
#   'track_href': 'https://api.spotify.com/v1/tracks/68vgtRHr7iZHpzGpon6Jlo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/68vgtRHr7iZHpzGpon6Jlo',
#   'duration_ms': 223440,
# ...
#   'energy': 0.672,
#   'key': 7,
#   'loudness': -6.852,
#   'mode': 1,
#   'speechiness': 0.0551,
#   'acousticness': 0.009,
#   'instrumentalness': 0,
#   'liveness': 0.232,
#   'valence': 0.705,
#   'tempo': 124.986,
#   'type': 'audio_features',
#   'id': '3GpbwCm3YxiWDvy29Uo3vP',
#   'uri': 'spotify:track:3GpbwCm3YxiWDvy29Uo3vP',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GpbwCm3YxiWDvy29Uo3vP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GpbwCm3YxiWDvy29Uo3vP',
#   'duration_ms': 204640,
#   'time_signature': 4},
#  {'danceability': 0.888,
#   'energy': 0.632,
#   'key': 1,
#   'loudness': -3.872,
#   'mode': 1,
#   'speechiness': 0.219,
#   'acousticness': 0.19,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.662,
#   'tempo': 91.979,
#   'type': 'audio_features',
#   'id': '2NBQmPrOEEjA8VbeWOQGxO',
#   'uri': 'spotify:track:2NBQmPrOEEjA8VbeWOQGxO',
#   'track_href': 'https://api.spotify.com/v1/tracks/2NBQmPrOEEjA8VbeWOQGxO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NBQmPrOEEjA8VbeWOQGxO',
#   'duration_ms': 266067,
#   'time_signature': 4},
#  {'danceability': 0.74,
#   'energy': 0.783,
#   'key': 0,
#   'loudness': -5.367,
#   'mode': 1,
#   'speechiness': 0.0427,
#   'acousticness': 0.0297,
#   'instrumentalness': 0.000308,
#   'liveness': 0.123,
#   'valence': 0.812,
#   'tempo': 100.011,
#   'type': 'audio_features',
#   'id': '5BSclXJTa9B0iURhUjZo50',
#   'uri': 'spotify:track:5BSclXJTa9B0iURhUjZo50',
#   'track_href': 'https://api.spotify.com/v1/tracks/5BSclXJTa9B0iURhUjZo50',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5BSclXJTa9B0iURhUjZo50',
#   'duration_ms': 212893,
#   'time_signature': 4},
#  {'danceability': 0.366,
#   'energy': 0.94,
#   'key': 1,
#   'loudness': -5.119,
#   'mode': 0,
#   'speechiness': 0.0696,
#   'acousticness': 0.000769,
#   'instrumentalness': 9.42e-05,
#   'liveness': 0.188,
#   'valence': 0.369,
#   'tempo': 130.198,
#   'type': 'audio_features',
#   'id': '5FZxsHWIvUsmSK1IAvm2pp',
#   'uri': 'spotify:track:5FZxsHWIvUsmSK1IAvm2pp',
#   'track_href': 'https://api.spotify.com/v1/tracks/5FZxsHWIvUsmSK1IAvm2pp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FZxsHWIvUsmSK1IAvm2pp',
#   'duration_ms': 255627,
#   'time_signature': 4},
#  {'danceability': 0.487,
#   'energy': 0.9,
#   'key': 0,
#   'loudness': -4.417,
#   'mode': 1,
#   'speechiness': 0.0482,
#   'acousticness': 6.79e-05,
#   'instrumentalness': 0,
#   'liveness': 0.358,
#   'valence': 0.484,
#   'tempo': 149.937,
#   'type': 'audio_features',
#   'id': '00Mb3DuaIH1kjrwOku9CGU',
#   'uri': 'spotify:track:00Mb3DuaIH1kjrwOku9CGU',
#   'track_href': 'https://api.spotify.com/v1/tracks/00Mb3DuaIH1kjrwOku9CGU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00Mb3DuaIH1kjrwOku9CGU',
#   'duration_ms': 204000,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.7,
#   'key': 7,
#   'loudness': -6.49,
#   'mode': 1,
#   'speechiness': 0.0478,
#   'acousticness': 0.0616,
#   'instrumentalness': 1.8e-06,
#   'liveness': 0.244,
#   'valence': 0.722,
#   'tempo': 101.875,
#   'type': 'audio_features',
#   'id': '3Gf5nttwcX9aaSQXRWidEZ',
#   'uri': 'spotify:track:3Gf5nttwcX9aaSQXRWidEZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Gf5nttwcX9aaSQXRWidEZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Gf5nttwcX9aaSQXRWidEZ',
#   'duration_ms': 291782,
#   'time_signature': 4},
#  {'danceability': 0.557,
#   'energy': 0.533,
#   'key': 10,
#   'loudness': -6.817,
#   'mode': 0,
#   'speechiness': 0.0252,
#   'acousticness': 0.0492,
#   'instrumentalness': 0,
#   'liveness': 0.205,
#   'valence': 0.233,
#   'tempo': 143.994,
#   'type': 'audio_features',
#   'id': '3NLrRZoMF0Lx6zTlYqeIo4',
#   'uri': 'spotify:track:3NLrRZoMF0Lx6zTlYqeIo4',
#   'track_href': 'https://api.spotify.com/v1/tracks/3NLrRZoMF0Lx6zTlYqeIo4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3NLrRZoMF0Lx6zTlYqeIo4',
#   'duration_ms': 238733,
#   'time_signature': 4},
#  {'danceability': 0.673,
#   'energy': 0.683,
#   'key': 1,
#   'loudness': -5.693,
#   'mode': 1,
#   'speechiness': 0.115,
#   'acousticness': 0.522,
#   'instrumentalness': 0,
#   'liveness': 0.235,
#   'valence': 0.713,
#   'tempo': 171.86,
#   'type': 'audio_features',
#   'id': '34ceTg8ChN5HjrqiIYCn9Q',
#   'uri': 'spotify:track:34ceTg8ChN5HjrqiIYCn9Q',
#   'track_href': 'https://api.spotify.com/v1/tracks/34ceTg8ChN5HjrqiIYCn9Q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34ceTg8ChN5HjrqiIYCn9Q',
#   'duration_ms': 232000,
#   'time_signature': 4},
#  {'danceability': 0.602,
#   'energy': 0.905,
#   'key': 2,
#   'loudness': -4.046,
#   'mode': 1,
#   'speechiness': 0.0775,
#   'acousticness': 0.000202,
#   'instrumentalness': 0.064,
#   'liveness': 0.117,
#   'valence': 0.411,
#   'tempo': 128.019,
#   'type': 'audio_features',
#   'id': '4VqPOruhp5EdPBeR92t6lQ',
#   'uri': 'spotify:track:4VqPOruhp5EdPBeR92t6lQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4VqPOruhp5EdPBeR92t6lQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VqPOruhp5EdPBeR92t6lQ',
#   'duration_ms': 304840,
#   'time_signature': 4},
#  {'danceability': 0.628,
#   'energy': 0.676,
#   'key': 7,
#   'loudness': -5.911,
#   'mode': 1,
#   'speechiness': 0.0916,
#   'acousticness': 0.00957,
#   'instrumentalness': 2.65e-05,
#   'liveness': 0.121,
#   'valence': 0.75,
#   'tempo': 85.984,
#   'type': 'audio_features',
#   'id': '0VwNdo84DaVYLIkbVO86ND',
#   'uri': 'spotify:track:0VwNdo84DaVYLIkbVO86ND',
#   'track_href': 'https://api.spotify.com/v1/tracks/0VwNdo84DaVYLIkbVO86ND',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VwNdo84DaVYLIkbVO86ND',
#   'duration_ms': 193147,
#   'time_signature': 4},
#  {'danceability': 0.649,
#   'energy': 0.647,
#   'key': 9,
#   'loudness': -7.695,
#   'mode': 0,
#   'speechiness': 0.0452,
#   'acousticness': 0.0039,
#   'instrumentalness': 0.161,
#   'liveness': 0.0686,
#   'valence': 0.405,
#   'tempo': 125.02,
#   'type': 'audio_features',
#   'id': '3850dYVgOFIXJh5U4BFEWH',
#   'uri': 'spotify:track:3850dYVgOFIXJh5U4BFEWH',
#   'track_href': 'https://api.spotify.com/v1/tracks/3850dYVgOFIXJh5U4BFEWH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3850dYVgOFIXJh5U4BFEWH',
#   'duration_ms': 337733,
#   'time_signature': 4},
#  {'danceability': 0.956,
#   'energy': 0.745,
#   'key': 11,
#   'loudness': -4.753,
#   'mode': 0,
#   'speechiness': 0.12,
#   'acousticness': 0.206,
#   'instrumentalness': 0,
#   'liveness': 0.0615,
#   'valence': 0.912,
#   'tempo': 107.075,
#   'type': 'audio_features',
#   'id': '04KTF78FFg8sOHC1BADqbY',
#   'uri': 'spotify:track:04KTF78FFg8sOHC1BADqbY',
#   'track_href': 'https://api.spotify.com/v1/tracks/04KTF78FFg8sOHC1BADqbY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/04KTF78FFg8sOHC1BADqbY',
#   'duration_ms': 228240,
#   'time_signature': 4},
#  {'danceability': 0.675,
#   'energy': 0.479,
#   'key': 0,
#   'loudness': -9.87,
#   'mode': 0,
#   'speechiness': 0.0278,
#   'acousticness': 0.633,
#   'instrumentalness': 1.76e-05,
#   'liveness': 0.088,
#   'valence': 0.454,
#   'tempo': 81.998,
#   'type': 'audio_features',
#   'id': '0vg4WnUWvze6pBOJDTq99k',
#   'uri': 'spotify:track:0vg4WnUWvze6pBOJDTq99k',
#   'track_href': 'https://api.spotify.com/v1/tracks/0vg4WnUWvze6pBOJDTq99k',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0vg4WnUWvze6pBOJDTq99k',
#   'duration_ms': 209493,
#   'time_signature': 4},
#  {'danceability': 0.448,
#   'energy': 0.665,
#   'key': 9,
#   'loudness': -4.203,
#   'mode': 1,
#   'speechiness': 0.026,
#   'acousticness': 0.06,
#   'instrumentalness': 2.55e-05,
#   'liveness': 0.0828,
#   'valence': 0.304,
#   'tempo': 172.004,
#   'type': 'audio_features',
#   'id': '1SKPmfSYaPsETbRHaiA18G',
#   'uri': 'spotify:track:1SKPmfSYaPsETbRHaiA18G',
#   'track_href': 'https://api.spotify.com/v1/tracks/1SKPmfSYaPsETbRHaiA18G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SKPmfSYaPsETbRHaiA18G',
#   'duration_ms': 237147,
#   'time_signature': 4},
#  {'danceability': 0.423,
#   'energy': 0.714,
#   'key': 11,
#   'loudness': -8.295,
#   'mode': 1,
#   'speechiness': 0.045,
#   'acousticness': 0.00113,
#   'instrumentalness': 6.28e-06,
#   'liveness': 0.0855,
#   'valence': 0.593,
#   'tempo': 110.017,
#   'type': 'audio_features',
#   'id': '1AdYZ6X00nXmO613Y7GJOl',
#   'uri': 'spotify:track:1AdYZ6X00nXmO613Y7GJOl',
#   'track_href': 'https://api.spotify.com/v1/tracks/1AdYZ6X00nXmO613Y7GJOl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1AdYZ6X00nXmO613Y7GJOl',
#   'duration_ms': 227250,
#   'time_signature': 4},
#  {'danceability': 0.621,
#   'energy': 0.82,
#   'key': 10,
#   'loudness': -4.865,
#   'mode': 1,
#   'speechiness': 0.0367,
#   'acousticness': 0.332,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.452,
#   'tempo': 144.905,
#   'type': 'audio_features',
#   'id': '6SKwQghsR8AISlxhcwyA9R',
#   'uri': 'spotify:track:6SKwQghsR8AISlxhcwyA9R',
#   'track_href': 'https://api.spotify.com/v1/tracks/6SKwQghsR8AISlxhcwyA9R',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SKwQghsR8AISlxhcwyA9R',
#   'duration_ms': 230192,
#   'time_signature': 4},
#  {'danceability': 0.375,
#   'energy': 0.862,
#   'key': 11,
#   'loudness': -3.363,
#   'mode': 0,
#   'speechiness': 0.255,
#   'acousticness': 0.071,
#   'instrumentalness': 0,
#   'liveness': 0.211,
#   'valence': 0.478,
#   'tempo': 159.841,
#   'type': 'audio_features',
#   'id': '3jlbL2OTD5YmIunYzgQTAN',
#   'uri': 'spotify:track:3jlbL2OTD5YmIunYzgQTAN',
#   'track_href': 'https://api.spotify.com/v1/tracks/3jlbL2OTD5YmIunYzgQTAN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3jlbL2OTD5YmIunYzgQTAN',
#   'duration_ms': 338853,
#   'time_signature': 4},
#  {'danceability': 0.744,
#   'energy': 0.766,
#   'key': 0,
#   'loudness': -6.375,
#   'mode': 1,
#   'speechiness': 0.0265,
#   'acousticness': 0.0873,
#   'instrumentalness': 0,
#   'liveness': 0.509,
#   'valence': 0.61,
#   'tempo': 127.966,
#   'type': 'audio_features',
#   'id': '2H1047e0oMSj10dgp7p2VG',
#   'uri': 'spotify:track:2H1047e0oMSj10dgp7p2VG',
#   'track_href': 'https://api.spotify.com/v1/tracks/2H1047e0oMSj10dgp7p2VG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2H1047e0oMSj10dgp7p2VG',
#   'duration_ms': 289133,
#   'time_signature': 4},
#  {'danceability': 0.745,
#   'energy': 0.219,
#   'key': 5,
#   'loudness': -11.216,
#   'mode': 1,
#   'speechiness': 0.0276,
#   'acousticness': 0.851,
#   'instrumentalness': 1.8e-05,
#   'liveness': 0.0678,
#   'valence': 0.635,
#   'tempo': 88.609,
#   'type': 'audio_features',
#   'id': '1zNXF2svmdlNxfS5XeNUgr',
#   'uri': 'spotify:track:1zNXF2svmdlNxfS5XeNUgr',
#   'track_href': 'https://api.spotify.com/v1/tracks/1zNXF2svmdlNxfS5XeNUgr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zNXF2svmdlNxfS5XeNUgr',
#   'duration_ms': 186251,
#   'time_signature': 4},
#  {'danceability': 0.899,
#   'energy': 0.713,
#   'key': 6,
#   'loudness': -2.752,
#   'mode': 0,
#   'speechiness': 0.366,
#   'acousticness': 0.255,
#   'instrumentalness': 0,
#   'liveness': 0.0708,
#   'valence': 0.777,
#   'tempo': 90.051,
#   'type': 'audio_features',
#   'id': '7iL6o9tox1zgHpKUfh9vuC',
#   'uri': 'spotify:track:7iL6o9tox1zgHpKUfh9vuC',
#   'track_href': 'https://api.spotify.com/v1/tracks/7iL6o9tox1zgHpKUfh9vuC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7iL6o9tox1zgHpKUfh9vuC',
#   'duration_ms': 193467,
#   'time_signature': 4},
#  {'danceability': 0.451,
#   'energy': 0.97,
#   'key': 0,
#   'loudness': -4.938,
#   'mode': 1,
#   'speechiness': 0.107,
#   'acousticness': 0.0264,
#   'instrumentalness': 0.00355,
#   'liveness': 0.102,
#   'valence': 0.198,
#   'tempo': 122.444,
#   'type': 'audio_features',
#   'id': '1f2V8U1BiWaC9aJWmpOARe',
#   'uri': 'spotify:track:1f2V8U1BiWaC9aJWmpOARe',
#   'track_href': 'https://api.spotify.com/v1/tracks/1f2V8U1BiWaC9aJWmpOARe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1f2V8U1BiWaC9aJWmpOARe',
#   'duration_ms': 216933,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.785,
#   'key': 3,
#   'loudness': -4.013,
#   'mode': 1,
#   'speechiness': 0.0309,
#   'acousticness': 0.448,
#   'instrumentalness': 0.00336,
#   'liveness': 0.151,
#   'valence': 0.52,
#   'tempo': 140.046,
#   'type': 'audio_features',
#   'id': '0mUyMawtxj1CJ76kn9gIZK',
#   'uri': 'spotify:track:0mUyMawtxj1CJ76kn9gIZK',
#   'track_href': 'https://api.spotify.com/v1/tracks/0mUyMawtxj1CJ76kn9gIZK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mUyMawtxj1CJ76kn9gIZK',
#   'duration_ms': 233640,
#   'time_signature': 4},
#  {'danceability': 0.768,
#   'energy': 0.82,
#   'key': 7,
#   'loudness': -4.63,
#   'mode': 0,
#   'speechiness': 0.0474,
#   'acousticness': 0.179,
#   'instrumentalness': 0,
#   'liveness': 0.689,
#   'valence': 0.625,
#   'tempo': 129.965,
#   'type': 'audio_features',
#   'id': '2V4bv1fNWfTcyRJKmej6Sj',
#   'uri': 'spotify:track:2V4bv1fNWfTcyRJKmej6Sj',
#   'track_href': 'https://api.spotify.com/v1/tracks/2V4bv1fNWfTcyRJKmej6Sj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2V4bv1fNWfTcyRJKmej6Sj',
#   'duration_ms': 213293,
#   'time_signature': 4},
#  {'danceability': 0.422,
#   'energy': 0.712,
#   'key': 11,
#   'loudness': -5.907,
#   'mode': 0,
#   'speechiness': 0.1,
#   'acousticness': 0.273,
#   'instrumentalness': 0,
#   'liveness': 0.051,
#   'valence': 0.471,
#   'tempo': 78.454,
#   'type': 'audio_features',
#   'id': '2CvOqDpQIMw69cCzWqr5yr',
#   'uri': 'spotify:track:2CvOqDpQIMw69cCzWqr5yr',
#   'track_href': 'https://api.spotify.com/v1/tracks/2CvOqDpQIMw69cCzWqr5yr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2CvOqDpQIMw69cCzWqr5yr',
#   'duration_ms': 261160,
#   'time_signature': 4},
#  {'danceability': 0.699,
#   'energy': 0.812,
#   'key': 0,
#   'loudness': -6.005,
#   'mode': 1,
#   'speechiness': 0.0377,
#   'acousticness': 0.0164,
#   'instrumentalness': 0.000763,
#   'liveness': 0.105,
#   'valence': 0.662,
#   'tempo': 138.185,
#   'type': 'audio_features',
#   'id': '4dyx5SzxPPaD8xQIid5Wjj',
#   'uri': 'spotify:track:4dyx5SzxPPaD8xQIid5Wjj',
#   'track_href': 'https://api.spotify.com/v1/tracks/4dyx5SzxPPaD8xQIid5Wjj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dyx5SzxPPaD8xQIid5Wjj',
#   'duration_ms': 276693,
#   'time_signature': 4},
#  {'danceability': 0.597,
#   'energy': 0.837,
#   'key': 10,
#   'loudness': -6.518,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.00427,
#   'instrumentalness': 0.00115,
#   'liveness': 0.839,
#   'valence': 0.447,
#   'tempo': 126.342,
#   'type': 'audio_features',
#   'id': '1xNcBAoUw8Hz6LqK2jt4Ff',
#   'uri': 'spotify:track:1xNcBAoUw8Hz6LqK2jt4Ff',
#   'track_href': 'https://api.spotify.com/v1/tracks/1xNcBAoUw8Hz6LqK2jt4Ff',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xNcBAoUw8Hz6LqK2jt4Ff',
#   'duration_ms': 171360,
#   'time_signature': 4},
#  {'danceability': 0.822,
#   'energy': 0.739,
#   'key': 1,
#   'loudness': -4.541,
#   'mode': 0,
#   'speechiness': 0.0311,
#   'acousticness': 0.0264,
#   'instrumentalness': 4.26e-05,
#   'liveness': 0.181,
#   'valence': 0.745,
#   'tempo': 118.992,
#   'type': 'audio_features',
#   'id': '2x7MyWybabEz6Y6wvHuwGE',
#   'uri': 'spotify:track:2x7MyWybabEz6Y6wvHuwGE',
#   'track_href': 'https://api.spotify.com/v1/tracks/2x7MyWybabEz6Y6wvHuwGE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2x7MyWybabEz6Y6wvHuwGE',
#   'duration_ms': 241933,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.745,
#   'key': 6,
#   'loudness': -4.432,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.178,
#   'instrumentalness': 1.59e-05,
#   'liveness': 0.111,
#   'valence': 0.435,
#   'tempo': 129.966,
#   'type': 'audio_features',
#   'id': '1GEBsLDvJGw7kviySRI6GX',
#   'uri': 'spotify:track:1GEBsLDvJGw7kviySRI6GX',
#   'track_href': 'https://api.spotify.com/v1/tracks/1GEBsLDvJGw7kviySRI6GX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1GEBsLDvJGw7kviySRI6GX',
#   'duration_ms': 232120,
#   'time_signature': 4},
#  {'danceability': 0.635,
#   'energy': 0.647,
#   'key': 5,
#   'loudness': -5.864,
#   'mode': 1,
#   'speechiness': 0.0366,
#   'acousticness': 0.192,
#   'instrumentalness': 0,
#   'liveness': 0.154,
#   'valence': 0.201,
#   'tempo': 104.058,
#   'type': 'audio_features',
#   'id': '6LtPIXlIzPOTF8vTecYjRe',
#   'uri': 'spotify:track:6LtPIXlIzPOTF8vTecYjRe',
#   'track_href': 'https://api.spotify.com/v1/tracks/6LtPIXlIzPOTF8vTecYjRe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6LtPIXlIzPOTF8vTecYjRe',
#   'duration_ms': 262693,
#   'time_signature': 4}]

# %%
selected_playlist_df = pd.DataFrame(song_list)

# %%
selected_playlist_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.706   0.841    7    -3.956     1       0.0418      0.000079
# 1           0.429   0.661   11    -7.227     1       0.0281      0.002390
# 2           0.908   0.669    7    -2.827     1       0.0738      0.002860
# 3           0.556   0.864    3    -5.870     0       0.0584      0.009580
# 4           0.639   0.628    6    -7.578     0       0.0399      0.038100
# ..            ...     ...  ...       ...   ...          ...           ...
# 145         0.699   0.812    0    -6.005     1       0.0377      0.016400
# 146         0.597   0.837   10    -6.518     1       0.3750      0.004270
# 147         0.822   0.739    1    -4.541     0       0.0311      0.026400
# 148         0.687   0.745    6    -4.432     1       0.0379      0.178000
# 149         0.635   0.647    5    -5.864     1       0.0366      0.192000
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.0688    0.861  132.032  audio_features
# 1            0.000121    0.2340    0.285  173.372  audio_features
# 2            0.000000    0.2370    0.662  112.238  audio_features
# 3            0.000000    0.2090    0.400  105.143  audio_features
# 4            0.000000    0.3860    0.430   90.482  audio_features
# ..                ...       ...      ...      ...             ...
# 145          0.000763    0.1050    0.662  138.185  audio_features
# 146          0.001150    0.8390    0.447  126.342  audio_features
# 147          0.000043    0.1810    0.745  118.992  audio_features
# 148          0.000016    0.1110    0.435  129.966  audio_features
# 149          0.000000    0.1540    0.201  104.058  audio_features
#
#                          id                                   uri  \
# 0    0iGckQFyv6svOfAbAY9aWJ  spotify:track:0iGckQFyv6svOfAbAY9aWJ
# 1    3AJwUDP919kvQ9QcozQPxg  spotify:track:3AJwUDP919kvQ9QcozQPxg
# 2    7lQ8MOhq6IN2w8EYcFNSUk  spotify:track:7lQ8MOhq6IN2w8EYcFNSUk
# 3    60a0Rd6pjrkxjPbaKzXjfq  spotify:track:60a0Rd6pjrkxjPbaKzXjfq
# 4    5TRPicyLGbAF2LGBFbHGvO  spotify:track:5TRPicyLGbAF2LGBFbHGvO
# ..                      ...                                   ...
# 145  4dyx5SzxPPaD8xQIid5Wjj  spotify:track:4dyx5SzxPPaD8xQIid5Wjj
# 146  1xNcBAoUw8Hz6LqK2jt4Ff  spotify:track:1xNcBAoUw8Hz6LqK2jt4Ff
# 147  2x7MyWybabEz6Y6wvHuwGE  spotify:track:2x7MyWybabEz6Y6wvHuwGE
# 148  1GEBsLDvJGw7kviySRI6GX  spotify:track:1GEBsLDvJGw7kviySRI6GX
# 149  6LtPIXlIzPOTF8vTecYjRe  spotify:track:6LtPIXlIzPOTF8vTecYjRe
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0iGckQFyv6sv...
# 1    https://api.spotify.com/v1/tracks/3AJwUDP919kv...
# 2    https://api.spotify.com/v1/tracks/7lQ8MOhq6IN2...
# 3    https://api.spotify.com/v1/tracks/60a0Rd6pjrkx...
# 4    https://api.spotify.com/v1/tracks/5TRPicyLGbAF...
# ..                                                 ...
# 145  https://api.spotify.com/v1/tracks/4dyx5SzxPPaD...
# 146  https://api.spotify.com/v1/tracks/1xNcBAoUw8Hz...
# 147  https://api.spotify.com/v1/tracks/2x7MyWybabEz...
# 148  https://api.spotify.com/v1/tracks/1GEBsLDvJGw7...
# 149  https://api.spotify.com/v1/tracks/6LtPIXlIzPOT...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/0iGc...       220227
# 1    https://api.spotify.com/v1/audio-analysis/3AJw...       266773
# 2    https://api.spotify.com/v1/audio-analysis/7lQ8...       290320
# 3    https://api.spotify.com/v1/audio-analysis/60a0...       216880
# 4    https://api.spotify.com/v1/audio-analysis/5TRP...       237507
# ..                                                 ...          ...
# 145  https://api.spotify.com/v1/audio-analysis/4dyx...       276693
# 146  https://api.spotify.com/v1/audio-analysis/1xNc...       171360
# 147  https://api.spotify.com/v1/audio-analysis/2x7M...       241933
# 148  https://api.spotify.com/v1/audio-analysis/1GEB...       232120
# 149  https://api.spotify.com/v1/audio-analysis/6LtP...       262693
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 145               4
# 146               4
# 147               4
# 148               4
# 149               4
#
# [150 rows x 18 columns]

# %%
salsa_playlist= get_playlist_tracks('spotify','6BROuMbBjhhOzP1gAuiiit')

# %%
salsa_playlist
# Out:
# [{'added_at': '2020-11-03T00:22:45Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/
},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'disc_number': 1,
#    'duration_ms': 252346,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSD11300112'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3QHMxEOAGD51PDlbFPHLyJ'},
#    'href': 'https://api.spotify.com/v1/tracks/3QHMxEOAGD51PDlbFPHLyJ',
#    'id': '3QHMxEOAGD51PDlbFPHLyJ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Vivir Mi Vida',
#    'popularity': 80,
#    'preview_url': 'https://p.scdn.co/mp3-preview/618d945e549b699453db828c6f363fc64671225b?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3QHMxEOAGD51PDlbFPHLyJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T00:41:56Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2weA6hhVqTIN2gSn9PUB9U'},
#       'href': 'https://api.spotify.com/v1/artists/2weA6hhVqTIN2gSn9PUB9U',
#       'id': '2weA6hhVqTIN2gSn9PUB9U',
#       'name': 'Celia Cruz',
#       'type': 'artist',
#       'uri': 'spotify:artist:2weA6hhVqTIN2gSn9PUB9U'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/634V0km4mTClHkrGiEKw9B'},
#     'href': 'https://api.spotify.com/v1/albums/634V0km4mTClHkrGiEKw9B',
#     'id': '634V0km4mTClHkrGiEKw9B',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d769d9aa3067cda1475f6894',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d769d9aa3067cda1475f6894',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d769d9aa3067cda1475f6894',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Celia Cruz - Greatest Hits',
#     'release_date': '2009',
#     'release_date_precision': 'year',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:634V0km4mTClHkrGiEKw9B'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2weA6hhVqTIN2gSn9PUB9U'},
#      'href': 'https://api.spotify.com/v1/artists/2weA6hhVqTIN2gSn9PUB9U',
#      'id': '2weA6hhVqTIN2gSn9PUB9U',
#      'name': 'Celia Cruz',
#      'type': 'artist',
#      'uri': 'spotify:artist:2weA6hhVqTIN2gSn9PUB9U'}],
#    'disc_number': 1,
#    'duration_ms': 291946,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USDBB0600020'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6ydEhrdfzhI29D2NBAqUY1'},
#    'href': 'https://api.spotify.com/v1/tracks/6ydEhrdfzhI29D2NBAqUY1',
#    'id': '6ydEhrdfzhI29D2NBAqUY1',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2pMHLKOA5drz72vffJTBPa'},
#     'href': 'https://api.spotify.com/v1/tracks/2pMHLKOA5drz72vffJTBPa',
#     'id': '2pMHLKOA5drz72vffJTBPa',
#     'type': 'track',
#     'uri': 'spotify:track:2pMHLKOA5drz72vffJTBPa'},
#    'name': 'Quimbara',
#    'popularity': 67,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6ydEhrdfzhI29D2NBAqUY1'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T00:53:46Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lwmRuXgjX8xIwlnauTZIP'},
#       'href': 'https://api.spotify.com/v1/artists/5lwmRuXgjX8xIwlnauTZIP',
#       'id': '5lwmRuXgjX8xIwlnauTZIP',
#       'name': 'Romeo Santos',
#       'type': 'artist',
#       'uri': 'spotify:artist:5lwmRuXgjX8xIwlnauTZIP'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7LNyFYqkKp7rntl0mC6Jce'},
#     'href': 'https://api.spotify.com/v1/albums/7LNyFYqkKp7rntl0mC6Jce',
#     'id': '7LNyFYqkKp7rntl0mC6Jce',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273906e8cc991ca530870b6a66a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02906e8cc991ca530870b6a66a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851906e8cc991ca530870b6a66a',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Fórmula, Vol. 2 (Deluxe Edition) [Clean Version]',
#     'release_date': '2014-02-25',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:7LNyFYqkKp7rntl0mC6Jce'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lwmRuXgjX8xIwlnauTZIP'},
#      'href': 'https://api.spotify.com/v1/artists/5lwmRuXgjX8xIwlnauTZIP',
#      'id': '5lwmRuXgjX8xIwlnauTZIP',
#      'name': 'Romeo Santos',
#      'type': 'artist',
#      'uri': 'spotify:artist:5lwmRuXgjX8xIwlnauTZIP'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#      'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#      'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#      'name': 'Marc Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#    'disc_number': 1,
#    'duration_ms': 306453,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSD11300467'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1bqHDCBs1wtB7VkAJ9NHjB'},
#    'href': 'https://api.spotify.com/v1/tracks/1bqHDCBs1wtB7VkAJ9NHjB',
#    'id': '1bqHDCBs1wtB7VkAJ9NHjB',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Yo También (feat. Marc Anthony)',
#    'popularity': 36,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2f8e7c913ab0f9026e5b1a4d300ef173b6a21e76?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:1bqHDCBs1wtB7VkAJ9NHjB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T00:53:53Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27vNK840zYq6IfDijHPsv1'},
#       'href': 'https://api.spotify.com/v1/artists/27vNK840zYq6IfDijHPsv1',
#       'id': '27vNK840zYq6IfDijHPsv1',
#       'name': 'Gilberto Santa Rosa',
#       'type': 'artist',
#       'uri': 'spotify:artist:27vNK840zYq6IfDijHPsv1'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0GxUdSpTj1PeJlqq0knC5I'},
#     'href': 'https://api.spotify.com/v1/albums/0GxUdSpTj1PeJlqq0knC5I',
#     'id': '0GxUdSpTj1PeJlqq0knC5I',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e16b4c3f943975315367e803',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e16b4c3f943975315367e803',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e16b4c3f943975315367e803',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Contraste En Salsa',
#     'release_date': '2008-07-21',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:0GxUdSpTj1PeJlqq0knC5I'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27vNK840zYq6IfDijHPsv1'},
#      'href': 'https://api.spotify.com/v1/artists/27vNK840zYq6IfDijHPsv1',
#      'id': '27vNK840zYq6IfDijHPsv1',
#      'name': 'Gilberto Santa Rosa',
#      'type': 'artist',
#      'uri': 'spotify:artist:27vNK840zYq6IfDijHPsv1'}],
#    'disc_number': 1,
#    'duration_ms': 266786,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSD10704531'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5YfqVqJwjxiyhxvofbCnHp'},
#    'href': 'https://api.spotify.com/v1/tracks/5YfqVqJwjxiyhxvofbCnHp',
#    'id': '5YfqVqJwjxiyhxvofbCnHp',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Conteo Regresivo - Salsa Version',
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8c24e42d8c7f0dfe61ee4be9576d9542aee5a88c?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5YfqVqJwjxiyhxvofbCnHp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T01:01:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70nxnxEqDQIEWneRjg2Q4O'},
#       'href': 'https://api.spotify.com/v1/artists/70nxnxEqDQIEWneRjg2Q4O',
#       'id': '70nxnxEqDQIEWneRjg2Q4O',
#       'name': "Adolescent's Orquesta",
#       'type': 'artist',
#       'uri': 'spotify:artist:70nxnxEqDQIEWneRjg2Q4O'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1r7GpzIQ7EHHsYrTRey2lV'},
#     'href': 'https://api.spotify.com/v1/albums/1r7GpzIQ7EHHsYrTRey2lV',
#     'id': '1r7GpzIQ7EHHsYrTRey2lV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737eabf7e5fa097cdfc4be26e3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027eabf7e5fa097cdfc4be26e3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517eabf7e5fa097cdfc4be26e3',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Ahora Mas Que Nunca',
#     'release_date': '2012-09-20',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:1r7GpzIQ7EHHsYrTRey2lV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70nxnxEqDQIEWneRjg2Q4O'},
#      'href': 'https://api.spotify.com/v1/artists/70nxnxEqDQIEWneRjg2Q4O',
#      'id': '70nxnxEqDQIEWneRjg2Q4O',
#      'name': "Adolescent's Orquesta",
#      'type': 'artist',
#      'uri': 'spotify:artist:70nxnxEqDQIEWneRjg2Q4O'}],
#    'disc_number': 1,
#    'duration_ms': 273763,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCADQ1807528'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1HWbpfmzt1YplLceHgirCv'},
#    'href': 'https://api.spotify.com/v1/tracks/1HWbpfmzt1YplLceHgirCv',
#    'id': '1HWbpfmzt1YplLceHgirCv',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5SIoLK4aqXc2UzNrhVHwtp'},
#     'href': 'https://api.spotify.com/v1/tracks/5SIoLK4aqXc2UzNrhVHwtp',
#     'id': '5SIoLK4aqXc2UzNrhVHwtp',
#     'type': 'track',
#     'uri': 'spotify:track:5SIoLK4aqXc2UzNrhVHwtp'},
#    'name': 'Virgen',
#    'popularity': 78,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1a1bcf4602022ed59f41b105fe954e125d89ac99?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:1HWbpfmzt1YplLceHgirCv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T01:02:27Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7x5Slu7yTE5icZjNsc3OzW'},
#       'href': 'https://api.spotify.com/v1/artists/7x5Slu7yTE5icZjNsc3OzW',
#       'id': '7x5Slu7yTE5icZjNsc3OzW',
#       'name': 'Willie Colón',
#       'type': 'artist',
#       'uri': 'spotify:artist:7x5Slu7yTE5icZjNsc3OzW'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1g47c1ObKFlLpjqDExfCap'},
#     'href': 'https://api.spotify.com/v1/albums/1g47c1ObKFlLpjqDExfCap',
#     'id': '1g47c1ObKFlLpjqDExfCap',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734ee304f8b3549fd6ac3d649b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024ee304f8b3549fd6ac3d649b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514ee304f8b3549fd6ac3d649b',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Top Secrets (Altos Secretos)',
#     'release_date': '2009',
#     'release_date_precision': 'year',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:1g47c1ObKFlLpjqDExfCap'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7x5Slu7yTE5icZjNsc3OzW'},
#      'href': 'https://api.spotify.com/v1/artists/7x5Slu7yTE5icZjNsc3OzW',
#      'id': '7x5Slu7yTE5icZjNsc3OzW',
#      'name': 'Willie Colón',
#      'type': 'artist',
#      'uri': 'spotify:artist:7x5Slu7yTE5icZjNsc3OzW'}],
#    'disc_number': 1,
#    'duration_ms': 414706,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USDBB0600751'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5XWfwjzFNl2pTB737fx7qr'},
#    'href': 'https://api.spotify.com/v1/tracks/5XWfwjzFNl2pTB737fx7qr',
#    'id': '5XWfwjzFNl2pTB737fx7qr',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2rhaQ3sW3hZ0hg4W4RzCKG'},
#     'href': 'https://api.spotify.com/v1/tracks/2rhaQ3sW3hZ0hg4W4RzCKG',
#     'id': '2rhaQ3sW3hZ0hg4W4RzCKG',
#     'type': 'track',
#     'uri': 'spotify:track:2rhaQ3sW3hZ0hg4W4RzCKG'},
#    'name': 'El Gran Varón',
#    'popularity': 72,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:5XWfwjzFNl2pTB737fx7qr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T01:02:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BiAkgxrLIXhB4evNuF2hn'},
#       'href': 'https://api.spotify.com/v1/artists/3BiAkgxrLIXhB4evNuF2hn',
#       'id': '3BiAkgxrLIXhB4evNuF2hn',
#       'name': 'Charlie Cruz',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BiAkgxrLIXhB4evNuF2hn'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/797bLNHEfSLtpxeRtDEHcx'},
#     'href': 'https://api.spotify.com/v1/albums/797bLNHEfSLtpxeRtDEHcx',
#     'id': '797bLNHEfSLtpxeRtDEHcx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735ef0a2b271110f2cd6234f64',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025ef0a2b271110f2cd6234f64',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515ef0a2b271110f2cd6234f64',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Sigo Aqui',
#     'release_date': '2010-11-16',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:797bLNHEfSLtpxeRtDEHcx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BiAkgxrLIXhB4evNuF2hn'},
#      'href': 'https://api.spotify.com/v1/artists/3BiAkgxrLIXhB4evNuF2hn',
#      'id': '3BiAkgxrLIXhB4evNuF2hn',
#      'name': 'Charlie Cruz',
#      'type': 'artist',
#      'uri': 'spotify:artist:3BiAkgxrLIXhB4evNuF2hn'}],
#    'disc_number': 1,
#    'duration_ms': 273576,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZ7R41750932'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5gKOs03E43d3TGZYzelQsY'},
#    'href': 'https://api.spotify.com/v1/tracks/5gKOs03E43d3TGZYzelQsY',
#    'id': '5gKOs03E43d3TGZYzelQsY',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track
},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2URe3fGSKuCh8v0d49lsNU'},
#    'href': 'https://api.spotify.com/v1/tracks/2URe3fGSKuCh8v0d49lsNU',
#    'id': '2URe3fGSKuCh8v0d49lsNU',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6F3YJ3vWzatHA3nz6GwDoA'},
#     'href': 'https://api.spotify.com/v1/tracks/6F3YJ3vWzatHA3nz6GwDoA',
#     'id': '6F3YJ3vWzatHA3nz6GwDoA',
#     'type': 'track',
#     'uri': 'spotify:track:6F3YJ3vWzatHA3nz6GwDoA'},
#    'name': 'Regálame una Noche',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3dc8214b32c72493f41107b5654a2effcad66064?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2URe3fGSKuCh8v0d49lsNU'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T01:04:33Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2mUI4K6csTQd3jieswcmiI'},
#       'href': 'https://api.spotify.com/v1/artists/2mUI4K6csTQd3jieswcmiI',
#       'id': '2mUI4K6csTQd3jieswcmiI',
#       'name': 'Luis Enrique',
#       'type': 'artist',
#       'uri': 'spotify:artist:2mUI4K6csTQd3jieswcmiI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0VVFatREnibJ2UhZFLqAdB'},
#     'href': 'https://api.spotify.com/v1/albums/0VVFatREnibJ2UhZFLqAdB',
#     'id': '0VVFatREnibJ2UhZFLqAdB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b7a4dab0d815795f6bf8739b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b7a4dab0d815795f6bf8739b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b7a4dab0d815795f6bf8739b',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Ciclos',
#     'release_date': '2009',
#     'release_date_precision': 'year',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0VVFatREnibJ2UhZFLqAdB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2mUI4K6csTQd3jieswcmiI'},
#      'href': 'https://api.spotify.com/v1/artists/2mUI4K6csTQd3jieswcmiI',
#      'id': '2mUI4K6csTQd3jieswcmiI',
#      'name': 'Luis Enrique',
#      'type': 'artist',
#      'uri': 'spotify:artist:2mUI4K6csTQd3jieswcmiI'}],
#    'disc_number': 1,
#    'duration_ms': 259853,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUYG1075006'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7nDIflSHQXzaa8zupxwv3U'},
#    'href': 'https://api.spotify.com/v1/tracks/7nDIflSHQXzaa8zupxwv3U',
#    'id': '7nDIflSHQXzaa8zupxwv3U',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5jJTqI5yteOyLWoDTjiHCO'},
#     'href': 'https://api.spotify.com/v1/tracks/5jJTqI5yteOyLWoDTjiHCO',
#     'id': '5jJTqI5yteOyLWoDTjiHCO',
#     'type': 'track',
#     'uri': 'spotify:track:5jJTqI5yteOyLWoDTjiHCO'},
#    'name': 'Yo No Sé Mañana',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f3a78b16e107a5b3d2a01a8e4af007c6328e4a37?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7nDIflSHQXzaa8zupxwv3U'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T01:04:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HyrDGPLI0c9Rd8luuO0zw'},
#       'href': 'https://api.spotify.com/v1/artists/3HyrDGPLI0c9Rd8luuO0zw',
#       'id': '3HyrDGPLI0c9Rd8luuO0zw',
#       'name': 'Maelo Ruiz',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HyrDGPLI0c9Rd8luuO0zw'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/328PG2rhdw4dSzUuPL5laC'},
#     'href': 'https://api.spotify.com/v1/albums/328PG2rhdw4dSzUuPL5laC',
#     'id': '328PG2rhdw4dSzUuPL5laC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d2b795921f14281f02696a19',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d2b795921f14281f02696a19',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d2b795921f14281f02696a19',
#       'width': 64}],
#     'is_playable': True,
#     'name': '30 Mejores',
#     'release_date': '2009-08-11',
#     'release_date_precision': 'day',
#     'total_tracks': 30,
#     'type': 'album',
#     'uri': 'spotify:album:328PG2rhdw4dSzUuPL5laC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HyrDGPLI0c9Rd8luuO0zw'},
#      'href': 'https://api.spotify.com/v1/artists/3HyrDGPLI0c9Rd8luuO0zw',
#      'id': '3HyrDGPLI0c9Rd8luuO0zw',
#      'name': 'Maelo Ruiz',
#      'type': 'artist',
#      'uri': 'spotify:artist:3HyrDGPLI0c9Rd8luuO0zw'}],
#    'disc_number': 1,
#    'duration_ms': 275893,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'COC010325728'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0rBmvZ4ftXKpxsocjsbAun'},
#    'href': 'https://api.spotify.com/v1/tracks/0rBmvZ4ftXKpxsocjsbAun',
#    'id': '0rBmvZ4ftXKpxsocjsbAun',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6JuPLGUOfgo8GhhB6cu7tM'},
#     'href': 'https://api.spotify.com/v1/tracks/6JuPLGUOfgo8GhhB6cu7tM',
#     'id': '6JuPLGUOfgo8GhhB6cu7tM',
#     'type': 'track',
#     'uri': 'spotify:track:6JuPLGUOfgo8GhhB6cu7tM'},
#    'name': 'Será Qué SÍ',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/211641690e112812024a74d4e43b28057db1506f?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0rBmvZ4ftXKpxsocjsbAun'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T01:05:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70nxnxEqDQIEWneRjg2Q4O'},
#       'href': 'https://api.spotify.com/v1/artists/70nxnxEqDQIEWneRjg2Q4O',
#       'id': '70nxnxEqDQIEWneRjg2Q4O',
#       'name': "Adolescent's Orquesta",
#       'type': 'artist',
#       'uri': 'spotify:artist:70nxnxEqDQIEWneRjg2Q4O'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3oN9w3Jyd8tZQq8zoO6EL2'},
#     'href': 'https://api.spotify.com/v1/albums/3oN9w3Jyd8tZQq8zoO6EL2',
#     'id': '3oN9w3Jyd8tZQq8zoO6EL2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731d074c5dc3d7774230609c31',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021d074c5dc3d7774230609c31',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511d074c5dc3d7774230609c31',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'La Misma Pluma',
#     'release_date': '2012-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3oN9w3Jyd8tZQq8zoO6EL2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70nxnxEqDQIEWneRjg2Q4O'},
#      'href': 'https://api.spotify.com/v1/artists/70nxnxEqDQIEWneRjg2Q4O',
#      'id': '70nxnxEqDQIEWneRjg2Q4O',
#      'name': "Adolescent's Orquesta",
#      'type': 'artist',
#      'uri': 'spotify:artist:70nxnxEqDQIEWneRjg2Q4O'}],
#    'disc_number': 1,
#    'duration_ms': 317596,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCADQ1807539'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0xgdMUInG692P5WjBElwvR'},
#    'href': 'https://api.spotify.com/v1/tracks/0xgdMUInG692P5WjBElwvR',
#    'id': '0xgdMUInG692P5WjBElwvR',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/68l1KAnUNML8GMTAuQu0X6'},
#     'href': 'https://api.spotify.com/v1/tracks/68l1KAnUNML8GMTAuQu0X6',
#     'id': '68l1KAnUNML8GMTAuQu0X6',
#     'type': 'track',
#     'uri': 'spotify:track:68l1KAnUNML8GMTAuQu0X6'},
#    'name': 'Si Te Marchas (Voy a Llorar)',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/760958fde01389e1fa2710575fe2d5751c60b9fa?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0xgdMUInG692P5WjBElwvR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T01:05:21Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HyrDGPLI0c9Rd8luuO0zw'},
#       'href': 'https://api.spotify.com/v1/artists/3HyrDGPLI0c9Rd8luuO0zw',
#       'id': '3HyrDGPLI0c9Rd8luuO0zw',
#       'name': 'Maelo Ruiz',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HyrDGPLI0c9Rd8luuO0zw'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/328PG2rhdw4dSzUuPL5laC'},
#     'href': 'https://api.spotify.com/v1/albums/328PG2rhdw4dSzUuPL5laC',
#     'id': '328PG2rhdw4dSzUuPL5laC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d2b795921f14281f02696a19',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d2b795921f14281f02696a19',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d2b795921f14281f02696a19',
#       'width': 64}],
#     'is_playable': True,
#     'name': '30 Mejores',
#     'release_date': '2009-08-11',
#     'release_date_precision': 'day',
#     'total_tracks': 30,
#     'type': 'album',
#     'uri': 'spotify:album:328PG2rhdw4dSzUuPL5laC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HyrDGPLI0c9Rd8luuO0zw'},
#      'href': 'https://api.spotify.com/v1/artists/3HyrDGPLI0c9Rd8luuO0zw',
#      'id': '3HyrDGPLI0c9Rd8luuO0zw',
#      'name': 'Maelo Ruiz',
#      'type': 'artist',
#      'uri': 'spotify:artist:3HyrDGPLI0c9Rd8luuO0zw'}],
#    'disc_number': 1,
#    'duration_ms': 255213,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'COC010727256'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5WyX397vZTvYQwSrylCka0'},
#    'href': 'https://api.spotify.com/v1/tracks/5WyX397vZTvYQwSrylCka0',
#    'id': '5WyX397vZTvYQwSrylCka0',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2jlORRYIXNGc2TUWZiMr1B'},
#     'href': 'https://api.spotify.com/v1/tracks/2jlORRYIXNGc2TUWZiMr1B',
#     'id': '2jlORRYIXNGc2TUWZiMr1B',
#     'type': 'track',
#     'uri': 'spotify:track:2jlORRYIXNGc2TUWZiMr1B'},
#    'name': 'Amiga',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9acc281015ace925a483062ceb0b39f11d3b0e86?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5WyX397vZTvYQwSrylCka0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-03T01:05:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wLXwxDeWQ8mtUIRPxGiD6'},
#       'href': 'https://api.spotify.com/v1/artists/4wLXwxDeWQ8mtUIRPxGiD6',
#       'id': '4wLXwxDeWQ8mtUIRPxGiD6',
#       'name': 'Marc Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wLXwxDeWQ8mtUIRPxGiD6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vBpLg3T8bojcqzoKI6m0R'},
# ...
#    'disc_number': 1,
#    'duration_ms': 305426,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLB630400126'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1UhC65P18YWD02sW0GiyMl'},
#    'href': 'https://api.spotify.com/v1/tracks/1UhC65P18YWD02sW0GiyMl',
#    'id': '1UhC65P18YWD02sW0GiyMl',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ahora Quien',
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b29d17c990734b9afa5d0cf6d60bd9eb8749e3af?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:1UhC65P18YWD02sW0GiyMl'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-20T13:35:23Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70nxnxEqDQIEWneRjg2Q4O'},
#       'href': 'https://api.spotify.com/v1/artists/70nxnxEqDQIEWneRjg2Q4O',
#       'id': '70nxnxEqDQIEWneRjg2Q4O',
#       'name': "Adolescent's Orquesta",
#       'type': 'artist',
#       'uri': 'spotify:artist:70nxnxEqDQIEWneRjg2Q4O'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3oN9w3Jyd8tZQq8zoO6EL2'},
#     'href': 'https://api.spotify.com/v1/albums/3oN9w3Jyd8tZQq8zoO6EL2',
#     'id': '3oN9w3Jyd8tZQq8zoO6EL2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731d074c5dc3d7774230609c31',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021d074c5dc3d7774230609c31',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511d074c5dc3d7774230609c31',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'La Misma Pluma',
#     'release_date': '2012-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3oN9w3Jyd8tZQq8zoO6EL2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70nxnxEqDQIEWneRjg2Q4O'},
#      'href': 'https://api.spotify.com/v1/artists/70nxnxEqDQIEWneRjg2Q4O',
#      'id': '70nxnxEqDQIEWneRjg2Q4O',
#      'name': "Adolescent's Orquesta",
#      'type': 'artist',
#      'uri': 'spotify:artist:70nxnxEqDQIEWneRjg2Q4O'}],
#    'disc_number': 1,
#    'duration_ms': 289959,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCADQ1807542'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/73Wi69BqzsFX1QIAD144qN'},
#    'href': 'https://api.spotify.com/v1/tracks/73Wi69BqzsFX1QIAD144qN',
#    'id': '73Wi69BqzsFX1QIAD144qN',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/48YoXQ4ebKZebztYtfQsas'},
#     'href': 'https://api.spotify.com/v1/tracks/48YoXQ4ebKZebztYtfQsas',
#     'id': '48YoXQ4ebKZebztYtfQsas',
#     'type': 'track',
#     'uri': 'spotify:track:48YoXQ4ebKZebztYtfQsas'},
#    'name': 'Me Negó',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d4dc32996293bde653013993a4f470aaa28f2968?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:73Wi69BqzsFX1QIAD144qN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-21T02:34:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70nxnxEqDQIEWneRjg2Q4O'},
#       'href': 'https://api.spotify.com/v1/artists/70nxnxEqDQIEWneRjg2Q4O',
#       'id': '70nxnxEqDQIEWneRjg2Q4O',
#       'name': "Adolescent's Orquesta",
#       'type': 'artist',
#       'uri': 'spotify:artist:70nxnxEqDQIEWneRjg2Q4O'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1r7GpzIQ7EHHsYrTRey2lV'},
#     'href': 'https://api.spotify.com/v1/albums/1r7GpzIQ7EHHsYrTRey2lV',
#     'id': '1r7GpzIQ7EHHsYrTRey2lV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737eabf7e5fa097cdfc4be26e3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027eabf7e5fa097cdfc4be26e3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517eabf7e5fa097cdfc4be26e3',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Ahora Mas Que Nunca',
#     'release_date': '2012-09-20',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:1r7GpzIQ7EHHsYrTRey2lV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70nxnxEqDQIEWneRjg2Q4O'},
#      'href': 'https://api.spotify.com/v1/artists/70nxnxEqDQIEWneRjg2Q4O',
#      'id': '70nxnxEqDQIEWneRjg2Q4O',
#      'name': "Adolescent's Orquesta",
#      'type': 'artist',
#      'uri': 'spotify:artist:70nxnxEqDQIEWneRjg2Q4O'}],
#    'disc_number': 1,
#    'duration_ms': 257488,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCADQ1807538'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1UCDUtm50LQAgCxROVYaQ2'},
#    'href': 'https://api.spotify.com/v1/tracks/1UCDUtm50LQAgCxROVYaQ2',
#    'id': '1UCDUtm50LQAgCxROVYaQ2',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4u4E5rmrnkRjVnF8jcuZur'},
#     'href': 'https://api.spotify.com/v1/tracks/4u4E5rmrnkRjVnF8jcuZur',
#     'id': '4u4E5rmrnkRjVnF8jcuZur',
#     'type': 'track',
#     'uri': 'spotify:track:4u4E5rmrnkRjVnF8jcuZur'},
#    'name': 'Me Gusta',
#    'popularity': 44,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b7fb4bf26ae93b4b2275f15255f3df9422a88a71?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:1UCDUtm50LQAgCxROVYaQ2'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-21T03:05:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70nxnxEqDQIEWneRjg2Q4O'},
#       'href': 'https://api.spotify.com/v1/artists/70nxnxEqDQIEWneRjg2Q4O',
#       'id': '70nxnxEqDQIEWneRjg2Q4O',
#       'name': "Adolescent's Orquesta",
#       'type': 'artist',
#       'uri': 'spotify:artist:70nxnxEqDQIEWneRjg2Q4O'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2NCLhGDYACSCs0UHT9jLAL'},
#     'href': 'https://api.spotify.com/v1/albums/2NCLhGDYACSCs0UHT9jLAL',
#     'id': '2NCLhGDYACSCs0UHT9jLAL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b3d1b8b84ce0e1c4a3ac108d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b3d1b8b84ce0e1c4a3ac108d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b3d1b8b84ce0e1c4a3ac108d',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Búscame',
#     'release_date': '2008',
#     'release_date_precision': 'year',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2NCLhGDYACSCs0UHT9jLAL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70nxnxEqDQIEWneRjg2Q4O'},
#      'href': 'https://api.spotify.com/v1/artists/70nxnxEqDQIEWneRjg2Q4O',
#      'id': '70nxnxEqDQIEWneRjg2Q4O',
#      'name': "Adolescent's Orquesta",
#      'type': 'artist',
#      'uri': 'spotify:artist:70nxnxEqDQIEWneRjg2Q4O'}],
#    'disc_number': 1,
#    'duration_ms': 223886,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUYG1039684'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/28fHEGFHiQGiP7uQUGxInK'},
#    'href': 'https://api.spotify.com/v1/tracks/28fHEGFHiQGiP7uQUGxInK',
#    'id': '28fHEGFHiQGiP7uQUGxInK',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6OwTDx3O07ThoDUUYCoPib'},
#     'href': 'https://api.spotify.com/v1/tracks/6OwTDx3O07ThoDUUYCoPib',
#     'id': '6OwTDx3O07ThoDUUYCoPib',
#     'type': 'track',
#     'uri': 'spotify:track:6OwTDx3O07ThoDUUYCoPib'},
#    'name': 'Mentirosa',
#    'popularity': 42,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8c591f6e60cf496815b13739a97b083b112bbfb2?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:28fHEGFHiQGiP7uQUGxInK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-12-13T22:55:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jS9nzysQ66L1yfPA0HATF'},
#       'href': 'https://api.spotify.com/v1/artists/7jS9nzysQ66L1yfPA0HATF',
#       'id': '7jS9nzysQ66L1yfPA0HATF',
#       'name': 'Nelson Arrieta',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jS9nzysQ66L1yfPA0HATF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1c8m6rFeA6QIhImbIaZ7k2'},
#       'href': 'https://api.spotify.com/v1/artists/1c8m6rFeA6QIhImbIaZ7k2',
#       'id': '1c8m6rFeA6QIhImbIaZ7k2',
#       'name': 'Ronald Borjas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1c8m6rFeA6QIhImbIaZ7k2'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1BCfXYvYcVKfcNNV7h3TKJ'},
#       'href': 'https://api.spotify.com/v1/artists/1BCfXYvYcVKfcNNV7h3TKJ',
#       'id': '1BCfXYvYcVKfcNNV7h3TKJ',
#       'name': 'Oscarcito',
#       'type': 'artist',
#       'uri': 'spotify:artist:1BCfXYvYcVKfcNNV7h3TKJ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5vab2Rt5XSdV8QAk1pqAqO'},
#     'href': 'https://api.spotify.com/v1/albums/5vab2Rt5XSdV8QAk1pqAqO',
#     'id': '5vab2Rt5XSdV8QAk1pqAqO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731f07abfcfd52e40bde3726ba',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021f07abfcfd52e40bde3726ba',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511f07abfcfd52e40bde3726ba',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Dime Cómo Hago',
#     'release_date': '2021-10-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5vab2Rt5XSdV8QAk1pqAqO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jS9nzysQ66L1yfPA0HATF'},
#      'href': 'https://api.spotify.com/v1/artists/7jS9nzysQ66L1yfPA0HATF',
#      'id': '7jS9nzysQ66L1yfPA0HATF',
#      'name': 'Nelson Arrieta',
#      'type': 'artist',
#      'uri': 'spotify:artist:7jS9nzysQ66L1yfPA0HATF'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1c8m6rFeA6QIhImbIaZ7k2'},
#      'href': 'https://api.spotify.com/v1/artists/1c8m6rFeA6QIhImbIaZ7k2',
#      'id': '1c8m6rFeA6QIhImbIaZ7k2',
#      'name': 'Ronald Borjas',
#      'type': 'artist',
#      'uri': 'spotify:artist:1c8m6rFeA6QIhImbIaZ7k2'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1BCfXYvYcVKfcNNV7h3TKJ'},
#      'href': 'https://api.spotify.com/v1/artists/1BCfXYvYcVKfcNNV7h3TKJ',
#      'id': '1BCfXYvYcVKfcNNV7h3TKJ',
#      'name': 'Oscarcito',
#      'type': 'artist',
#      'uri': 'spotify:artist:1BCfXYvYcVKfcNNV7h3TKJ'}],
#    'disc_number': 1,
#    'duration_ms': 228250,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'TCAFU2124127'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3WSASuEFLKfnGbn3ZelPdu'},
#    'href': 'https://api.spotify.com/v1/tracks/3WSASuEFLKfnGbn3ZelPdu',
#    'id': '3WSASuEFLKfnGbn3ZelPdu',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5SQMbspeEIYJPkXDWeiOJH'},
#     'href': 'https://api.spotify.com/v1/tracks/5SQMbspeEIYJPkXDWeiOJH',
#     'id': '5SQMbspeEIYJPkXDWeiOJH',
#     'type': 'track',
#     'uri': 'spotify:track:5SQMbspeEIYJPkXDWeiOJH'},
#    'name': 'Dime Cómo Hago',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/46629c5485f8573798e31688bf63da63f270656f?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3WSASuEFLKfnGbn3ZelPdu'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-04-10T06:03:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zb4tsvstmlfz99b7fak0f16m9'},
#    'href': 'https://api.spotify.com/v1/users/zb4tsvstmlfz99b7fak0f16m9',
#    'id': 'zb4tsvstmlfz99b7fak0f16m9',
#    'type': 'user',
#    'uri': 'spotify:user:zb4tsvstmlfz99b7fak0f16m9'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27vNK840zYq6IfDijHPsv1'},
#       'href': 'https://api.spotify.com/v1/artists/27vNK840zYq6IfDijHPsv1',
#       'id': '27vNK840zYq6IfDijHPsv1',
#       'name': 'Gilberto Santa Rosa',
#       'type': 'artist',
#       'uri': 'spotify:artist:27vNK840zYq6IfDijHPsv1'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4E3uQMm1IyNndidSzcCjg3'},
#     'href': 'https://api.spotify.com/v1/albums/4E3uQMm1IyNndidSzcCjg3',
#     'id': '4E3uQMm1IyNndidSzcCjg3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738b878221906147900bab3942',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028b878221906147900bab3942',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518b878221906147900bab3942',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Expresion',
#     'release_date': '1999-12-21',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4E3uQMm1IyNndidSzcCjg3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27vNK840zYq6IfDijHPsv1'},
#      'href': 'https://api.spotify.com/v1/artists/27vNK840zYq6IfDijHPsv1',
#      'id': '27vNK840zYq6IfDijHPsv1',
#      'name': 'Gilberto Santa Rosa',
#      'type': 'artist',
#      'uri': 'spotify:artist:27vNK840zYq6IfDijHPsv1'}],
#    'disc_number': 1,
#    'duration_ms': 290413,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSD19904114'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7JElWLgpQ7lxN1JNIYwuVu'},
#    'href': 'https://api.spotify.com/v1/tracks/7JElWLgpQ7lxN1JNIYwuVu',
#    'id': '7JElWLgpQ7lxN1JNIYwuVu',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Que Alguien Me Diga',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e39f9b044092bf5bf966397441b799138d9bada4?cid=3cdaae92842748f4b4e8491566562cd2',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7JElWLgpQ7lxN1JNIYwuVu'},
#   'video_thumbnail': {'url': None}}]

# %%
salsa_id =[]

# %%
for i in salsa_playlist:
    
    salsa_id.append(i["track"]["id"])

# %%
salsa_id
# Out:
# ['3yEtuhGR8jOtusa29jWrhG',
#  '2q9udNV9NK0BL3q9p6TLxf',
#  '3QHMxEOAGD51PDlbFPHLyJ',
#  '6ydEhrdfzhI29D2NBAqUY1',
#  '1bqHDCBs1wtB7VkAJ9NHjB',
#  '5YfqVqJwjxiyhxvofbCnHp',
#  '1HWbpfmzt1YplLceHgirCv',
#  '5XWfwjzFNl2pTB737fx7qr',
#  '5gKOs03E43d3TGZYzelQsY',
#  '7mIlFG1PKmqfTsaT48dEU4',
#  '2ozSogNm6z9G2Uv6a9iji4',
#  '1GT0Q2ZTeKtIBueYKr4vhr',
#  '2URe3fGSKuCh8v0d49lsNU',
#  '7nDIflSHQXzaa8zupxwv3U',
#  '0rBmvZ4ftXKpxsocjsbAun',
#  '0xgdMUInG692P5WjBElwvR',
#  '5WyX397vZTvYQwSrylCka0',
#  '47TyfLrGhYHHyyQWk64d0M',
#  '2QOA0E6cuORpCD6gfKCoRk',
#  '0bUgIkg2Nyoqon5ypj2sUt',
#  '0Tu9FmT2ATnzwTQm9TcnGu',
#  '0bXUbrHbHOcvyv1Fmurmfq',
#  '19TJqGoUMbptYQ1Lwfd2Ri',
#  '2naqSVQHgiaoEpxtkVOhmK',
#  '7nflSbrgBCitUnW4psdR7a',
#  '2wBnlC3DdW9s1UnFlAWCdI',
#  '5irJ9qqvXp2hPpRqAhqWiS',
#  '4RCzKrRP5OrB4bvINizTGf',
#  '4UHRMwbbiZ7tkeEkhyN7iB',
#  '5N8HRh3pKXakJrdxQKMi1j',
#  '41LiGcvaTkXHyPjfsxKvWv',
#  '4zOZQdgs7nSjMkqB7keSM5',
#  '6SZrhuLGjIzsliOLEG7Y7O',
#  '2naqSVQHgiaoEpxtkVOhmK',
#  '2BOcua9pjhKuVtgN40AAHX',
#  '2kBgJXGbVA6WcA40IFA9KF',
#  '00Ro1lnV3V6i87aY4t8Q43',
#  '4UXdWLgdsdmkeOFABIGwZY',
#  '16c6awlmGfeusU7zoVu5yc',
#  '4tw0DIMjr09hH0Ot8ePp0w',
#  '5Uve0jm1RgxKWzdSvncBDO',
#  '56Zt2aybXpAHIA4dxxKQxF',
#  '3GgI4QQWvsqqdKCvnNN0UM',
#  '2SSGUtDsmXSmUKi2YAcf7L',
#  '1wvWtEqSwnmoRuPkPb74Ef',
#  '59YDizy2BZUUe3zlYYDxmv',
#  '537KE6mr2r62jIp1036Stq',
#  '1BwrMGGhPA6GarWIYaFrW8',
#  '0A6uCqTC2RS0x7lyDTIend',
#  '2soM5TyZ2c98CDMvXljT7a',
#  '36T4XY4vbxmw40XMJPe3zw',
#  '1RpCXjlxFGS6LfPOvqSJ7M',
#  '2MnKininlD8bY9ggRNSJ37',
#  '6uR3Trakqs0tMkSBcuxXdb',
#  '4pUmQqaZklcCOB3rFdWc7g',
#  '7arYtARCpVmLPsB8Chua4A',
#  '4ZWksPVZdma0A5GiSCStIK',
#  '3rsVX2Pd8UkjqF2MAZqeif',
#  '7guVlnmdqpcFjJmwP6RSRr',
#  '5kwJWQgBaJWm1QZtWeC3uj',
#  '37nXsqE1XW0cxOQvIMsmFc',
#  '2WOMIZnu99mzeMo13bZq8m',
#  '00Ro1lnV3V6i87aY4t8Q43',
#  '6VQ2fI8goSX8mpSvytXkXR',
#  '3WXfQDsASfXrSojk9WB3aR',
#  '5mg6sU732O35VMfCYk3lmX',
#  '1UhC65P18YWD02sW0GiyMl',
#  '73Wi69BqzsFX1QIAD144qN',
#  '1UCDUtm50LQAgCxROVYaQ2',
#  '28fHEGFHiQGiP7uQUGxInK',
#  '3WSASuEFLKfnGbn3ZelPdu',
#  '7JElWLgpQ7lxN1JNIYwuVu']

# %%
salsa_af_song =[]

# %%
for i in salsa_id:
    salsa_af_song.append(sp.audio_features(i)[0])

# %%
salsa_af_song
# Out:
# [{'danceability': 0.691,
#   'energy': 0.658,
#   'key': 0,
#   'loudness': -6.496,
#   'mode': 1,
#   'speechiness': 0.0359,
#   'acousticness': 0.398,
#   'instrumentalness': 4.58e-05,
#   'liveness': 0.112,
#   'valence': 0.617,
#   'tempo': 97.68,
#   'type': 'audio_features',
#   'id': '3yEtuhGR8jOtusa29jWrhG',
#   'uri': 'spotify:track:3yEtuhGR8jOtusa29jWrhG',
#   'track_href': 'https://api.spotify.com/v1/tracks/3yEtuhGR8jOtusa29jWrhG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yEtuhGR8jOtusa29jWrhG',
#   'duration_ms': 300160,
#   'time_signature': 4},
#  {'danceability': 0.805,
#   'energy': 0.757,
#   'key': 8,
#   'loudness': -7.46,
#   'mode': 1,
#   'speechiness': 0.0355,
#   'acousticness': 0.279,
#   'instrumentalness': 0.000839,
#   'liveness': 0.101,
#   'valence': 0.973,
#   'tempo': 102.14,
#   'type': 'audio_features',
#   'id': '2q9udNV9NK0BL3q9p6TLxf',
#   'uri': 'spotify:track:2q9udNV9NK0BL3q9p6TLxf',
#   'track_href': 'https://api.spotify.com/v1/tracks/2q9udNV9NK0BL3q9p6TLxf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2q9udNV9NK0BL3q9p6TLxf',
#   'duration_ms': 271031,
#   'time_signature': 4},
#  {'danceability': 0.656,
#   'energy': 0.877,
#   'key': 0,
#   'loudness': -3.231,
#   'mode': 0,
#   'speechiness': 0.0342,
#   'acousticness': 0.345,
#   'instrumentalness': 0,
#   'liveness': 0.349,
#   'valence': 0.894,
#   'tempo': 105.018,
#   'type': 'audio_features',
#   'id': '3QHMxEOAGD51PDlbFPHLyJ',
#   'uri': 'spotify:track:3QHMxEOAGD51PDlbFPHLyJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QHMxEOAGD51PDlbFPHLyJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QHMxEOAGD51PDlbFPHLyJ',
#   'duration_ms': 252347,
#   'time_signature': 4},
#  {'danceability': 0.6,
#   'energy': 0.633,
#   'key': 4,
#   'loudness': -7.507,
#   'mode': 0,
#   'speechiness': 0.0667,
#   'acousticness': 0.741,
#   'instrumentalness': 0.0736,
#   'liveness': 0.0478,
#   'valence': 0.966,
#   'tempo': 120.627,
#   'type': 'audio_features',
#   'id': '6ydEhrdfzhI29D2NBAqUY1',
#   'uri': 'spotify:track:6ydEhrdfzhI29D2NBAqUY1',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ydEhrdfzhI29D2NBAqUY1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ydEhrdfzhI29D2NBAqUY1',
#   'duration_ms': 291947,
#   'time_signature': 4},
#  {'danceability': 0.481,
#   'energy': 0.787,
#   'key': 4,
#   'loudness': -4.218,
#   'mode': 0,
#   'speechiness': 0.0926,
#   'acousticness': 0.381,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.734,
#   'tempo': 182.279,
#   'type': 'audio_features',
#   'id': '1bqHDCBs1wtB7VkAJ9NHjB',
#   'uri': 'spotify:track:1bqHDCBs1wtB7VkAJ9NHjB',
#   'track_href': 'https://api.spotify.com/v1/tracks/1bqHDCBs1wtB7VkAJ9NHjB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1bqHDCBs1wtB7VkAJ9NHjB',
#   'duration_ms': 306453,
#   'time_signature': 4},
#  {'danceability': 0.777,
#   'energy': 0.72,
#   'key': 8,
#   'loudness': -6.162,
#   'mode': 1,
#   'speechiness': 0.0803,
#   'acousticness': 0.778,
#   'instrumentalness': 0,
#   'liveness': 0.069,
#   'valence': 0.96,
#   'tempo': 163.905,
#   'type': 'audio_features',
#   'id': '5YfqVqJwjxiyhxvofbCnHp',
#   'uri': 'spotify:track:5YfqVqJwjxiyhxvofbCnHp',
#   'track_href': 'https://api.spotify.com/v1/tracks/5YfqVqJwjxiyhxvofbCnHp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YfqVqJwjxiyhxvofbCnHp',
#   'duration_ms': 266787,
#   'time_signature': 4},
#  {'danceability': 0.66,
#   'energy': 0.756,
#   'key': 8,
#   'loudness': -4.903,
#   'mode': 1,
#   'speechiness': 0.0443,
#   'acousticness': 0.727,
#   'instrumentalness': 0.000323,
#   'liveness': 0.115,
#   'valence': 0.768,
#   'tempo': 90.839,
#   'type': 'audio_features',
#   'id': '1HWbpfmzt1YplLceHgirCv',
#   'uri': 'spotify:track:1HWbpfmzt1YplLceHgirCv',
#   'track_href': 'https://api.spotify.com/v1/tracks/1HWbpfmzt1YplLceHgirCv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HWbpfmzt1YplLceHgirCv',
#   'duration_ms': 273763,
#   'time_signature': 4},
#  {'danceability': 0.645,
#   'energy': 0.665,
#   'key': 7,
#   'loudness': -5.519,
#   'mode': 0,
#   'speechiness': 0.0384,
#   'acousticness': 0.581,
#   'instrumentalness': 0,
#   'liveness': 0.0391,
#   'valence': 0.369,
#   'tempo': 94.115,
#   'type': 'audio_features',
#   'id': '5XWfwjzFNl2pTB737fx7qr',
#   'uri': 'spotify:track:5XWfwjzFNl2pTB737fx7qr',
#   'track_href': 'https://api.spotify.com/v1/tracks/5XWfwjzFNl2pTB737fx7qr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XWfwjzFNl2pTB737fx7qr',
#   'duration_ms': 414707,
#   'time_signature': 4},
#  {'danceability': 0.664,
#   'energy': 0.869,
#   'key': 7,
#   'loudness': -4.348,
#   'mode': 0,
#   'speechiness': 0.0381,
#   'acousticness': 0.199,
#   'instrumentalness': 0,
#   'liveness': 0.198,
#   'valence': 0.88,
#   'tempo': 95.014,
#   'type': 'audio_features',
#   'id': '5gKOs03E43d3TGZYzelQsY',
#   'uri': 'spotify:track:5gKOs03E43d3TGZYzelQsY',
#   'track_href': 'https://api.spotify.com/v1/tracks/5gKOs03E43d3TGZYzelQsY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5gKOs03E43d3TGZYzelQsY',
#   'duration_ms': 273576,
#   'time_signature': 4},
#  {'danceability': 0.656,
#   'energy': 0.8,
#   'key': 0,
#   'loudness': -4.037,
#   'mode': 1,
#   'speechiness': 0.0434,
#   'acousticness': 0.603,
#   'instrumentalness': 0.00362,
#   'liveness': 0.0682,
#   'valence': 0.6,
#   'tempo': 179.5,
#   'type': 'audio_features',
#   'id': '7mIlFG1PKmqfTsaT48dEU4',
#   'uri': 'spotify:track:7mIlFG1PKmqfTsaT48dEU4',
#   'track_href': 'https://api.spotify.com/v1/tracks/7mIlFG1PKmqfTsaT48dEU4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7mIlFG1PKmqfTsaT48dEU4',
#   'duration_ms': 245653,
#   'time_signature': 4},
#  {'danceability': 0.606,
#   'energy': 0.839,
#   'key': 8,
#   'loudness': -4.39,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.404,
#   'instrumentalness': 0,
#   'liveness': 0.27,
#   'valence': 0.727,
#   'tempo': 177.668,
#   'type': 'audio_features',
#   'id': '2ozSogNm6z9G2Uv6a9iji4',
#   'uri': 'spotify:track:2ozSogNm6z9G2Uv6a9iji4',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ozSogNm6z9G2Uv6a9iji4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ozSogNm6z9G2Uv6a9iji4',
#   'duration_ms': 292920,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.977,
#   'key': 1,
#   'loudness': -3.57,
#   'mode': 1,
#   'speechiness': 0.0615,
#   'acousticness': 0.622,
#   'instrumentalness': 0,
#   'liveness': 0.328,
#   'valence': 0.801,
#   'tempo': 138.264,
#   'type': 'audio_features',
#   'id': '1GT0Q2ZTeKtIBueYKr4vhr',
#   'uri': 'spotify:track:1GT0Q2ZTeKtIBueYKr4vhr',
#   'track_href': 'https://api.spotify.com/v1/tracks/1GT0Q2ZTeKtIBueYKr4vhr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1GT0Q2ZTeKtIBueYKr4vhr',
#   'duration_ms': 232880,
#   'time_signature': 4},
#  {'danceability': 0.672,
#   'energy': 0.679,
#   'key': 9,
#   'loudness': -5.357,
#   'mode': 0,
#   'speechiness': 0.0484,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.09,
#   'valence': 0.504,
#   'tempo': 87.102,
#   'type': 'audio_features',
#   'id': '2URe3fGSKuCh8v0d49lsNU',
#   'uri': 'spotify:track:2URe3fGSKuCh8v0d49lsNU',
#   'track_href': 'https://api.spotify.com/v1/tracks/2URe3fGSKuCh8v0d49lsNU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2URe3fGSKuCh8v0d49lsNU',
#   'duration_ms': 276347,
#   'time_signature': 4},
#  {'danceability': 0.653,
#   'energy': 0.827,
#   'key': 4,
#   'loudness': -3.206,
#   'mode': 0,
#   'speechiness': 0.042,
#   'acousticness': 0.649,
#   'instrumentalness': 0,
#   'liveness': 0.18,
#   'valence': 0.733,
#   'tempo': 95.223,
#   'type': 'audio_features',
#   'id': '7nDIflSHQXzaa8zupxwv3U',
#   'uri': 'spotify:track:7nDIflSHQXzaa8zupxwv3U',
#   'track_href': 'https://api.spotify.com/v1/tracks/7nDIflSHQXzaa8zupxwv3U',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7nDIflSHQXzaa8zupxwv3U',
#   'duration_ms': 259853,
#   'time_signature': 4},
#  {'danceability': 0.644,
#   'energy': 0.885,
#   'key': 11,
#   'loudness': -5.326,
#   'mode': 0,
#   'speechiness': 0.0466,
#   'acousticness': 0.516,
#   'instrumentalness': 0,
#   'liveness': 0.188,
#   'valence': 0.748,
#   'tempo': 176.759,
#   'type': 'audio_features',
#   'id': '0rBmvZ4ftXKpxsocjsbAun',
#   'uri': 'spotify:track:0rBmvZ4ftXKpxsocjsbAun',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rBmvZ4ftXKpxsocjsbAun',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rBmvZ4ftXKpxsocjsbAun',
#   'duration_ms': 275893,
#   'time_signature': 4},
#  {'danceability': 0.821,
#   'energy': 0.67,
#   'key': 5,
#   'loudness': -9.003,
#   'mode': 0,
#   'speechiness': 0.0494,
#   'acousticness': 0.514,
#   'instrumentalness': 0,
#   'liveness': 0.0732,
#   'valence': 0.969,
#   'tempo': 109.641,
#   'type': 'audio_features',
#   'id': '0xgdMUInG692P5WjBElwvR',
#   'uri': 'spotify:track:0xgdMUInG692P5WjBElwvR',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xgdMUInG692P5WjBElwvR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xgdMUInG692P5WjBElwvR',
#   'duration_ms': 317597,
#   'time_signature': 4},
#  {'danceability': 0.683,
#   'energy': 0.826,
#   'key': 7,
#   'loudness': -8.599,
#   'mode': 1,
#   'speechiness': 0.0727,
#   'acousticness': 0.506,
#   'instrumentalness': 0,
#   'liveness': 0.162,
#   'valence': 0.832,
#   'tempo': 171.131,
#   'type': 'audio_features',
#   'id': '5WyX397vZTvYQwSrylCka0',
#   'uri': 'spotify:track:5WyX397vZTvYQwSrylCka0',
#   'track_href': 'https://api.spotify.com/v1/tracks/5WyX397vZTvYQwSrylCka0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5WyX397vZTvYQwSrylCka0',
#   'duration_ms': 255213,
#   'time_signature': 4},
#  {'danceability': 0.574,
#   'energy': 0.802,
#   'key': 7,
#   'loudness': -3.976,
#   'mode': 1,
#   'speechiness': 0.0316,
#   'acousticness': 0.659,
#   'instrumentalness': 5.07e-06,
#   'liveness': 0.0765,
#   'valence': 0.739,
#   'tempo': 93.537,
#   'type': 'audio_features',
#   'id': '47TyfLrGhYHHyyQWk64d0M',
#   'uri': 'spotify:track:47TyfLrGhYHHyyQWk64d0M',
#   'track_href': 'https://api.spotify.com/v1/tracks/47TyfLrGhYHHyyQWk64d0M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/47TyfLrGhYHHyyQWk64d0M',
#   'duration_ms': 280453,
#   'time_signature': 4},
#  {'danceability': 0.684,
#   'energy': 0.946,
#   'key': 0,
#   'loudness': -2.37,
#   'mode': 0,
#   'speechiness': 0.0527,
#   'acousticness': 0.266,
#   'instrumentalness': 0.00012,
#   'liveness': 0.393,
#   'valence': 0.846,
#   'tempo': 112.002,
#   'type': 'audio_features',
#   'id': '2QOA0E6cuORpCD6gfKCoRk',
#   'uri': 'spotify:track:2QOA0E6cuORpCD6gfKCoRk',
#   'track_href': 'https://api.spotify.com/v1/tracks/2QOA0E6cuORpCD6gfKCoRk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2QOA0E6cuORpCD6gfKCoRk',
#   'duration_ms': 256000,
#   'time_signature': 4},
#  {'danceability': 0.791,
#   'energy': 0.972,
#   'key': 7,
#   'loudness': -0.694,
#   'mode': 0,
#   'speechiness': 0.0599,
#   'acousticness': 0.359,
#   'instrumentalness': 0,
#   'liveness': 0.136,
#   'valence': 0.894,
#   'tempo': 107.542,
#   'type': 'audio_features',
#   'id': '0bUgIkg2Nyoqon5ypj2sUt',
#   'uri': 'spotify:track:0bUgIkg2Nyoqon5ypj2sUt',
#   'track_href': 'https://api.spotify.com/v1/tracks/0bUgIkg2Nyoqon5ypj2sUt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0bUgIkg2Nyoqon5ypj2sUt',
#   'duration_ms': 237345,
#   'time_signature': 4},
#  {'danceability': 0.777,
#   'energy': 0.691,
#   'key': 8,
#   'loudness': -11.591,
#   'mode': 1,
#   'speechiness': 0.0716,
#   'acousticness': 0.164,
#   'instrumentalness': 3.53e-06,
#   'liveness': 0.246,
#   'valence': 0.801,
#   'tempo': 100.398,
#   'type': 'audio_features',
#   'id': '0Tu9FmT2ATnzwTQm9TcnGu',
#   'uri': 'spotify:track:0Tu9FmT2ATnzwTQm9TcnGu',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Tu9FmT2ATnzwTQm9TcnGu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Tu9FmT2ATnzwTQm9TcnGu',
#   'duration_ms': 224705,
#   'time_signature': 4},
#  {'danceability': 0.724,
#   'energy': 0.77,
#   'key': 4,
#   'loudness': -4.024,
#   'mode': 1,
#   'speechiness': 0.0533,
#   'acousticness': 0.184,
#   'instrumentalness': 3.7e-05,
#   'liveness': 0.243,
#   'valence': 0.935,
#   'tempo': 176.243,
#   'type': 'audio_features',
#   'id': '0bXUbrHbHOcvyv1Fmurmfq',
#   'uri': 'spotify:track:0bXUbrHbHOcvyv1Fmurmfq',
#   'track_href': 'https://api.spotify.com/v1/tracks/0bXUbrHbHOcvyv1Fmurmfq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0bXUbrHbHOcvyv1Fmurmfq',
#   'duration_ms': 278872,
#   'time_signature': 4},
#  {'danceability': 0.623,
#   'energy': 0.899,
#   'key': 7,
#   'loudness': -3.262,
#   'mode': 1,
#   'speechiness': 0.0434,
#   'acousticness': 0.497,
#   'instrumentalness': 8.35e-06,
#   'liveness': 0.463,
#   'valence': 0.905,
#   'tempo': 104.947,
#   'type': 'audio_features',
#   'id': '19TJqGoUMbptYQ1Lwfd2Ri',
#   'uri': 'spotify:track:19TJqGoUMbptYQ1Lwfd2Ri',
#   'track_href': 'https://api.spotify.com/v1/tracks/19TJqGoUMbptYQ1Lwfd2Ri',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/19TJqGoUMbptYQ1Lwfd2Ri',
#   'duration_ms': 246422,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.884,
#   'key': 8,
#   'loudness': -6.275,
#   'mode': 1,
#   'speechiness': 0.0527,
#   'acousticness': 0.549,
#   'instrumentalness': 0.000364,
#   'liveness': 0.0492,
#   'valence': 0.964,
#   'tempo': 93.058,
#   'type': 'audio_features',
#   'id': '2naqSVQHgiaoEpxtkVOhmK',
#   'uri': 'spotify:track:2naqSVQHgiaoEpxtkVOhmK',
#   'track_href': 'https://api.spotify.com/v1/tracks/2naqSVQHgiaoEpxtkVOhmK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2naqSVQHgiaoEpxtkVOhmK',
#   'duration_ms': 228554,
#   'time_signature': 4},
#  {'danceability': 0.799,
#   'energy': 0.843,
#   'key': 11,
#   'loudness': -4.424,
#   'mode': 0,
#   'speechiness': 0.053,
#   'acousticness': 0.0338,
#   'instrumentalness': 3.33e-05,
#   'liveness': 0.199,
#   'valence': 0.96,
#   'tempo': 110.726,
#   'type': 'audio_features',
#   'id': '7nflSbrgBCitUnW4psdR7a',
#   'uri': 'spotify:track:7nflSbrgBCitUnW4psdR7a',
#   'track_href': 'https://api.spotify.com/v1/tracks/7nflSbrgBCitUnW4psdR7a',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7nflSbrgBCitUnW4psdR7a',
#   'duration_ms': 253347,
#   'time_signature': 4},
#  {'danceability': 0.623,
#   'energy': 0.785,
#   'key': 8,
#   'loudness': -3.797,
#   'mode': 1,
#   'speechiness': 0.052,
#   'acousticness': 0.0834,
#   'instrumentalness': 1.18e-05,
#   'liveness': 0.0604,
#   'valence': 0.678,
#   'tempo': 122.363,
#   'type': 'audio_features',
#   'id': '2wBnlC3DdW9s1UnFlAWCdI',
#   'uri': 'spotify:track:2wBnlC3DdW9s1UnFlAWCdI',
#   'track_href': 'https://api.spotify.com/v1/tracks/2wBnlC3DdW9s1UnFlAWCdI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2wBnlC3DdW9s1UnFlAWCdI',
#   'duration_ms': 315267,
#   'time_signature': 4},
#  {'danceability': 0.774,
#   'energy': 0.771,
#   'key': 8,
#   'loudness': -4.463,
#   'mode': 1,
#   'speechiness': 0.0417,
#   'acousticness': 0.678,
#   'instrumentalness': 0,
#   'liveness': 0.739,
#   'valence': 0.905,
#   'tempo': 94.945,
#   'type': 'audio_features',
#   'id': '5irJ9qqvXp2hPpRqAhqWiS',
#   'uri': 'spotify:track:5irJ9qqvXp2hPpRqAhqWiS',
#   'track_href': 'https://api.spotify.com/v1/tracks/5irJ9qqvXp2hPpRqAhqWiS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5irJ9qqvXp2hPpRqAhqWiS',
#   'duration_ms': 275760,
#   'time_signature': 4},
#  {'danceability': 0.797,
#   'energy': 0.813,
#   'key': 7,
#   'loudness': -2.935,
#   'mode': 1,
#   'speechiness': 0.0501,
#   'acousticness': 0.456,
#   'instrumentalness': 0,
#   'liveness': 0.14,
#   'valence': 0.645,
#   'tempo': 102.906,
#   'type': 'audio_features',
#   'id': '4RCzKrRP5OrB4bvINizTGf',
#   'uri': 'spotify:track:4RCzKrRP5OrB4bvINizTGf',
#   'track_href': 'https://api.spotify.com/v1/tracks/4RCzKrRP5OrB4bvINizTGf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4RCzKrRP5OrB4bvINizTGf',
#   'duration_ms': 260920,
#   'time_signature': 4},
#  {'danceability': 0.527,
#   'energy': 0.59,
#   'key': 2,
#   'loudness': -8.897,
#   'mode': 0,
#   'speechiness': 0.0347,
#   'acousticness': 0.39,
#   'instrumentalness': 0,
#   'liveness': 0.223,
#   'valence': 0.881,
#   'tempo': 96.687,
#   'type': 'audio_features',
#   'id': '4UHRMwbbiZ7tkeEkhyN7iB',
#   'uri': 'spotify:track:4UHRMwbbiZ7tkeEkhyN7iB',
#   'track_href': 'https://api.spotify.com/v1/tracks/4UHRMwbbiZ7tkeEkhyN7iB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4UHRMwbbiZ7tkeEkhyN7iB',
#   'duration_ms': 279850,
#   'time_signature': 4},
#  {'danceability': 0.62,
#   'energy': 0.766,
#   'key': 5,
#   'loudness': -5.409,
#   'mode': 0,
#   'speechiness': 0.0376,
#   'acousticness': 0.166,
#   'instrumentalness': 0.00333,
#   'liveness': 0.125,
#   'valence': 0.815,
#   'tempo': 106.168,
#   'type': 'audio_features',
#   'id': '5N8HRh3pKXakJrdxQKMi1j',
#   'uri': 'spotify:track:5N8HRh3pKXakJrdxQKMi1j',
#   'track_href': 'https://api.spotify.com/v1/tracks/5N8HRh3pKXakJrdxQKMi1j',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5N8HRh3pKXakJrdxQKMi1j',
#   'duration_ms': 293787,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.668,
#   'key': 1,
#   'loudness': -6.942,
#   'mode': 0,
#   'speechiness': 0.0399,
#   'acousticness': 0.151,
#   'instrumentalness': 0,
#   'liveness': 0.0838,
#   'valence': 0.94,
#   'tempo': 99.16,
#   'type': 'audio_features',
#   'id': '41LiGcvaTkXHyPjfsxKvWv',
#   'uri': 'spotify:track:41LiGcvaTkXHyPjfsxKvWv',
#   'track_href': 'https://api.spotify.com/v1/tracks/41LiGcvaTkXHyPjfsxKvWv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/41LiGcvaTkXHyPjfsxKvWv',
#   'duration_ms': 278333,
#   'time_signature': 4},
#  {'danceability': 0.772,
#   'energy': 0.645,
#   'key': 5,
#   'loudness': -8.32,
#   'mode': 0,
#   'speechiness': 0.0465,
#   'acousticness': 0.66,
#   'instrumentalness': 1.45e-05,
#   'liveness': 0.142,
#   'valence': 0.968,
#   'tempo': 93.876,
#   'type': 'audio_features',
#   'id': '4zOZQdgs7nSjMkqB7keSM5',
#   'uri': 'spotify:track:4zOZQdgs7nSjMkqB7keSM5',
#   'track_href': 'https://api.spotify.com/v1/tracks/4zOZQdgs7nSjMkqB7keSM5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zOZQdgs7nSjMkqB7keSM5',
#   'duration_ms': 261333,
#   'time_signature': 4},
#  {'danceability': 0.76,
#   'energy': 0.635,
#   'key': 2,
#   'loudness': -6.48,
#   'mode': 1,
#   'speechiness': 0.0409,
#   'acousticness': 0.618,
#   'instrumentalness': 4.35e-05,
#   'liveness': 0.118,
#   'valence': 0.931,
#   'tempo': 106.672,
#   'type': 'audio_features',
#   'id': '6SZrhuLGjIzsliOLEG7Y7O',
#   'uri': 'spotify:track:6SZrhuLGjIzsliOLEG7Y7O',
#   'track_href': 'https://api.spotify.com/v1/tracks/6SZrhuLGjIzsliOLEG7Y7O',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SZrhuLGjIzsliOLEG7Y7O',
#   'duration_ms': 229355,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.884,
#   'key': 8,
#   'loudness': -6.275,
#   'mode': 1,
#   'speechiness': 0.0527,
#   'acousticness': 0.549,
#   'instrumentalness': 0.000364,
#   'liveness': 0.0492,
#   'valence': 0.964,
#   'tempo': 93.058,
#   'type': 'audio_features',
#   'id': '2naqSVQHgiaoEpxtkVOhmK',
#   'uri': 'spotify:track:2naqSVQHgiaoEpxtkVOhmK',
#   'track_href': 'https://api.spotify.com/v1/tracks/2naqSVQHgiaoEpxtkVOhmK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2naqSVQHgiaoEpxtkVOhmK',
#   'duration_ms': 228554,
#   'time_signature': 4},
#  {'danceability': 0.661,
#   'energy': 0.61,
#   'key': 8,
#   'loudness': -9.824,
#   'mode': 1,
#   'speechiness': 0.0707,
#   'acousticness': 0.777,
#   'instrumentalness': 0,
#   'liveness': 0.0475,
#   'valence': 0.452,
#   'tempo': 96.402,
#   'type': 'audio_features',
#   'id': '2BOcua9pjhKuVtgN40AAHX',
#   'uri': 'spotify:track:2BOcua9pjhKuVtgN40AAHX',
#   'track_href': 'https://api.spotify.com/v1/tracks/2BOcua9pjhKuVtgN40AAHX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2BOcua9pjhKuVtgN40AAHX',
#   'duration_ms': 303400,
#   'time_signature': 4},
#  {'danceability': 0.691,
#   'energy': 0.873,
#   'key': 5,
#   'loudness': -8.758,
#   'mode': 0,
#   'speechiness': 0.0382,
#   'acousticness': 0.33,
#   'instrumentalness': 1.63e-06,
#   'liveness': 0.0362,
#   'valence': 0.916,
#   'tempo': 93.685,
#   'type': 'audio_features',
#   'id': '2kBgJXGbVA6WcA40IFA9KF',
#   'uri': 'spotify:track:2kBgJXGbVA6WcA40IFA9KF',
#   'track_href': 'https://api.spotify.com/v1/tracks/2kBgJXGbVA6WcA40IFA9KF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2kBgJXGbVA6WcA40IFA9KF',
#   'duration_ms': 251253,
#   'time_signature': 4},
#  {'danceability': 0.571,
#   'energy': 0.755,
#   'key': 1,
#   'loudness': -7.907,
#   'mode': 1,
#   'speechiness': 0.0735,
#   'acousticness': 0.142,
#   'instrumentalness': 2.55e-05,
#   'liveness': 0.136,
#   'valence': 0.875,
#   'tempo': 107.951,
#   'type': 'audio_features',
#   'id': '00Ro1lnV3V6i87aY4t8Q43',
#   'uri': 'spotify:track:00Ro1lnV3V6i87aY4t8Q43',
#   'track_href': 'https://api.spotify.com/v1/tracks/00Ro1lnV3V6i87aY4t8Q43',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00Ro1lnV3V6i87aY4t8Q43',
#   'duration_ms': 376013,
#   'time_signature': 4},
#  {'danceability': 0.616,
#   'energy': 0.674,
#   'key': 10,
#   'loudness': -6.701,
#   'mode': 0,
#   'speechiness': 0.044,
#   'acousticness': 0.585,
#   'instrumentalness': 0,
#   'liveness': 0.904,
#   'valence': 0.783,
#   'tempo': 91.096,
#   'type': 'audio_features',
#   'id': '4UXdWLgdsdmkeOFABIGwZY',
#   'uri': 'spotify:track:4UXdWLgdsdmkeOFABIGwZY',
#   'track_href': 'https://api.spotify.com/v1/tracks/4UXdWLgdsdmkeOFABIGwZY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4UXdWLgdsdmkeOFABIGwZY',
#   'duration_ms': 367920,
#   'time_signature': 4},
#  {'danceability': 0.75,
#   'energy': 0.64,
#   'key': 4,
#   'loudness': -4.537,
#   'mode': 0,
#   'speechiness': 0.0365,
#   'acousticness': 0.37,
#   'instrumentalness': 0,
#   'liveness': 0.122,
#   'valence': 0.645,
#   'tempo': 92.038,
#   'type': 'audio_features',
#   'id': '16c6awlmGfeusU7zoVu5yc',
#   'uri': 'spotify:track:16c6awlmGfeusU7zoVu5yc',
#   'track_href': 'https://api.spotify.com/v1/tracks/16c6awlmGfeusU7zoVu5yc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/16c6awlmGfeusU7zoVu5yc',
#   'duration_ms': 231410,
#   'time_signature': 4},
#  {'danceability': 0.642,
#   'energy': 0.7,
#   'key': 1,
#   'loudness': -9.213,
#   'mode': 1,
#   'speechiness': 0.0552,
#   'acousticness': 0.172,
#   'instrumentalness': 0.000232,
#   'liveness': 0.0895,
#   'valence': 0.784,
#   'tempo': 103.899,
#   'type': 'audio_features',
#   'id': '4tw0DIMjr09hH0Ot8ePp0w',
#   'uri': 'spotify:track:4tw0DIMjr09hH0Ot8ePp0w',
#   'track_href': 'https://api.spotify.com/v1/tracks/4tw0DIMjr09hH0Ot8ePp0w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4tw0DIMjr09hH0Ot8ePp0w',
#   'duration_ms': 312480,
#   'time_signature': 4},
#  {'danceability': 0.549,
#   'energy': 0.498,
#   'key': 7,
#   'loudness': -9.203,
#   'mode': 0,
#   'speechiness': 0.0371,
#   'acousticness': 0.694,
#   'instrumentalness': 3.87e-05,
#   'liveness': 0.109,
#   'valence': 0.575,
#   'tempo': 95.345,
#   'type': 'audio_features',
#   'id': '5Uve0jm1RgxKWzdSvncBDO',
#   'uri': 'spotify:track:5Uve0jm1RgxKWzdSvncBDO',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Uve0jm1RgxKWzdSvncBDO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Uve0jm1RgxKWzdSvncBDO',
#   'duration_ms': 626880,
#   'time_signature': 4},
#  {'danceability': 0.473,
#   'energy': 0.817,
#   'key': 0,
#   'loudness': -6.186,
#   'mode': 1,
#   'speechiness': 0.0376,
#   'acousticness': 0.354,
#   'instrumentalness': 1.9e-05,
#   'liveness': 0.0834,
#   'valence': 0.92,
#   'tempo': 164.718,
#   'type': 'audio_features',
#   'id': '56Zt2aybXpAHIA4dxxKQxF',
#   'uri': 'spotify:track:56Zt2aybXpAHIA4dxxKQxF',
#   'track_href': 'https://api.spotify.com/v1/tracks/56Zt2aybXpAHIA4dxxKQxF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56Zt2aybXpAHIA4dxxKQxF',
#   'duration_ms': 297067,
#   'time_signature': 4},
#  {'danceability': 0.807,
#   'energy': 0.768,
#   'key': 5,
#   'loudness': -6.745,
#   'mode': 0,
#   'speechiness': 0.0427,
#   'acousticness': 0.332,
#   'instrumentalness': 3.09e-06,
#   'liveness': 0.251,
#   'valence': 0.962,
#   'tempo': 100.324,
#   'type': 'audio_features',
#   'id': '3GgI4QQWvsqqdKCvnNN0UM',
#   'uri': 'spotify:track:3GgI4QQWvsqqdKCvnNN0UM',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GgI4QQWvsqqdKCvnNN0UM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GgI4QQWvsqqdKCvnNN0UM',
#   'duration_ms': 254933,
#   'time_signature': 4},
#  {'danceability': 0.699,
#   'energy': 0.613,
#   'key': 4,
#   'loudness': -7.376,
#   'mode': 1,
#   'speechiness': 0.0345,
#   'acousticness': 0.481,
#   'instrumentalness': 2.68e-05,
#   'liveness': 0.125,
#   'valence': 0.771,
#   'tempo': 161.339,
#   'type': 'audio_features',
#   'id': '2SSGUtDsmXSmUKi2YAcf7L',
#   'uri': 'spotify:track:2SSGUtDsmXSmUKi2YAcf7L',
#   'track_href': 'https://api.spotify.com/v1/tracks/2SSGUtDsmXSmUKi2YAcf7L',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2SSGUtDsmXSmUKi2YAcf7L',
#   'duration_ms': 286373,
#   'time_signature': 4},
#  {'danceability': 0.812,
#   'energy': 0.841,
#   'key': 7,
#   'loudness': -6.219,
#   'mode': 0,
#   'speechiness': 0.155,
#   'acousticness': 0.408,
#   'instrumentalness': 0,
#   'liveness': 0.193,
#   'valence': 0.961,
#   'tempo': 90.007,
#   'type': 'audio_features',
#   'id': '1wvWtEqSwnmoRuPkPb74Ef',
#   'uri': 'spotify:track:1wvWtEqSwnmoRuPkPb74Ef',
#   'track_href': 'https://api.spotify.com/v1/tracks/1wvWtEqSwnmoRuPkPb74Ef',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wvWtEqSwnmoRuPkPb74Ef',
#   'duration_ms': 245800,
#   'time_signature': 4},
#  {'danceability': 0.809,
#   'energy': 0.665,
#   'key': 0,
#   'loudness': -5.31,
#   'mode': 1,
#   'speechiness': 0.0305,
#   'acousticness': 0.671,
#   'instrumentalness': 0,
#   'liveness': 0.0911,
#   'valence': 0.615,
#   'tempo': 125.019,
#   'type': 'audio_features',
#   'id': '59YDizy2BZUUe3zlYYDxmv',
#   'uri': 'spotify:track:59YDizy2BZUUe3zlYYDxmv',
#   'track_href': 'https://api.spotify.com/v1/tracks/59YDizy2BZUUe3zlYYDxmv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/59YDizy2BZUUe3zlYYDxmv',
#   'duration_ms': 239040,
#   'time_signature': 4},
#  {'danceability': 0.765,
#   'energy': 0.842,
#   'key': 9,
#   'loudness': -5.305,
#   'mode': 1,
#   'speechiness': 0.0535,
#   'acousticness': 0.288,
#   'instrumentalness': 0,
#   'liveness': 0.0769,
#   'valence': 0.896,
#   'tempo': 109.963,
#   'type': 'audio_features',
#   'id': '537KE6mr2r62jIp1036Stq',
#   'uri': 'spotify:track:537KE6mr2r62jIp1036Stq',
#   'track_href': 'https://api.spotify.com/v1/tracks/537KE6mr2r62jIp1036Stq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/537KE6mr2r62jIp1036Stq',
#   'duration_ms': 207693,
#   'time_signature': 4},
#  {'danceability': 0.813,
#   'energy': 0.701,
#   'key': 0,
#   'loudness': -6.508,
#   'mode': 0,
#   'speechiness': 0.0701,
#   'acousticness': 0.489,
#   'instrumentalness': 0.00116,
#   'liveness': 0.294,
#   'valence': 0.855,
#   'tempo': 104.019,
#   'type': 'audio_features',
#   'id': '1BwrMGGhPA6GarWIYaFrW8',
#   'uri': 'spotify:track:1BwrMGGhPA6GarWIYaFrW8',
#   'track_href': 'https://api.spotify.com/v1/tracks/1BwrMGGhPA6GarWIYaFrW8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1BwrMGGhPA6GarWIYaFrW8',
#   'duration_ms': 278867,
#   'time_signature': 4},
#  {'danceability': 0.442,
#   'energy': 0.634,
#   'key': 0,
#   'loudness': -7.683,
#   'mode': 0,
#   'speechiness': 0.0307,
#   'acousticness': 0.0129,
#   'instrumentalness': 0.867,
#   'liveness': 0.0953,
#   'valence': 0.578,
#   'tempo': 98.093,
#   'type': 'audio_features',
#   'id': '0A6uCqTC2RS0x7lyDTIend',
#   'uri': 'spotify:track:0A6uCqTC2RS0x7lyDTIend',
#   'track_href': 'https://api.spotify.com/v1/tracks/0A6uCqTC2RS0x7lyDTIend',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0A6uCqTC2RS0x7lyDTIend',
#   'duration_ms': 409080,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.744,
#   'key': 5,
#   'loudness': -5.586,
#   'mode': 0,
#   'speechiness': 0.0359,
#   'acousticness': 0.647,
#   'instrumentalness': 0.000123,
#   'liveness': 0.328,
#   'valence': 0.967,
#   'tempo': 84.591,
#   'type': 'audio_features',
#   'id': '2soM5TyZ2c98CDMvXljT7a',
#   'uri': 'spotify:track:2soM5TyZ2c98CDMvXljT7a',
#   'track_href': 'https://api.spotify.com/v1/tracks/2soM5TyZ2c98CDMvXljT7a',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2soM5TyZ2c98CDMvXljT7a',
#   'duration_ms': 314040,
#   'time_signature': 4},
#  {'danceability': 0.688,
#   'energy': 0.614,
#   'key': 9,
#   'loudness': -9.247,
#   'mode': 1,
#   'speechiness': 0.0378,
#   'acousticness': 0.585,
#   'instrumentalness': 0,
#   'liveness': 0.0978,
#   'valence': 0.852,
#   'tempo': 176.396,
#   'type': 'audio_features',
#   'id': '36T4XY4vbxmw40XMJPe3zw',
#   'uri': 'spotify:track:36T4XY4vbxmw40XMJPe3zw',
#   'track_href': 'https://api.spotify.com/v1/tracks/36T4XY4vbxmw40XMJPe3zw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/36T4XY4vbxmw40XMJPe3zw',
#   'duration_ms': 307200,
#   'time_signature': 4},
#  {'danceability': 0.679,
#   'energy': 0.62,
#   'key': 0,
#   'loudness': -10.943,
#   'mode': 1,
#   'speechiness': 0.0469,
#   'acousticness': 0.549,
#   'instrumentalness': 0.0189,
#   'liveness': 0.0774,
#   'valence': 0.619,
#   'tempo': 179.505,
#   'type': 'audio_features',
#   'id': '1RpCXjlxFGS6LfPOvqSJ7M',
#   'uri': 'spotify:track:1RpCXjlxFGS6LfPOvqSJ7M',
#   'track_href': 'https://api.spotify.com/v1/tracks/1RpCXjlxFGS6LfPOvqSJ7M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1RpCXjlxFGS6LfPOvqSJ7M',
#   'duration_ms': 301573,
#   'time_signature': 4},
#  {'danceability': 0.42,
#   'energy': 0.843,
#   'key': 7,
#   'loudness': -4.692,
#   'mode': 1,
#   'speechiness': 0.0647,
#   'acousticness': 0.248,
#   'instrumentalness': 0,
#   'liveness': 0.078,
#   'valence': 0.539,
#   'tempo': 173.91,
#   'type': 'audio_features',
#   'id': '2MnKininlD8bY9ggRNSJ37',
#   'uri': 'spotify:track:2MnKininlD8bY9ggRNSJ37',
#   'track_href': 'https://api.spotify.com/v1/tracks/2MnKininlD8bY9ggRNSJ37',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MnKininlD8bY9ggRNSJ37',
#   'duration_ms': 302947,
#   'time_signature': 4},
#  {'danceability': 0.656,
#   'energy': 0.852,
#   'key': 5,
#   'loudness': -4.857,
#   'mode': 0,
#   'speechiness': 0.0359,
#   'acousticness': 0.397,
#   'instrumentalness': 5.34e-05,
#   'liveness': 0.0834,
#   'valence': 0.802,
#   'tempo': 165.094,
#   'type': 'audio_features',
#   'id': '6uR3Trakqs0tMkSBcuxXdb',
#   'uri': 'spotify:track:6uR3Trakqs0tMkSBcuxXdb',
#   'track_href': 'https://api.spotify.com/v1/tracks/6uR3Trakqs0tMkSBcuxXdb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6uR3Trakqs0tMkSBcuxXdb',
#   'duration_ms': 296040,
#   'time_signature': 4},
#  {'danceability': 0.525,
#   'energy': 0.704,
#   'key': 9,
#   'loudness': -5.801,
#   'mode': 0,
#   'speechiness': 0.0501,
#   'acousticness': 0.353,
#   'instrumentalness': 5.26e-06,
#   'liveness': 0.0743,
#   'valence': 0.855,
#   'tempo': 98.455,
#   'type': 'audio_features',
#   'id': '4pUmQqaZklcCOB3rFdWc7g',
#   'uri': 'spotify:track:4pUmQqaZklcCOB3rFdWc7g',
#   'track_href': 'https://api.spotify.com/v1/tracks/4pUmQqaZklcCOB3rFdWc7g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4pUmQqaZklcCOB3rFdWc7g',
#   'duration_ms': 289293,
#   'time_signature': 4},
#  {'danceability': 0.753,
#   'energy': 0.522,
#   'key': 10,
#   'loudness': -7.254,
#   'mode': 1,
#   'speechiness': 0.0416,
#   'acousticness': 0.831,
#   'instrumentalness': 0.00398,
#   'liveness': 0.407,
#   'valence': 0.862,
#   'tempo': 144.2,
#   'type': 'audio_features',
#   'id': '7arYtARCpVmLPsB8Chua4A',
#   'uri': 'spotify:track:7arYtARCpVmLPsB8Chua4A',
#   'track_href': 'https://api.spotify.com/v1/tracks/7arYtARCpVmLPsB8Chua4A',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7arYtARCpVmLPsB8Chua4A',
#   'duration_ms': 197067,
#   'time_signature': 4},
#  {'danceability': 0.724,
#   'energy': 0.77,
#   'key': 4,
#   'loudness': -4.024,
#   'mode': 1,
#   'speechiness': 0.0533,
#   'acousticness': 0.184,
#   'instrumentalness': 3.7e-05,
#   'liveness': 0.243,
#   'valence': 0.935,
#   'tempo': 176.243,
#   'type': 'audio_features',
#   'id': '4ZWksPVZdma0A5GiSCStIK',
#   'uri': 'spotify:track:4ZWksPVZdma0A5GiSCStIK',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ZWksPVZdma0A5GiSCStIK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ZWksPVZdma0A5GiSCStIK',
#   'duration_ms': 278872,
#   'time_signature': 4},
#  {'danceability': 0.725,
#   'energy': 0.889,
#   'key': 4,
#   'loudness': -3.257,
#   'mode': 1,
#   'speechiness': 0.0471,
#   'acousticness': 0.294,
#   'instrumentalness': 0.00311,
#   'liveness': 0.252,
#   'valence': 0.924,
#   'tempo': 99.672,
#   'type': 'audio_features',
#   'id': '3rsVX2Pd8UkjqF2MAZqeif',
#   'uri': 'spotify:track:3rsVX2Pd8UkjqF2MAZqeif',
#   'track_href': 'https://api.spotify.com/v1/tracks/3rsVX2Pd8UkjqF2MAZqeif',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3rsVX2Pd8UkjqF2MAZqeif',
#   'duration_ms': 302320,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.687,
#   'key': 8,
#   'loudness': -10.302,
#   'mode': 1,
#   'speechiness': 0.133,
#   'acousticness': 0.473,
#   'instrumentalness': 0,
#   'liveness': 0.0784,
#   'valence': 0.645,
#   'tempo': 111.932,
#   'type': 'audio_features',
#   'id': '7guVlnmdqpcFjJmwP6RSRr',
#   'uri': 'spotify:track:7guVlnmdqpcFjJmwP6RSRr',
#   'track_href': 'https://api.spotify.com/v1/tracks/7guVlnmdqpcFjJmwP6RSRr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7guVlnmdqpcFjJmwP6RSRr',
#   'duration_ms': 316960,
#   'time_signature': 4},
#  {'danceability': 0.578,
#   'energy': 0.774,
#   'key': 10,
#   'loudness': -4.729,
#   'mode': 1,
#   'speechiness': 0.0416,
#   'acousticness': 0.548,
#   'instrumentalness': 4.79e-06,
#   'liveness': 0.198,
#   'valence': 0.915,
#   'tempo': 176.78,
#   'type': 'audio_features',
#   'id': '5kwJWQgBaJWm1QZtWeC3uj',
#   'uri': 'spotify:track:5kwJWQgBaJWm1QZtWeC3uj',
#   'track_href': 'https://api.spotify.com/v1/tracks/5kwJWQgBaJWm1QZtWeC3uj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5kwJWQgBaJWm1QZtWeC3uj',
#   'duration_ms': 331773,
#   'time_signature': 4},
#  {'danceability': 0.777,
#   'energy': 0.72,
#   'key': 8,
#   'loudness': -6.162,
#   'mode': 1,
#   'speechiness': 0.0803,
#   'acousticness': 0.778,
#   'instrumentalness': 0,
#   'liveness': 0.069,
#   'valence': 0.96,
#   'tempo': 163.905,
#   'type': 'audio_features',
#   'id': '37nXsqE1XW0cxOQvIMsmFc',
#   'uri': 'spotify:track:37nXsqE1XW0cxOQvIMsmFc',
#   'track_href': 'https://api.spotify.com/v1/tracks/37nXsqE1XW0cxOQvIMsmFc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37nXsqE1XW0cxOQvIMsmFc',
#   'duration_ms': 266787,
#   'time_signature': 4},
#  {'danceability': 0.758,
#   'energy': 0.666,
#   'key': 5,
#   'loudness': -9.022,
#   'mode': 0,
#   'speechiness': 0.0445,
#   'acousticness': 0.56,
#   'instrumentalness': 0,
#   'liveness': 0.0912,
#   'valence': 0.961,
#   'tempo': 92.811,
#   'type': 'audio_features',
#   'id': '2WOMIZnu99mzeMo13bZq8m',
#   'uri': 'spotify:track:2WOMIZnu99mzeMo13bZq8m',
#   'track_href': 'https://api.spotify.com/v1/tracks/2WOMIZnu99mzeMo13bZq8m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2WOMIZnu99mzeMo13bZq8m',
#   'duration_ms': 296027,
#   'time_signature': 4},
#  {'danceability': 0.571,
#   'energy': 0.755,
#   'key': 1,
#   'loudness': -7.907,
#   'mode': 1,
#   'speechiness': 0.0735,
#   'acousticness': 0.142,
#   'instrumentalness': 2.55e-05,
#   'liveness': 0.136,
#   'valence': 0.875,
#   'tempo': 107.951,
#   'type': 'audio_features',
#   'id': '00Ro1lnV3V6i87aY4t8Q43',
#   'uri': 'spotify:track:00Ro1lnV3V6i87aY4t8Q43',
#   'track_href': 'https://api.spotify.com/v1/tracks/00Ro1lnV3V6i87aY4t8Q43',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00Ro1lnV3V6i87aY4t8Q43',
#   'duration_ms': 376013,
#   'time_signature': 4},
#  {'danceability': 0.527,
#   'energy': 0.715,
#   'key': 5,
#   'loudness': -8.309,
#   'mode': 0,
#   'speechiness': 0.0398,
#   'acousticness': 0.552,
#   'instrumentalness': 0.00622,
#   'liveness': 0.085,
#   'valence': 0.904,
#   'tempo': 93.979,
#   'type': 'audio_features',
#   'id': '6VQ2fI8goSX8mpSvytXkXR',
#   'uri': 'spotify:track:6VQ2fI8goSX8mpSvytXkXR',
#   'track_href': 'https://api.spotify.com/v1/tracks/6VQ2fI8goSX8mpSvytXkXR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6VQ2fI8goSX8mpSvytXkXR',
#   'duration_ms': 308693,
#   'time_signature': 4},
#  {'danceability': 0.642,
#   'energy': 0.7,
#   'key': 1,
#   'loudness': -9.213,
#   'mode': 1,
#   'speechiness': 0.0552,
#   'acousticness': 0.172,
#   'instrumentalness': 0.000232,
#   'liveness': 0.0895,
#   'valence': 0.784,
#   'tempo': 103.899,
#   'type': 'audio_features',
#   'id': '3WXfQDsASfXrSojk9WB3aR',
#   'uri': 'spotify:track:3WXfQDsASfXrSojk9WB3aR',
#   'track_href': 'https://api.spotify.com/v1/tracks/3WXfQDsASfXrSojk9WB3aR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WXfQDsASfXrSojk9WB3aR',
#   'duration_ms': 312480,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.719,
#   'key': 5,
#   'loudness': -5.353,
#   'mode': 0,
#   'speechiness': 0.0363,
#   'acousticness': 0.633,
#   'instrumentalness': 0.00015,
#   'liveness': 0.313,
#   'valence': 0.962,
#   'tempo': 84.414,
#   'type': 'audio_features',
#   'id': '5mg6sU732O35VMfCYk3lmX',
#   'uri': 'spotify:track:5mg6sU732O35VMfCYk3lmX',
#   'track_href': 'https://api.spotify.com/v1/tracks/5mg6sU732O35VMfCYk3lmX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mg6sU732O35VMfCYk3lmX',
#   'duration_ms': 314013,
#   'time_signature': 4},
#  {'danceability': 0.603,
#   'energy': 0.624,
#   'key': 4,
#   'loudness': -6.982,
#   'mode': 0,
#   'speechiness': 0.0305,
#   'acousticness': 0.197,
#   'instrumentalness': 0,
#   'liveness': 0.0992,
#   'valence': 0.334,
#   'tempo': 130.004,
#   'type': 'audio_features',
#   'id': '1UhC65P18YWD02sW0GiyMl',
#   'uri': 'spotify:track:1UhC65P18YWD02sW0GiyMl',
#   'track_href': 'https://api.spotify.com/v1/tracks/1UhC65P18YWD02sW0GiyMl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1UhC65P18YWD02sW0GiyMl',
#   'duration_ms': 305427,
#   'time_signature': 4},
#  {'danceability': 0.752,
#   'energy': 0.612,
#   'key': 5,
#   'loudness': -8.236,
#   'mode': 0,
#   'speechiness': 0.0525,
#   'acousticness': 0.589,
#   'instrumentalness': 0,
#   'liveness': 0.322,
#   'valence': 0.954,
#   'tempo': 109.689,
#   'type': 'audio_features',
#   'id': '73Wi69BqzsFX1QIAD144qN',
#   'uri': 'spotify:track:73Wi69BqzsFX1QIAD144qN',
#   'track_href': 'https://api.spotify.com/v1/tracks/73Wi69BqzsFX1QIAD144qN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/73Wi69BqzsFX1QIAD144qN',
#   'duration_ms': 289959,
#   'time_signature': 4},
#  {'danceability': 0.854,
#   'energy': 0.965,
#   'key': 3,
#   'loudness': -3.875,
#   'mode': 0,
#   'speechiness': 0.0756,
#   'acousticness': 0.349,
#   'instrumentalness': 0,
#   'liveness': 0.0721,
#   'valence': 0.894,
#   'tempo': 130.439,
#   'type': 'audio_features',
#   'id': '1UCDUtm50LQAgCxROVYaQ2',
#   'uri': 'spotify:track:1UCDUtm50LQAgCxROVYaQ2',
#   'track_href': 'https://api.spotify.com/v1/tracks/1UCDUtm50LQAgCxROVYaQ2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1UCDUtm50LQAgCxROVYaQ2',
#   'duration_ms': 257489,
#   'time_signature': 4},
#  {'danceability': 0.909,
#   'energy': 0.816,
#   'key': 0,
#   'loudness': -5.059,
#   'mode': 1,
#   'speechiness': 0.105,
#   'acousticness': 0.254,
#   'instrumentalness': 0,
#   'liveness': 0.0852,
#   'valence': 0.891,
#   'tempo': 111.851,
#   'type': 'audio_features',
#   'id': '28fHEGFHiQGiP7uQUGxInK',
#   'uri': 'spotify:track:28fHEGFHiQGiP7uQUGxInK',
#   'track_href': 'https://api.spotify.com/v1/tracks/28fHEGFHiQGiP7uQUGxInK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/28fHEGFHiQGiP7uQUGxInK',
#   'duration_ms': 223887,
#   'time_signature': 4},
#  {'danceability': 0.425,
#   'energy': 0.823,
#   'key': 8,
#   'loudness': -5.628,
#   'mode': 1,
#   'speechiness': 0.0458,
#   'acousticness': 0.385,
#   'instrumentalness': 0,
#   'liveness': 0.0882,
#   'valence': 0.847,
#   'tempo': 92.118,
#   'type': 'audio_features',
#   'id': '3WSASuEFLKfnGbn3ZelPdu',
#   'uri': 'spotify:track:3WSASuEFLKfnGbn3ZelPdu',
#   'track_href': 'https://api.spotify.com/v1/tracks/3WSASuEFLKfnGbn3ZelPdu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WSASuEFLKfnGbn3ZelPdu',
#   'duration_ms': 228250,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.868,
#   'key': 7,
#   'loudness': -7.285,
#   'mode': 0,
#   'speechiness': 0.0444,
#   'acousticness': 0.256,
#   'instrumentalness': 0,
#   'liveness': 0.197,
#   'valence': 0.758,
#   'tempo': 94.098,
#   'type': 'audio_features',
#   'id': '7JElWLgpQ7lxN1JNIYwuVu',
#   'uri': 'spotify:track:7JElWLgpQ7lxN1JNIYwuVu',
#   'track_href': 'https://api.spotify.com/v1/tracks/7JElWLgpQ7lxN1JNIYwuVu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7JElWLgpQ7lxN1JNIYwuVu',
#   'duration_ms': 290413,
#   'time_signature': 4}]

# %%
salsa_playlist_df = pd.DataFrame(salsa_af_song)

# %%
salsa_playlist_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.691   0.658    0    -6.496     1       0.0359         0.398
# 1          0.805   0.757    8    -7.460     1       0.0355         0.279
# 2          0.656   0.877    0    -3.231     0       0.0342         0.345
# 3          0.600   0.633    4    -7.507     0       0.0667         0.741
# 4          0.481   0.787    4    -4.218     0       0.0926         0.381
# ..           ...     ...  ...       ...   ...          ...           ...
# 67         0.752   0.612    5    -8.236     0       0.0525         0.589
# 68         0.854   0.965    3    -3.875     0       0.0756         0.349
# 69         0.909   0.816    0    -5.059     1       0.1050         0.254
# 70         0.425   0.823    8    -5.628     1       0.0458         0.385
# 71         0.585   0.868    7    -7.285     0       0.0444         0.256
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000046    0.1120    0.617   97.680  audio_features
# 1           0.000839    0.1010    0.973  102.140  audio_features
# 2           0.000000    0.3490    0.894  105.018  audio_features
# 3           0.073600    0.0478    0.966  120.627  audio_features
# 4           0.000000    0.1120    0.734  182.279  audio_features
# ..               ...       ...      ...      ...             ...
# 67          0.000000    0.3220    0.954  109.689  audio_features
# 68          0.000000    0.0721    0.894  130.439  audio_features
# 69          0.000000    0.0852    0.891  111.851  audio_features
# 70          0.000000    0.0882    0.847   92.118  audio_features
# 71          0.000000    0.1970    0.758   94.098  audio_features
#
#                         id                                   uri  \
# 0   3yEtuhGR8jOtusa29jWrhG  spotify:track:3yEtuhGR8jOtusa29jWrhG
# 1   2q9udNV9NK0BL3q9p6TLxf  spotify:track:2q9udNV9NK0BL3q9p6TLxf
# 2   3QHMxEOAGD51PDlbFPHLyJ  spotify:track:3QHMxEOAGD51PDlbFPHLyJ
# 3   6ydEhrdfzhI29D2NBAqUY1  spotify:track:6ydEhrdfzhI29D2NBAqUY1
# 4   1bqHDCBs1wtB7VkAJ9NHjB  spotify:track:1bqHDCBs1wtB7VkAJ9NHjB
# ..                     ...                                   ...
# 67  73Wi69BqzsFX1QIAD144qN  spotify:track:73Wi69BqzsFX1QIAD144qN
# 68  1UCDUtm50LQAgCxROVYaQ2  spotify:track:1UCDUtm50LQAgCxROVYaQ2
# 69  28fHEGFHiQGiP7uQUGxInK  spotify:track:28fHEGFHiQGiP7uQUGxInK
# 70  3WSASuEFLKfnGbn3ZelPdu  spotify:track:3WSASuEFLKfnGbn3ZelPdu
# 71  7JElWLgpQ7lxN1JNIYwuVu  spotify:track:7JElWLgpQ7lxN1JNIYwuVu
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/3yEtuhGR8jOt...
# 1   https://api.spotify.com/v1/tracks/2q9udNV9NK0B...
# 2   https://api.spotify.com/v1/tracks/3QHMxEOAGD51...
# 3   https://api.spotify.com/v1/tracks/6ydEhrdfzhI2...
# 4   https://api.spotify.com/v1/tracks/1bqHDCBs1wtB...
# ..                                                ...
# 67  https://api.spotify.com/v1/tracks/73Wi69BqzsFX...
# 68  https://api.spotify.com/v1/tracks/1UCDUtm50LQA...
# 69  https://api.spotify.com/v1/tracks/28fHEGFHiQGi...
# 70  https://api.spotify.com/v1/tracks/3WSASuEFLKfn...
# 71  https://api.spotify.com/v1/tracks/7JElWLgpQ7lx...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/3yEt...       300160
# 1   https://api.spotify.com/v1/audio-analysis/2q9u...       271031
# 2   https://api.spotify.com/v1/audio-analysis/3QHM...       252347
# 3   https://api.spotify.com/v1/audio-analysis/6ydE...       291947
# 4   https://api.spotify.com/v1/audio-analysis/1bqH...       306453
# ..                                                ...          ...
# 67  https://api.spotify.com/v1/audio-analysis/73Wi...       289959
# 68  https://api.spotify.com/v1/audio-analysis/1UCD...       257489
# 69  https://api.spotify.com/v1/audio-analysis/28fH...       223887
# 70  https://api.spotify.com/v1/audio-analysis/3WSA...       228250
# 71  https://api.spotify.com/v1/audio-analysis/7JEl...       290413
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 67               4
# 68               4
# 69               4
# 70               4
# 71               4
#
# [72 rows x 18 columns]

# %%
eightees_playlist= get_playlist_tracks('spotify','37i9dQZF1DXbTxeAdrVG2l')

# %%
eightees_id =[]

# %%
for i in eightees_playlist:
    
    eightees_id.append(i["track"]["id"])

eightees_af_song =[]  
    
for i in eightees_id:
    eightees_af_song.append(sp.audio_features(i)[0])    
    
eightees_playlist_df = pd.DataFrame(eightees_af_song)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 3
#       1 for i in eightees_playlist:
# ----> 3     eightees_id.append(i["track"]["id"])
#       5 eightees_af_song =[]
#       7 for i in eightees_id:
#
# TypeError: string indices must be integers

# %%
sixties_playlist= get_playlist_tracks('spotify','37i9dQZF1DXaKIA8E7WcJj')

sixties_id =[]

for i in sixties_playlist:
    
    sixties_id.append(i["track"]["id"])
    
    
sixties_af_song =[]

for i in sixties_id:
    sixties_af_song.append(sp.audio_features(i)[0])

sixties_playlist_df = pd.DataFrame(sixties_af_song)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 7
#       3 sixties_id =[]
#       5 for i in sixties_playlist:
# ----> 7     sixties_id.append(i["track"]["id"])
#      10 sixties_af_song =[]
#      12 for i in sixties_id:
#
# TypeError: string indices must be integers

# %%
fifties_playlist= get_playlist_tracks('spotify',"37i9dQZF1DWSV3Tk4GO2fq")

fifties_id =[]

for i in fifties_playlist:
    
    fifties_id.append(i["track"]["id"])
    
    
fifties_af_song =[]

for i in fifties_id:
    fifties_af_song.append(sp.audio_features(i)[0])

fifties_playlist_df = pd.DataFrame(fifties_af_song)

# %%
rock_playlist= get_playlist_tracks('spotify',"37i9dQZF1DWSV3Tk4GO2fq")

rock_id =[]

for i in rock_playlist:
    
    rock_id.append(i["track"]["id"])
    
    
rock_af_song =[]

for i in rock_id:
    rock_af_song.append(sp.audio_features(i)[0])

rock_playlist_df = pd.DataFrame(rock_af_song)

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    audio_list = []
    for i in range(len(tracks)):
            audio_list.append(sp.audio_features(tracks[i]["track"]["id"])[0])
    audio_df = pd.DataFrame(audio_list)
    return audio_df
