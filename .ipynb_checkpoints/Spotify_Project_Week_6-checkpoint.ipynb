-01
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  2.003000e+03  2.003000e+03      2.003000e+03  2.003000e+03
# mean  -7.094785e-17  7.981633e-18      8.868481e-18 -1.152903e-16
# std    1.000250e+00  1.000250e+00      1.000250e+00  1.000250e+00
# min   -8.039891e-01 -8.289929e-01     -1.511093e-01 -1.157222e+00
# 25%   -6.128100e-01 -7.206748e-01     -1.511093e-01 -6.432277e-01
# 50%   -4.354511e-01 -3.995901e-01     -1.511093e-01 -3.995414e-01
# 75%    1.576648e-01  3.220760e-01     -1.505809e-01  4.127462e-01
# max    6.330677e+00  4.038811e+00      1.246576e+01  5.170431e+00
#
#             valence         tempo
# count  2.003000e+03  2.003000e+03
# mean   2.660544e-16 -5.356563e-16
# std    1.000250e+00  1.000250e+00
# min   -2.269111e+00 -2.169062e+00
# 25%   -7.441912e-01 -8.021962e-01
# 50%   -2.062287e-02  8.989320e-03
# 75%    7.753023e-01  6.762718e-01
# max    2.009891e+00  3.111363e+00

# %% [markdown]
# Now, all features will have the same weight.

# %% [markdown]
# ### Chosing K

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Training a K-Means model with 20 clusters!
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %% [markdown]
# ### Silouhette

# %%
K = range(2, 20)
silhouette = []
for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))
    
plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
from yellowbrick.cluster import SilhouetteVisualizer
model = KMeans(3, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
visualizer.fit(X_scaled_df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 2003 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
from yellowbrick.cluster import SilhouetteVisualizer
model = KMeans(5, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
visualizer.fit(X_scaled_df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 2003 Samples in 5 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
from yellowbrick.cluster import SilhouetteVisualizer
model = KMeans(7, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
visualizer.fit(X_scaled_df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 2003 Samples in 7 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# ### Clustering with K-Means

# %%
kmeans = KMeans(n_clusters=5, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=1234)

# %%
labels = kmeans.labels_
labels
# Out:
# array([0, 0, 0, ..., 0, 3, 3], dtype=int32)

# %%
np.unique(labels)
# Out:
# array([0, 1, 2, 3, 4], dtype=int32)

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 3])
    # show the plot
pyplot.show()

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    828
# 1    360
# 2    223
# 3    571
# 4     21
# dtype: int64

# %%
clusters
# Out:
# array([0, 0, 0, ..., 0, 3, 3], dtype=int32)

# %% [markdown]
# ## Creating the Cluster Column

# %%
#X_df = pd.DataFrame(X)
X["cluster"] = clusters
X
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.645   0.713    6    -5.355     1       0.0393       0.00835
# 1            0.666   0.830    0    -5.715     1       0.0751       0.01230
# 2            0.792   0.625    1    -5.609     1       0.0536       0.00776
# 3            0.664   0.714    7    -6.645     0       0.1110       0.03530
# 4            0.503   0.843   10    -4.991     0       0.3160       0.04870
# ...            ...     ...  ...       ...   ...          ...           ...
# 1998         0.534   0.803   10    -9.129     1       0.0743       0.74100
# 1999         0.581   0.780    4    -7.053     1       0.0567       0.50800
# 2000         0.328   0.936    0    -3.254     1       0.0628       0.06650
# 2001         0.623   0.537   10   -10.014     0       0.0726       0.33200
# 2002         0.676   0.659   11    -5.123     0       0.0476       0.19400
#
#       instrumentalness  liveness  valence    tempo  cluster
# 0             0.000000    0.1130    0.566   74.989        0
# 1             0.000000    0.1910    0.702  113.030        0
# 2             0.001800    0.3290    0.370  103.967        0
# 3             0.000008    0.0843    0.710  101.969        3
# 4             0.000000    0.3440    0.778  128.630        2
# ...                ...       ...      ...      ...      ...
# 1998          0.000061    0.3070    0.969  167.983        1
# 1999          0.000011    0.0799    0.561  123.711        1
# 2000          0.000003    0.1650    0.310  162.970        0
# 2001          0.000014    0.0963    0.905  166.885        3
# 2002          0.000000    0.2830    0.595  134.985        3
#
# [2003 rows x 12 columns]

# %%
X[X['cluster'] == 2].sample()
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 799         0.932   0.547    0    -7.787     0        0.333        0.0388
#
#      instrumentalness  liveness  valence   tempo  cluster
# 799               0.0    0.0924    0.695  94.998        2

# %%
X
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.645   0.713    6    -5.355     1       0.0393       0.00835
# 1            0.666   0.830    0    -5.715     1       0.0751       0.01230
# 2            0.792   0.625    1    -5.609     1       0.0536       0.00776
# 3            0.664   0.714    7    -6.645     0       0.1110       0.03530
# 4            0.503   0.843   10    -4.991     0       0.3160       0.04870
# ...            ...     ...  ...       ...   ...          ...           ...
# 1998         0.534   0.803   10    -9.129     1       0.0743       0.74100
# 1999         0.581   0.780    4    -7.053     1       0.0567       0.50800
# 2000         0.328   0.936    0    -3.254     1       0.0628       0.06650
# 2001         0.623   0.537   10   -10.014     0       0.0726       0.33200
# 2002         0.676   0.659   11    -5.123     0       0.0476       0.19400
#
#       instrumentalness  liveness  valence    tempo  cluster
# 0             0.000000    0.1130    0.566   74.989        0
# 1             0.000000    0.1910    0.702  113.030        0
# 2             0.001800    0.3290    0.370  103.967        0
# 3             0.000008    0.0843    0.710  101.969        3
# 4             0.000000    0.3440    0.778  128.630        2
# ...                ...       ...      ...      ...      ...
# 1998          0.000061    0.3070    0.969  167.983        1
# 1999          0.000011    0.0799    0.561  123.711        1
# 2000          0.000003    0.1650    0.310  162.970        0
# 2001          0.000014    0.0963    0.905  166.885        3
# 2002          0.000000    0.2830    0.595  134.985        3
#
# [2003 rows x 12 columns]

# %%
df = pd.read_csv("songs_id_file.csv")

# %%
df
# Out:
#                           id
# 0     2Z8WuEywRWYTKe1NybPQEW
# 1     6JV2JOEocMgcZxYSZelKcc
# 2     1zi7xx7UVEFkmKfv06H8x0
# 3     0vbtURX4qv1l7besfwmnD8
# 4     5YHR8wBR5jXfGtP766NiAT
# ...                      ...
# 1998  2QfiRTz5Yc8DdShCxG1tB2
# 1999  0bfvHnWWOeU1U5XeKyVLbW
# 2000  12dU3vAh6AFoJkisorfoUl
# 2001  452KBpASS5lZLeJWX9Ixub
# 2002  6ieWL5CLN9WdC875guWtMe
#
# [2003 rows x 1 columns]

# %%
final_df = pd.concat([df, X], axis=1)

# %%
final_df
# Out:
#                           id  danceability  energy  key  loudness  mode  \
# 0     2Z8WuEywRWYTKe1NybPQEW         0.645   0.713    6    -5.355     1
# 1     6JV2JOEocMgcZxYSZelKcc         0.666   0.830    0    -5.715     1
# 2     1zi7xx7UVEFkmKfv06H8x0         0.792   0.625    1    -5.609     1
# 3     0vbtURX4qv1l7besfwmnD8         0.664   0.714    7    -6.645     0
# 4     5YHR8wBR5jXfGtP766NiAT         0.503   0.843   10    -4.991     0
# ...                      ...           ...     ...  ...       ...   ...
# 1998  2QfiRTz5Yc8DdShCxG1tB2         0.534   0.803   10    -9.129     1
# 1999  0bfvHnWWOeU1U5XeKyVLbW         0.581   0.780    4    -7.053     1
# 2000  12dU3vAh6AFoJkisorfoUl         0.328   0.936    0    -3.254     1
# 2001  452KBpASS5lZLeJWX9Ixub         0.623   0.537   10   -10.014     0
# 2002  6ieWL5CLN9WdC875guWtMe         0.676   0.659   11    -5.123     0
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0393       0.00835          0.000000    0.1130    0.566   74.989
# 1          0.0751       0.01230          0.000000    0.1910    0.702  113.030
# 2          0.0536       0.00776          0.001800    0.3290    0.370  103.967
# 3          0.1110       0.03530          0.000008    0.0843    0.710  101.969
# 4          0.3160       0.04870          0.000000    0.3440    0.778  128.630
# ...           ...           ...               ...       ...      ...      ...
# 1998       0.0743       0.74100          0.000061    0.3070    0.969  167.983
# 1999       0.0567       0.50800          0.000011    0.0799    0.561  123.711
# 2000       0.0628       0.06650          0.000003    0.1650    0.310  162.970
# 2001       0.0726       0.33200          0.000014    0.0963    0.905  166.885
# 2002       0.0476       0.19400          0.000000    0.2830    0.595  134.985
#
#       cluster
# 0           0
# 1           0
# 2           0
# 3           3
# 4           2
# ...       ...
# 1998        1
# 1999        1
# 2000        0
# 2001        3
# 2002        3
#
# [2003 rows x 13 columns]

# %% [markdown]
# ### Parameters

# %%
kmeans.inertia_
# Out:
# 14941.978139527066

# %%
kmeans2 = KMeans(n_clusters=3,
                init="k-means++",
                n_init=50,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=1,
                tol=0,
                algorithm="elkan",
                random_state=1234)
kmeans2.fit(X_scaled_df)
print(kmeans2.inertia_)
# Out:
# 18005.926920912516

# %% [markdown]
# ## User INPUT / Embeded track player

# %%
from IPython.display import IFrame

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
song_input = input("Please, enter the song title: ")

user_input = sp.search(q= song_input, type='track', limit=1)

song_id = user_input ["tracks"]["items"][0]["id"]
song_id

display(play_song(song_id))

verified = input("Is this your song? (yes/no): ")

if verified.lower() == "yes":
    # Collect song features
    song_features = sp.audio_features([song_id])[0]
    
    # Create a DataFrame with the song features
    user_song = pd.DataFrame(song_features, index=[0])
    
    # Print the user_song DataFrame
    print("\nUser Song Features:")
    print(user_song)
# Out:
# Please, enter the song title: macarena
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/4oaj36KzXRgDg4McgcTsZK?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Is this your song? (yes/no): yes
#
# User Song Features:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.927   0.721    8   -12.561     1       0.0908         0.422
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000044    0.0422    0.965  103.018  audio_features
#
#                        id                                   uri  \
# 0  4oaj36KzXRgDg4McgcTsZK  spotify:track:4oaj36KzXRgDg4McgcTsZK
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4oaj36KzXRgD...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4oaj...       249382
#
#    time_signature
# 0               4

# %%
import pandas as pd

user =pd.DataFrame([song_features])

# %%
user
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.761   0.525   11      -6.9     1       0.0944          0.44
#
#    instrumentalness  liveness  valence  tempo            type  \
# 0          0.000007    0.0921    0.531  80.87  audio_features
#
#                        id                                   uri  \
# 0  3USxtqRwSYz57Ewm6wWRMp  spotify:track:3USxtqRwSYz57Ewm6wWRMp
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3USxtqRwSYz5...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3USx...       238805
#
#    time_signature
# 0               4

# %%
columns_to_drop = ['id', 'type', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature']
user = user.drop(columns=columns_to_drop)

# %%
user
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.761   0.525   11      -6.9     1       0.0944          0.44
#
#    instrumentalness  liveness  valence  tempo
# 0          0.000007    0.0921    0.531  80.87

# %% [markdown]
# ## Scaled & Predict

# %%
user_scaled = scaler.transform(user)
user_scaled_df = pd.DataFrame(user_scaled, columns=user.columns)
# Display the scaled user DataFrame
print("\nScaled User Song Features:")
user_scaled_df
# Out:
# Scaled User Song Features:
#    danceability    energy       key  loudness      mode  speechiness  \
# 0       0.89177 -1.123839  1.617441  -0.36727  0.762987      0.02407
#
#    acousticness  instrumentalness  liveness   valence   tempo
# 0      1.442259         -0.151014 -0.671897 -0.025145 -1.5101

# %% [markdown]
# ## Recommendation

# %%
# Apply KMeans prediction to user_scaled_df
user_cluster = kmeans2.predict(user_scaled_df)
# Filter recommended songs based on predicted cluster
recommended_songs = final_df[final_df['cluster'] == user_cluster[0]]
# Select a random song from recommended songs
recommended_song = recommended_songs.sample(n=1)
# Retrieve track_id of recommended song
recommended_track_id = recommended_song['id'].values[0]
# Display the recommended song
display(play_song(recommended_track_id))
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/0FDzzruyVECATHXKHFs9eJ?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
